# %% [markdown]
# # Overall Corpus Topic Modelling
#
# This notebook runs BERTopic on the **full Ditwah cyclone corpus** (all outlets combined),
# identifies the 10 most discussed topics, and uses an LLM to label each topic with a short
# aspect phrase and longer description.
#
# ## Approach
# 1. Load pre-computed embeddings for all articles across all outlets
# 2. Fit a single BERTopic model on the full corpus
# 3. Select the top 10 topics by article count
# 4. Extract keywords and representative articles per topic
# 5. Use an LLM to generate aspect labels and descriptions for each topic

# %% [markdown]
# ## 1. Setup

# %%
import sys
import json
import warnings
import numpy as np
import pandas as pd

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS
from sentence_transformers import SentenceTransformer

warnings.filterwarnings('ignore')
sys.path.append('..')

from src.db import get_db
from src.llm import get_llm
from dashboard.components.source_mapping import SOURCE_NAMES, SOURCE_COLORS

print("All imports successful")

# %%
# Configuration
EMBEDDING_MODEL = "google/embeddinggemma-300m"
N_TOPICS = 15
TOP_WORDS = 30
TOP_ARTICLES = 10

# BERTopic parameters for full corpus (~1600 articles)
MIN_TOPIC_SIZE = 10
MIN_DF = 5
UMAP_N_NEIGHBORS = 15
RANDOM_SEED = 42

# %% [markdown]
# ## 2. Version Selection & Data Loading

# %%
# Load all embeddings by model name (shared across versions)
print(f"Loading embeddings for model '{EMBEDDING_MODEL}'...")
with get_db() as db:
    emb_count = db.get_embedding_count(embedding_model=EMBEDDING_MODEL)
    if emb_count == 0:
        raise RuntimeError(
            f"No embeddings found for model '{EMBEDDING_MODEL}'. "
            f"Generate them first:\n"
            f"  python3 scripts/embeddings/01_generate_embeddings.py --model {EMBEDDING_MODEL}"
        )
    all_data = db.get_all_embeddings(embedding_model=EMBEDDING_MODEL)

documents = [f"{d['title']}\n\n{d['content']}" for d in all_data]
embeddings = np.array([d['embedding'] for d in all_data])
article_ids = [d['article_id'] for d in all_data]
titles = [d['title'] for d in all_data]
contents = [d['content'] for d in all_data]
sources = [d['source_id'] for d in all_data]

print(f"Corpus size: {len(documents)} articles")
print(f"Embedding dimensions: {embeddings.shape[1]}")
for src_id, src_name in SOURCE_NAMES.items():
    count = sum(1 for s in sources if s == src_id)
    print(f"  {src_name}: {count} articles")

# %% [markdown]
# ## 3. Fit BERTopic

# %%
import random
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# Load embedding model for topic representation
print(f"Loading SentenceTransformer model ({EMBEDDING_MODEL})...")
embedding_model = SentenceTransformer(EMBEDDING_MODEL)

custom_stop_words = sorted(set(ENGLISH_STOP_WORDS) | {"sri", "lanka", "lankan", "lankans", "cyclone", "ditwah", "cyclone ditwah", "disaster", "affected"})

umap_model = UMAP(
    n_neighbors=UMAP_N_NEIGHBORS,
    n_components=5,
    min_dist=0.0,
    metric='cosine',
    random_state=RANDOM_SEED,
)

hdbscan_model = HDBSCAN(
    min_cluster_size=MIN_TOPIC_SIZE,
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=True,
    core_dist_n_jobs=1,
)

vectorizer = CountVectorizer(
    ngram_range=(1, 3),
    stop_words=custom_stop_words,
    min_df=MIN_DF,
)

model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer,
    representation_model=KeyBERTInspired(),
    top_n_words=TOP_WORDS,
    verbose=False,
)

print("Fitting BERTopic on full corpus...")
topics, probs = model.fit_transform(documents, embeddings)

topic_info = model.get_topic_info()
n_topics = len(topic_info[topic_info['Topic'] != -1])
n_outliers = sum(1 for t in topics if t == -1)
print(f"\nTopics discovered: {n_topics}")
print(f"Outlier articles: {n_outliers}/{len(documents)} ({100*n_outliers/len(documents):.1f}%)")
print(f"Assigned articles: {len(documents) - n_outliers}")
# Out:
# Loading SentenceTransformer model (google/embeddinggemma-300m)...
# Fitting BERTopic on full corpus...
#
# Topics discovered: 44
# Outlier articles: 396/1657 (23.9%)
# Assigned articles: 1261

# %% [markdown]
# ## 4. Top 10 Topics

# %%
# Get top 10 non-outlier topics by article count
top_topics_df = (
    topic_info[topic_info['Topic'] != -1]
    .sort_values('Count', ascending=False)
    .head(N_TOPICS)
    .reset_index(drop=True)
)

print(f"Top {N_TOPICS} topics by article count:")
print(f"{'='*80}")
for i, row in top_topics_df.iterrows():
    tid = row['Topic']
    words = model.get_topic(tid)
    keyword_str = ', '.join(w for w, _ in words) if words else ''
    print(f"  Topic {tid:3d} | {row['Count']:4d} articles | {keyword_str}")

total_in_top = top_topics_df['Count'].sum()
total_assigned = len(documents) - n_outliers
print(f"\nTop {N_TOPICS} topics cover {total_in_top}/{total_assigned} assigned articles ({100*total_in_top/total_assigned:.1f}%)")

display(top_topics_df[['Topic', 'Count', 'Name']])
# Out:
# Top 15 topics by article count:
# ================================================================================
#   Topic   0 |   82 articles | country, government rebuilding, sanath, secretary president, financial, chief executive, secretary, chief, finance, corporate
#   Topic   1 |   64 articles | ceylon, development ministry, disruptions, gov, government, ministry, sector, impacted, export, national
#   Topic   2 |   63 articles | humanitarian assistance, indian naval, indian air force, naval, india, colombo, relief supplies, indian army, search rescue, operation sagar bandhu
#   Topic   3 |   55 articles | rescue, landslide, flood, landslides, nuwara eliya, displaced, colombo, report, anuradhapura, ongoing
#   Topic   4 |   54 articles | military, secretary, country, ministry, national, navy, defence, today, recovery, president
#   Topic   5 |   52 articles | srilankan, nature, resilience, srilankan airlines, colombo, nuwara eliya, wildlife, natural, destination, risk
#   Topic   6 |   51 articles | maldives, relief efforts, singapore, relief supplies, colombo, humanitarian, myanmar, rescue, foreign affairs, india
#   Topic   7 |   42 articles | foreign, infrastructure, rs trillion, international, president, dissanayake, sector, government, country, ministry
#   Topic   8 |   42 articles | cyclonic storm, heavy rainfall, heavy rain, cyclonic, meteorology, department meteorology, strong winds, forecast, rain, storm
#   Topic   9 |   41 articles | disasters, climate, resilience, foreign, infrastructure, emergency, construction, fdi, domestic, crisis
#   Topic  10 |   39 articles | flooding, landslides, infrastructure, colombo, nuwara eliya, development authority, ministry, deputy minister, national water, rail
#   Topic  11 |   38 articles | humanitarian, recovery reconstruction, emergency, debt sustainability, government, recovery, urgent, assistance, economic, country
#   Topic  12 |   35 articles | floods, rainfall, landslides, landslide, tsunami, housing construction, mahaweli, construction, hazard, ds
#   Topic  13 |   33 articles | disasters, natural disasters, floods, cyclones, flood, landslide, tsunami, landslides, storms, meteorological
#   Topic  14 |   32 articles | floods, flooding, flood, landslides, aftermath, country, helping, new, humanity, compassion
#
# Top 15 topics cover 723/1261 assigned articles (57.3%)
#     Topic  Count                                               Name
# 0       0     82  0_country_government rebuilding_sanath_secreta...
# 1       1     64      1_ceylon_development ministry_disruptions_gov
# 2       2     63  2_humanitarian assistance_indian naval_indian ...
# 3       3     55                3_rescue_landslide_flood_landslides
# 4       4     54              4_military_secretary_country_ministry
# 5       5     52   5_srilankan_nature_resilience_srilankan airlines
# 6       6     51  6_maldives_relief efforts_singapore_relief sup...
# 7       7     42  7_foreign_infrastructure_rs trillion_internati...
# 8       8     42  8_cyclonic storm_heavy rainfall_heavy rain_cyc...
# 9       9     41             9_disasters_climate_resilience_foreign
# 10     10     39      10_flooding_landslides_infrastructure_colombo
# 11     11     38  11_humanitarian_recovery reconstruction_emerge...
# 12     12     35            12_floods_rainfall_landslides_landslide
# 13     13     33     13_disasters_natural disasters_floods_cyclones
# 14     14     32                14_floods_flooding_flood_landslides

# %% [markdown]
# ## 5. Keywords & Representative Articles per Topic

# %%
topics_arr = np.array(topics)
probs_arr = np.array(probs) if probs is not None else None

topic_details = []

for _, row in top_topics_df.iterrows():
    tid = row['Topic']

    # Get keywords with scores
    words = model.get_topic(tid)
    keywords = [(w, float(s)) for w, s in words[:TOP_WORDS]] if words else []

    # Get articles assigned to this topic
    mask = topics_arr == tid
    indices = np.where(mask)[0]

    # Sort by probability if available, otherwise just take first N
    if probs_arr is not None and probs_arr.ndim == 2 and probs_arr.shape[1] > 0:
        # Multi-topic probabilities - find column for this topic
        topic_ids_sorted = sorted(set(topics) - {-1})
        if tid in topic_ids_sorted:
            col_idx = topic_ids_sorted.index(tid)
            topic_probs = probs_arr[indices, col_idx] if col_idx < probs_arr.shape[1] else np.ones(len(indices))
        else:
            topic_probs = np.ones(len(indices))
        sorted_order = np.argsort(-topic_probs)
    elif probs_arr is not None and probs_arr.ndim == 1:
        topic_probs = probs_arr[indices]
        sorted_order = np.argsort(-topic_probs)
    else:
        sorted_order = np.arange(len(indices))

    top_indices = indices[sorted_order[:TOP_ARTICLES]]

    rep_articles = []
    for idx in top_indices:
        rep_articles.append({
            'article_id': article_ids[idx],
            'title': titles[idx],
            'excerpt': contents[idx][:500],
            'source': SOURCE_NAMES.get(sources[idx], sources[idx]),
        })

    detail = {
        'topic_id': tid,
        'article_count': int(row['Count']),
        'keywords': keywords,
        'representative_articles': rep_articles,
    }
    topic_details.append(detail)

# Display summary
for d in topic_details:
    print(f"\n{'='*80}")
    print(f"Topic {d['topic_id']} ({d['article_count']} articles)")
    print(f"{'='*80}")
    kw_str = ', '.join(f"{w} ({s:.3f})" for w, s in d['keywords'])
    print(f"Keywords: {kw_str}")
    print(f"\nRepresentative articles:")
    for i, art in enumerate(d['representative_articles'], 1):
        print(f"  {i}. [{art['source']}] {art['title'][:80]}")
# Out:
# ================================================================================
# Topic 0 (82 articles)
# ================================================================================
# Keywords: country (0.354), government rebuilding (0.352), sanath (0.343), secretary president (0.342), financial (0.338), chief executive (0.336), secretary (0.336), chief (0.335), finance (0.334), corporate (0.333)
#
# Representative articles:
#   1. [Daily FT] Rs. 20 m donated to Rebuilding Sri Lanka
#   2. [The Island] Bandaranaike Memorial National Foundation donates Rs. 250 million to the Governm
#   3. [Daily News] Naturub Group of Companies donates Rs. 100 Million to ‘Rebuilding Sri Lanka’ Fun
#   4. [Daily News] BNMF donates Rs. 250 Mn for recovery efforts
#   5. [Daily News] Thilakawardena Textiles donates to the ‘Rebuilding Sri Lanka’ Fund
#   6. [Daily FT] Anunine Holdings donates Rs. 25 m to ‘Rebuilding Sri Lanka’ Fund
#   7. [The Island] Lakbima Rice Mills (Pvt) Ltd donates Rs 100 million to the ‘Rebuilding Sri Lanka
#   8. [Daily News] Union Chemicals donates Rs. 1 Mn to ‘Rebuilding Sri Lanka’ Fund
#   9. [Daily FT] Yaden Laboratories donates Rs. 20 m to ’Rebuilding Sri Lanka’ Fund
#   10. [Daily News] Lakbima Rice Mills (Pvt) Ltd donates Rs. 100Mn to ‘Rebuilding Sri Lanka’ Fund
#
# ================================================================================
# Topic 1 (64 articles)
# ================================================================================
# Keywords: ceylon (0.375), development ministry (0.368), disruptions (0.364), gov (0.359), government (0.356), ministry (0.349), sector (0.342), impacted (0.341), export (0.340), national (0.339)
#
# Representative articles:
#   1. [The Morning] Cyclone Ditwah: Industrialists asked for info. on damages
#   2. [Daily News] Ministry of Industries launches data collection for Cyclone Ditwah-affected indu
#   3. [Daily News] President reviews relief and support plans for cyclone affected industries
#   4. [Daily News] Ministry of Industry launches immediate data collection drive to restore ‘Ditwaa
#   5. [The Morning] Data collection initiated to assess Ditwah’s impact
#   6. [Daily News] Government offers Rs. 200,000 to disaster affected industries for rapid recovery
#   7. [Daily News] Comprehensive plan to restore industrial sector affected by cyclone submitted to
#   8. [Daily News] Eighteen thousand businesses affected by Cyclone Ditwah
#   9. [The Morning] Tailored support urged for MSMEs post-Ditwah
#   10. [Daily FT] Cyclone-affected large-scale industries’ struggle under spotlight
#
# ================================================================================
# Topic 2 (63 articles)
# ================================================================================
# Keywords: humanitarian assistance (0.424), indian naval (0.405), indian air force (0.401), naval (0.398), india (0.396), colombo (0.395), relief supplies (0.392), indian army (0.388), search rescue (0.387), operation sagar bandhu (0.387)
#
# Representative articles:
#   1. [Daily FT] India intensifies support to Sri Lanka under Operation Sagar Bandhu
#   2. [Daily News] India’s NDRF joins forces with SL to tackle cyclone devastation
#   3. [The Morning] India Intensifies Support to Sri Lanka under Operation Sagar Bandhu
#   4. [Daily News] India intensifies support to Sri Lanka under ‘Operation Sagar Bandhu’
#   5. [The Island] INS Sukanya brings in relief to East, medical support stepped up
#   6. [The Morning] A Neighbour in Need, A Friend Indeed: India’s Support to Sri Lanka Continues und
#   7. [Daily News] India’s humanitarian assistance continues with Operation Sagar Bandhu
#   8. [The Morning] Over 1,000 Tonnes of Indian Humanitarian Aid Reach Sri Lanka under Operation Sag
#   9. [The Morning] Under Operation Sagar Bandhu, 1000 Tonnes of Relief Material from Tamil Nadu Arr
#   10. [The Morning] Fresh Relief Supplies Delivered to Sri Lanka; India’s Multidimensional Support C
#
# ================================================================================
# Topic 3 (55 articles)
# ================================================================================
# Keywords: rescue (0.416), landslide (0.388), flood (0.384), landslides (0.371), nuwara eliya (0.367), displaced (0.366), colombo (0.361), report (0.347), anuradhapura (0.344), ongoing (0.341)
#
# Representative articles:
#   1. [Daily News] Extreme weather claims 123 lives, 130 still missing – DMC
#   2. [Daily News] 355 deaths and 370 missing persons recorded so far – DMC
#   3. [The Island] Cyclone Ditwah: 355 deaths, 366 missing as at 9 am Monday
#   4. [Daily News] Sri Lanka’s disaster toll reaches 465
#   5. [Daily FT] Ditwah deaths exceed 607, over 2 m affected
#   6. [The Island] Cyclone death toll crosses 410
#   7. [The Island] DMC: 474 dead and 356 missing
#   8. [The Morning] Sri Lanka death toll from Cyclone Ditwah rises to 638
#   9. [The Island] Disaster: 635 bodies found so far, 192 listed as missing
#   10. [The Island] Disaster death toll rises to 638
#
# ================================================================================
# Topic 4 (54 articles)
# ================================================================================
# Keywords: military (0.378), secretary (0.377), country (0.373), ministry (0.372), national (0.372), navy (0.369), defence (0.357), today (0.357), recovery (0.355), president (0.354)
#
# Representative articles:
#   1. [The Morning] Preschools damaged: New national curriculum training next year
#   2. [Daily News] Education: The post-Ditwah scenario
#   3. [The Morning] Post-Disaster Education: PM urges child-centred school reopening
#   4. [Daily News] “Prathishta” program launched to rebuild Schools damaged by Cyclone Ditwah
#   5. [Daily News] Education should not be a burden to cyclone-hit children – PM
#   6. [The Island] Steps are being taken to relocate schools in risk prone Areas to Safe Locations
#   7. [Daily News] Steps underway to relocate schools in high-risk areas, PM says
#   8. [Daily News] 1,382 schools directly affected by Ditwah mostly in Central, Uva and Sabaragamuw
#   9. [Daily News] Schools in risk prone areas will be relocated to safe locations – PM
#   10. [The Morning] Ditwah’s impact on edu. continuity: Case-by-case approach to child victims
#
# ================================================================================
# Topic 5 (52 articles)
# ================================================================================
# Keywords: srilankan (0.488), nature (0.418), resilience (0.402), srilankan airlines (0.398), colombo (0.368), nuwara eliya (0.367), wildlife (0.366), natural (0.351), destination (0.349), risk (0.349)
#
# Representative articles:
#   1. [Daily FT] Cyclone Ditwa: A storm Sri Lanka saw coming but tourism still paid the price
#   2. [The Morning] SLTDA assures: Sri Lanka safe for tourists
#   3. [Daily FT] Tourism weathers Cyclone Ditwah, remains 75% operational
#   4. [Daily FT] Despite Ditwah cyclone, luxury cruise brings 2,000 tourists to Colombo
#   5. [Daily FT] Deputy Minister confirms tourism sector returns to normalcy
#   6. [Daily FT] Need for daily official updates about upcountry access roads for tourists
#   7. [The Morning] Tourism in SL post-Ditwah
#   8. [Daily FT] Over 25,000 tourists arrive amidst and post-Cyclone Ditwah
#   9. [Daily FT] SL draws over 43,000 tourists in first week of December despite Ditwah
#   10. [The Morning] Voyaging amidst turmoil
#
# ================================================================================
# Topic 6 (51 articles)
# ================================================================================
# Keywords: maldives (0.458), relief efforts (0.431), singapore (0.408), relief supplies (0.382), colombo (0.379), humanitarian (0.373), myanmar (0.372), rescue (0.370), foreign affairs (0.369), india (0.368)
#
# Representative articles:
#   1. [Daily FT] China donates $ 1 m in cash; $ 1.4 m in supplies
#   2. [The Morning] China donates emergency aid to support Sri Lanka’s flood relief efforts
#   3. [Daily FT] China donates 85 MT of flood relief supplies
#   4. [The Island] China donates 85 tonnes of relief supplies to Sri Lanka following Cyclone Ditwah
#   5. [Daily News] China donates 85 tonnes of relief supplies to support Sri Lanka’s post-cyclone r
#   6. [Daily FT] China stands with Sri Lanka in the wake of Cyclone Ditwah
#   7. [Daily FT] Sri Lanka Overseas Chinese Association donates to cyclone relief
#   8. [The Morning] China donates over $1 mn and relief supplies to support Sri Lanka’s Cyclone reco
#   9. [The Morning] China donates RMB 1 mn in relief supplies
#   10. [Daily News] Chinese drone experts help identify vulnerable areas after Cyclone Ditva
#
# ================================================================================
# Topic 7 (42 articles)
# ================================================================================
# Keywords: foreign (0.385), infrastructure (0.382), rs trillion (0.369), international (0.366), president (0.364), dissanayake (0.361), sector (0.358), government (0.356), country (0.354), ministry (0.352)
#
# Representative articles:
#   1. [The Morning] Reconstruction and recovery: Govt. must allocate Rs. 500 b: COPF Chair
#   2. [Daily News] Government has managed expenditure, minimised waste and established fiscal disci
#   3. [Daily FT] Govt. in fresh push to expand tax net via voluntary compliance
#   4. [Daily FT] Govt. says Rs. 500 b post-Ditwah spending plan within 2026 borrowing limits
#   5. [Daily FT] Budget deficit down 60% YTD Oct., primary surplus exceeds Rs. 1.6 t
#   6. [The Morning] 2026: Primary expenditure balance limit to exceed 13% of GDP
#   7. [The Morning] Disaster-related spending: Supplementary allocations will suffice: Treasury
#   8. [Daily FT] AKD debunks alarmists with unprecedented fiscal gains
#   9. [Daily FT] Cyclone Ditwah hits 2026 Budget
#   10. [Daily News] Govt has met all revenue targets for 2025 – Minister
#
# ================================================================================
# Topic 8 (42 articles)
# ================================================================================
# Keywords: cyclonic storm (0.553), heavy rainfall (0.505), heavy rain (0.497), cyclonic (0.479), meteorology (0.462), department meteorology (0.438), strong winds (0.436), forecast (0.433), rain (0.431), storm (0.430)
#
# Representative articles:
#   1. [Daily News] Deep depression near Sri Lanka upgraded to cyclone ‘Ditwah’
#   2. [The Morning] Cyclone “Ditwah” near Trincomalee to bring heavy rain and strong winds across Sr
#   3. [Daily News] Cyclone ‘Ditwa’ moves closer to Sri Lanka’s east coast
#   4. [Daily FT] Cyclonic storm “Ditwah” triggers red alert across Sri Lanka
#   5. [The Morning] Met. dept warns of heavy rain and strong winds as Cyclone “Ditwah” nears Sri Lan
#   6. [Daily News] Cyclone “Ditwah” shifts north of Jaffna as rainfall gradually reduces
#   7. [Daily News] Cyclone Ditwah moving towards Tamil Nadu; rainfall to ease in Sri Lanka
#   8. [The Island] India-based Regional Specialised Meteorological Centre issued weather warning on
#   9. [The Island] Ditwah: An unusual cyclone
#   10. [Daily News] Bogawantalawa experiences ground frost following Cyclone Ditwah
#
# ================================================================================
# Topic 9 (41 articles)
# ================================================================================
# Keywords: disasters (0.514), climate (0.413), resilience (0.376), foreign (0.374), infrastructure (0.372), emergency (0.369), construction (0.358), fdi (0.355), domestic (0.354), crisis (0.351)
#
# Representative articles:
#   1. [The Morning] The strength of Sri Lanka’s economy
#   2. [The Island] Trade preferences to support post-Ditwah reconstruction
#   3. [Daily FT] Why Sri Lanka needs a National Budget Performance and Evaluation Office now more
#   4. [The Morning] FDI attraction, CMSMEs development: Financial consequences of the cyclonic rampa
#   5. [Daily News] A reasonable request
#   6. [Daily News] The need for external financing
#   7. [Daily FT] Single National Asset Tax (SNAT): A bold blueprint for disaster recovery, econom
#   8. [The Morning] Rebuilding without derailing reforms
#   9. [Daily FT] Postponing sovereign debt repayment: Are we being pushed back to hell?
#   10. [Daily News] Sri Lanka should build better in 2026
#
# ================================================================================
# Topic 10 (39 articles)
# ================================================================================
# Keywords: flooding (0.427), landslides (0.391), infrastructure (0.380), colombo (0.377), nuwara eliya (0.362), development authority (0.356), ministry (0.346), deputy minister (0.343), national water (0.331), rail (0.325)
#
# Representative articles:
#   1. [The Morning] Over 150 roads reopened after severe flooding
#   2. [The Morning] 1,500 reserved SLTB bus journeys cancelled
#   3. [The Morning] Kandy–Colombo road reopened for traffic
#   4. [Daily News] All access roads to Nuwara Eliya reopened after Cyclone Ditwah
#   5. [Daily News] RDA to open all cyclone hit roads this week
#   6. [The Morning] DMT to launch special mobile service for disaster-damaged vehicles
#   7. [The Morning] Nawalapitiya-Kandy rd. reopened
#   8. [Daily News] Landslide-hit Nawalapitiya Kandy road reopened after 18 days
#   9. [The Morning] Railways Dept.: No threat to Demodara 9 Arch Bridge
#   10. [The Morning] Nawalapitiya–Kandy road reopens to traffic
#
# ================================================================================
# Topic 11 (38 articles)
# ================================================================================
# Keywords: humanitarian (0.419), recovery reconstruction (0.368), emergency (0.350), debt sustainability (0.348), government (0.347), recovery (0.340), urgent (0.337), assistance (0.337), economic (0.335), country (0.334)
#
# Representative articles:
#   1. [The Morning] IMF considers request for $ 200 m
#   2. [Daily News] RFI assistance under consideration – IMF
#   3. [The Morning] SL requests $ 200 m IMF emergency aid
#   4. [The Island] IMF Executive Board approves US$206 Million in Emergency Financial Support for S
#   5. [The Morning] IMF approves $206 mn emergency financing for Sri Lanka
#   6. [The Morning] IMF board to review Sri Lanka’s $200 mn emergency aid request today
#   7. [The Morning] Recovery aid: IMF Executive Board to review SL’s $ 200 m
#   8. [The Morning] IMF board to review Sri Lanka emergency funding request
#   9. [The Morning] IMF team to visit Sri Lanka in early 2026
#   10. [Daily News] EFF 5th review discussions to begin early 2026
#
# ================================================================================
# Topic 12 (35 articles)
# ================================================================================
# Keywords: floods (0.437), rainfall (0.404), landslides (0.404), landslide (0.401), tsunami (0.396), housing construction (0.336), mahaweli (0.331), construction (0.330), hazard (0.319), ds (0.317)
#
# Representative articles:
#   1. [Daily News] Water Resources Board begins cleaning flood damaged Wells
#   2. [Daily News] Restoration of disaster-hit agricultural fields begins across Sri Lanka with GSM
#   3. [The Morning] Green light to restore paddy fields affected by Cyclone Ditwah
#   4. [The Morning] Kandy Court Complex to be restored
#   5. [Daily News] Irrigation Department works to restore water supply for agriculture
#   6. [The Morning] Reservoir water levels return to normal
#   7. [The Morning] Irrigation dept. begins rapid repairs to restore water for farmlands
#   8. [The Morning] Restoration of canals damaged by cyclone Ditwah underway
#   9. [Daily News] Uma Ela anicut damaged by Cyclone nears restoration
#   10. [The Morning] Damaged Irrigation: Temporary repairs underway
#
# ================================================================================
# Topic 13 (33 articles)
# ================================================================================
# Keywords: disasters (0.553), natural disasters (0.526), floods (0.520), cyclones (0.500), flood (0.458), landslide (0.441), tsunami (0.438), landslides (0.437), storms (0.429), meteorological (0.412)
#
# Representative articles:
#   1. [The Island] After Cyclone Ditwah: Climate-proofing Sri Lanka’s health system
#   2. [The Morning] Surviving the day after
#   3. [Daily FT] Preparing for the unpredictable: Why contingency planning must become Sri Lanka’
#   4. [Daily News] Key strategies for effective disaster management
#   5. [Daily FT] Cyclone Ditwah: A harsh reflection of Sri Lanka’s early-warning gap
#   6. [The Morning] Planning for disasters
#   7. [The Morning] Storms are coming – Sri Lanka can’t wait
#   8. [Daily News] Driving on roads after a major natural disaster
#   9. [Daily FT] Beyond relief: Building Sri Lanka’s digital disaster brain
#   10. [Daily News] Facing natural disasters
#
# ================================================================================
# Topic 14 (32 articles)
# ================================================================================
# Keywords: floods (0.458), flooding (0.458), flood (0.448), landslides (0.416), aftermath (0.385), country (0.376), helping (0.375), new (0.374), humanity (0.367), compassion (0.354)
#
# Representative articles:
#   1. [The Morning] Cherishing Christmas
#   2. [Daily News] Let us dispel the darkest era and illuminate the World with the Lamp of Hope
#   3. [Daily FT] Christmas amidst climate catastrophe: Serenity of stillness
#   4. [Daily News] A time for Giving
#   5. [Daily FT] Wise Christmas
#   6. [The Island] A wise Christmas
#   7. [The Morning] With hope and care
#   8. [The Morning] A season for giving, not polluting
#   9. [Daily News] Serving others as we follow Christ
#   10. [The Morning] Christmas for a cause

# %% [markdown]
# ## 6. LLM Aspect Labelling

# %%
llm = get_llm()
print(f"LLM loaded: {llm.model} ({type(llm).__name__})")

SYSTEM_PROMPT = """You are an expert media analyst studying how Sri Lankan English newspapers covered \
Cyclone Ditwah (November 2025 - December 2025). The cyclone caused significant damage in Sri Lanka, \
triggering government response, international aid, and extensive media coverage across multiple outlets.

You are analysing topics discovered by BERTopic from the full corpus of ~1600 articles. \
For each topic, you will receive its top keywords (with importance scores) and representative \
article titles and excerpts.

Your task is to identify what specific aspect of the Ditwah cyclone event this topic captures."""

llm_results = []

for i, d in enumerate(topic_details):
    print(f"\nLabelling topic {d['topic_id']} ({i+1}/{len(topic_details)})...")

    # Build keyword section
    kw_lines = [f"  {w} (score: {s:.4f})" for w, s in d['keywords']]
    kw_section = "\n".join(kw_lines)

    # Build articles section
    art_lines = []
    for j, art in enumerate(d['representative_articles'], 1):
        art_lines.append(f"  Article {j} [{art['source']}]:")
        art_lines.append(f"    Title: {art['title']}")
        art_lines.append(f"    Excerpt: {art['excerpt'][:400]}")
    art_section = "\n".join(art_lines)

    prompt = f"""Below is a topic discovered from Sri Lankan newspaper coverage of Cyclone Ditwah.

TOPIC {d['topic_id']} ({d['article_count']} articles)

Top {TOP_WORDS} keywords (with BERTopic importance scores):
{kw_section}

Top {len(d['representative_articles'])} representative articles:
{art_section}

Based on the keywords and articles above, provide:
1. A short aspect phrase (2-5 words) that captures what this topic is about
2. A 1-2 sentence description explaining what this topic covers in the context of Cyclone Ditwah coverage

Respond with JSON in this exact format:
{{"aspect": "short phrase here", "description": "1-2 sentence description here"}}"""

    try:
        response = llm.generate(prompt, system_prompt=SYSTEM_PROMPT, json_mode=True)
        result = json.loads(response.content)
        aspect = result.get('aspect', 'Unknown')
        description = result.get('description', '')
        print(f"  -> {aspect}")
    except Exception as e:
        print(f"  LLM error: {e}")
        # Fallback: use top keywords as label
        aspect = ', '.join(w for w, _ in d['keywords'][:3])
        description = f"Topic characterised by keywords: {', '.join(w for w, _ in d['keywords'][:8])}"
        print(f"  -> Fallback: {aspect}")

    llm_results.append({
        'topic_id': d['topic_id'],
        'aspect': aspect,
        'description': description,
        'article_count': d['article_count'],
        'keywords': d['keywords'],
    })

print(f"\nAll {len(llm_results)} topics labelled.")
# Out:
# LLM loaded: gpt-4o (OpenAILLM)
#
# Labelling topic 0 (1/15)...
#   -> Corporate Donations for Rebuilding
#
# Labelling topic 1 (2/15)...
#   -> Industrial sector recovery
#
# Labelling topic 2 (3/15)...
#   -> India's Humanitarian Aid
#
# Labelling topic 3 (4/15)...
#   -> Casualties and Displacement
#
# Labelling topic 4 (5/15)...
#   -> Education sector recovery
#
# Labelling topic 5 (6/15)...
#   -> Tourism impact and recovery
#
# Labelling topic 6 (7/15)...
#   -> Chinese aid and support
#
# Labelling topic 7 (8/15)...
#   -> Fiscal response to cyclone
#
# Labelling topic 8 (9/15)...
#   -> Meteorological updates and forecasts
#
# Labelling topic 9 (10/15)...
#   -> Economic recovery and aid
#
# Labelling topic 10 (11/15)...
#   -> Infrastructure and Road Recovery
#
# Labelling topic 11 (12/15)...
#   -> IMF Emergency Aid Request
#
# Labelling topic 12 (13/15)...
#   -> Flood and irrigation restoration
#
# Labelling topic 13 (14/15)...
#   -> Disaster Preparedness Critique
#
# Labelling topic 14 (15/15)...
#   -> Christmas and Cyclone Aftermath
#
# All 15 topics labelled.

# %% [markdown]
# ## 7. Results

# %%
# Build results table
results_rows = []
for r in llm_results:
    top_kw = ', '.join(w for w, _ in r['keywords'][:8])
    results_rows.append({
        'Topic ID': r['topic_id'],
        'Aspect': r['aspect'],
        'Description': r['description'],
        'Articles': r['article_count'],
        'Top Keywords': top_kw,
    })

results_df = pd.DataFrame(results_rows)
with pd.option_context('display.max_colwidth', None):
    display(results_df[['Aspect', 'Description']])
# Out:
#                                   Aspect  \
# 0     Corporate Donations for Rebuilding
# 1             Industrial sector recovery
# 2               India's Humanitarian Aid
# 3            Casualties and Displacement
# 4              Education sector recovery
# 5            Tourism impact and recovery
# 6                Chinese aid and support
# 7             Fiscal response to cyclone
# 8   Meteorological updates and forecasts
# 9              Economic recovery and aid
# 10      Infrastructure and Road Recovery
# 11             IMF Emergency Aid Request
# 12      Flood and irrigation restoration
# 13        Disaster Preparedness Critique
# 14       Christmas and Cyclone Aftermath
#
#                                                                                                                                                                                                                                                                                                                                                                                                    Description
# 0                                      This topic covers the financial contributions made by various corporations and organizations to the 'Rebuilding Sri Lanka' Fund, established by the government to aid in the recovery and rebuilding efforts following the devastation caused by Cyclone Ditwah. It highlights the involvement of key figures and entities in supporting national recovery initiatives.
# 1                                 This topic covers the impact of Cyclone Ditwah on Sri Lanka's industrial sector, focusing on government efforts to collect data on affected industries and provide financial support for recovery. It highlights the Ministry of Industry's initiatives to assess damage and facilitate the restoration of businesses, including micro, small, and medium-sized enterprises.
# 2                                                         This topic covers India's extensive humanitarian assistance to Sri Lanka in the aftermath of Cyclone Ditwah, primarily through 'Operation Sagar Bandhu'. It highlights the deployment of Indian naval and air force resources to deliver relief supplies, conduct search and rescue operations, and provide medical support to the affected regions.
# 3                                                This topic covers the human toll of Cyclone Ditwah, focusing on the number of deaths, missing persons, and the widespread displacement caused by the cyclone. It highlights the reports from the Disaster Management Centre on the impact of floods and landslides across various districts, particularly emphasizing the severe effects in areas like Kandy.
# 4                                              This topic covers the impact of Cyclone Ditwah on the education sector in Sri Lanka, highlighting the damage to schools and the government's efforts to rebuild and relocate affected educational institutions. It also discusses the prioritization of children's psychosocial well-being and the involvement of various stakeholders in the recovery process.
# 5                                                                 This topic covers the impact of Cyclone Ditwah on Sri Lanka's tourism industry, highlighting the resilience and recovery efforts to assure safety and normalcy for tourists. It discusses the challenges faced by the sector, the response from tourism authorities, and the continued influx of tourists despite the cyclone's devastation.
# 6                                                                                                  This topic covers the extensive humanitarian aid and relief efforts provided by China to Sri Lanka in the aftermath of Cyclone Ditwah. It highlights financial donations, relief supplies, and technical assistance, such as drone expertise, to support recovery and rebuilding efforts in affected areas.
# 7                                                                       This topic covers the Sri Lankan government's financial strategies and budgetary adjustments in response to Cyclone Ditwah. It highlights the allocation of funds for recovery and reconstruction, the impact on fiscal targets, and the government's efforts to maintain economic stability while addressing the cyclone's aftermath.
# 8   This topic covers the meteorological updates and forecasts related to Cyclone Ditwah, including its development, movement, and the expected weather conditions such as heavy rainfall and strong winds across Sri Lanka. It highlights the role of the Department of Meteorology and other meteorological centers in issuing warnings and alerts as the cyclone approached and moved away from the island.
# 9                                                                                    This topic covers the economic impact of Cyclone Ditwah on Sri Lanka, focusing on the country's resilience and recovery efforts. It highlights the role of international aid, foreign direct investment, and government measures in rebuilding infrastructure and managing the financial crisis triggered by the cyclone.
# 10                                             This topic covers the impact of Cyclone Ditwah on Sri Lanka's infrastructure, particularly focusing on road closures and reopenings due to flooding and landslides. It highlights the efforts by authorities like the Road Development Authority to restore transportation routes and ensure safety in affected areas such as Colombo, Nuwara Eliya, and Kandy.
# 11                                                                                          This topic covers Sri Lanka's request for emergency financial assistance from the International Monetary Fund (IMF) following the devastation caused by Cyclone Ditwah. It highlights the approval and disbursement of funds under the Rapid Financing Instrument to address urgent economic and fiscal pressures.
# 12                                                               This topic covers the restoration efforts for flood-damaged infrastructure, particularly focusing on irrigation systems and agricultural fields affected by Cyclone Ditwah. It highlights the actions taken by various government bodies to repair canals, reservoirs, and paddy fields to ensure water supply and agricultural productivity.
# 13                                                                                This topic covers the criticism and analysis of Sri Lanka's preparedness and response to natural disasters, particularly in the wake of Cyclone Ditwah. It highlights the need for improved early-warning systems, contingency planning, and effective disaster management strategies to mitigate the impact of such events.
# 14                                      This topic explores the intersection of the Christmas season with the aftermath of Cyclone Ditwah in Sri Lanka. It highlights how the festive period is marked by reflection, compassion, and community support in the face of the devastation caused by the cyclone, drawing parallels to past natural disasters and emphasizing the spirit of giving and resilience.

# %% [markdown]
# ## 8. Selection Bias Analysis
#
# For each of the 15 LLM-labelled topics, compute how much of each outlet's coverage is devoted to that topic. High variance across outlets signals **selection bias** — some outlets emphasise certain aspects of the cyclone while others downplay or ignore them.

# %%
import plotly.express as px

# Build aspect lookup from LLM results
aspect_lookup = {r['topic_id']: r['aspect'] for r in llm_results}
top_topic_ids = [r['topic_id'] for r in llm_results]

# Count total articles per outlet (full corpus, not just assigned)
outlet_totals = {}
for src_id, src_name in SOURCE_NAMES.items():
    outlet_totals[src_name] = sum(1 for s in sources if s == src_id)

# For each topic x outlet: count articles and compute proportion
rows = []
for tid in top_topic_ids:
    mask = topics_arr == tid
    topic_sources = [sources[i] for i in range(len(sources)) if mask[i]]

    outlet_counts = {}
    outlet_props = {}
    for src_id, src_name in SOURCE_NAMES.items():
        count = sum(1 for s in topic_sources if s == src_id)
        prop = count / outlet_totals[src_name] if outlet_totals[src_name] > 0 else 0.0
        outlet_counts[src_name] = count
        outlet_props[src_name] = prop

    props = list(outlet_props.values())
    variance = np.var(props)
    spread = max(props) - min(props)
    max_outlet = max(outlet_props, key=outlet_props.get)
    min_outlet = min(outlet_props, key=outlet_props.get)

    row = {
        'Topic ID': tid,
        'Aspect': aspect_lookup[tid],
        **{f'{name} (count)': outlet_counts[name] for name in outlet_totals},
        **{f'{name} (%)': outlet_props[name] * 100 for name in outlet_totals},
        'Variance': variance,
        'Spread': spread,
        'Max Coverage': max_outlet,
        'Min Coverage': min_outlet,
    }
    rows.append(row)

bias_df = pd.DataFrame(rows).sort_values('Variance', ascending=False).reset_index(drop=True)

# Display summary table
outlet_names = list(outlet_totals.keys())
display_cols = ['Aspect'] + [f'{n} (%)' for n in outlet_names] + ['Spread', 'Max Coverage', 'Min Coverage']
styled = bias_df[display_cols].copy()
for n in outlet_names:
    styled[f'{n} (%)'] = styled[f'{n} (%)'].map('{:.1f}%'.format)
styled['Spread'] = (bias_df['Spread'] * 100).map('{:.1f}pp'.format)

print("Per-outlet topic proportions (% of each outlet's articles), sorted by selection bias strength:\n")
with pd.option_context('display.max_colwidth', 40):
    display(styled)
# Out:
# Per-outlet topic proportions (% of each outlet's articles), sorted by selection bias strength:
#                                   Aspect Daily News (%) The Morning (%)  \
# 0     Corporate Donations for Rebuilding           6.8%            1.6%
# 1       Flood and irrigation restoration           1.8%            4.7%
# 2              Education sector recovery           4.4%            4.9%
# 3             Fiscal response to cyclone           2.6%            1.2%
# 4   Meteorological updates and forecasts           3.2%            2.0%
# 5       Infrastructure and Road Recovery           2.0%            4.5%
# 6            Casualties and Displacement           3.4%            3.7%
# 7            Tourism impact and recovery           2.6%            2.0%
# 8        Christmas and Cyclone Aftermath           1.4%            3.9%
# 9              Economic recovery and aid           1.6%            3.5%
# 10            Industrial sector recovery           5.2%            2.9%
# 11             IMF Emergency Aid Request           1.8%            2.2%
# 12        Disaster Preparedness Critique           1.4%            1.8%
# 13              India's Humanitarian Aid           4.4%            4.1%
# 14               Chinese aid and support           3.0%            2.6%
#
#    Daily FT (%) The Island (%) Spread Max Coverage Min Coverage
# 0          7.6%           3.9%  6.0pp     Daily FT  The Morning
# 1          0.5%           0.4%  4.3pp  The Morning   The Island
# 2          0.8%           1.8%  4.1pp  The Morning     Daily FT
# 3          5.3%           1.1%  4.2pp     Daily FT   The Island
# 4          0.5%           4.9%  4.4pp   The Island     Daily FT
# 5          0.3%           2.1%  4.2pp  The Morning     Daily FT
# 6          1.3%           5.3%  4.0pp   The Island     Daily FT
# 7          5.5%           2.8%  3.5pp     Daily FT  The Morning
# 8          0.5%           1.4%  3.3pp  The Morning     Daily FT
# 9          3.4%           1.1%  2.4pp  The Morning   The Island
# 10         3.9%           3.2%  2.3pp   Daily News  The Morning
# 11         3.4%           1.8%  1.7pp     Daily FT   The Island
# 12         3.2%           1.8%  1.8pp     Daily FT   Daily News
# 13         2.9%           3.5%  1.5pp   Daily News     Daily FT
# 14         3.4%           3.5%  0.9pp   The Island  The Morning

# %%
# Proportion heatmap: topics (sorted by variance) x outlets
heatmap_data = bias_df[['Aspect'] + [f'{n} (%)' for n in outlet_names]].copy()
heatmap_data = heatmap_data.set_index('Aspect')
heatmap_data.columns = outlet_names

fig = px.imshow(
    heatmap_data.values,
    x=outlet_names,
    y=heatmap_data.index.tolist(),
    text_auto='.1f',
    color_continuous_scale='YlOrRd',
    labels={'x': 'Outlet', 'y': 'Topic', 'color': '% of outlet articles'},
    aspect='auto',
)
fig.update_layout(
    title='Coverage Proportion by Outlet (% of each outlet\'s articles)',
    height=600,
    width=800,
    yaxis=dict(dtick=1),
)
fig.show()

# %%
# Grouped bar chart: article counts per topic per outlet
bar_rows = []
for _, row in bias_df.iterrows():
    for name in outlet_names:
        bar_rows.append({
            'Aspect': row['Aspect'],
            'Outlet': name,
            'Articles': row[f'{name} (count)'],
        })

bar_df = pd.DataFrame(bar_rows)

fig = px.bar(
    bar_df,
    x='Aspect',
    y='Articles',
    color='Outlet',
    barmode='group',
    color_discrete_map=SOURCE_COLORS,
    title='Article Counts per Topic by Outlet',
)
fig.update_layout(
    xaxis_tickangle=-45,
    height=500,
    width=1000,
    xaxis_title='',
    legend_title='Outlet',
)
fig.show()

# %%
# Spread chart: max - min proportion per topic (selection bias signal strength)
spread_df = bias_df[['Aspect', 'Spread']].copy()
spread_df['Spread (pp)'] = spread_df['Spread'] * 100

fig = px.bar(
    spread_df,
    x='Aspect',
    y='Spread (pp)',
    color='Spread (pp)',
    color_continuous_scale='Reds',
    title='Selection Bias Signal: Coverage Spread (max - min outlet proportion)',
    labels={'Spread (pp)': 'Spread (percentage points)'},
    text_auto='.1f',
)
fig.update_layout(
    xaxis_tickangle=-45,
    height=500,
    width=1000,
    xaxis_title='',
    yaxis_title='Spread (percentage points)',
    showlegend=False,
)
fig.show()

# %%
# Selection bias summary
print("SELECTION BIAS RANKING")
print("=" * 80)
print(f"Topics ranked by coverage spread (max - min outlet proportion):\n")

for rank, (_, row) in enumerate(bias_df.iterrows(), 1):
    spread_pp = row['Spread'] * 100
    aspect = row['Aspect']
    max_out = row['Max Coverage']
    min_out = row['Min Coverage']

    per_outlet = ' | '.join(
        f"{n}: {row[f'{n} (%)']:.1f}%" for n in outlet_names
    )

    print(f"{rank:2d}. {aspect}")
    print(f"    Spread: {spread_pp:.1f}pp  |  Most: {max_out}  |  Least: {min_out}")
    print(f"    {per_outlet}")
    print()
# Out:
# SELECTION BIAS RANKING
# ================================================================================
# Topics ranked by coverage spread (max - min outlet proportion):
#
#  1. Corporate Donations for Rebuilding
#     Spread: 6.0pp  |  Most: Daily FT  |  Least: The Morning
#     Daily News: 6.8% | The Morning: 1.6% | Daily FT: 7.6% | The Island: 3.9%
#
#  2. Flood and irrigation restoration
#     Spread: 4.3pp  |  Most: The Morning  |  Least: The Island
#     Daily News: 1.8% | The Morning: 4.7% | Daily FT: 0.5% | The Island: 0.4%
#
#  3. Education sector recovery
#     Spread: 4.1pp  |  Most: The Morning  |  Least: Daily FT
#     Daily News: 4.4% | The Morning: 4.9% | Daily FT: 0.8% | The Island: 1.8%
#
#  4. Fiscal response to cyclone
#     Spread: 4.2pp  |  Most: Daily FT  |  Least: The Island
#     Daily News: 2.6% | The Morning: 1.2% | Daily FT: 5.3% | The Island: 1.1%
#
#  5. Meteorological updates and forecasts
#     Spread: 4.4pp  |  Most: The Island  |  Least: Daily FT
#     Daily News: 3.2% | The Morning: 2.0% | Daily FT: 0.5% | The Island: 4.9%
#
#  6. Infrastructure and Road Recovery
#     Spread: 4.2pp  |  Most: The Morning  |  Least: Daily FT
#     Daily News: 2.0% | The Morning: 4.5% | Daily FT: 0.3% | The Island: 2.1%
#
#  7. Casualties and Displacement
#     Spread: 4.0pp  |  Most: The Island  |  Least: Daily FT
#     Daily News: 3.4% | The Morning: 3.7% | Daily FT: 1.3% | The Island: 5.3%
#
#  8. Tourism impact and recovery
#     Spread: 3.5pp  |  Most: Daily FT  |  Least: The Morning
#     Daily News: 2.6% | The Morning: 2.0% | Daily FT: 5.5% | The Island: 2.8%
#
#  9. Christmas and Cyclone Aftermath
#     Spread: 3.3pp  |  Most: The Morning  |  Least: Daily FT
#     Daily News: 1.4% | The Morning: 3.9% | Daily FT: 0.5% | The Island: 1.4%
#
# 10. Economic recovery and aid
#     Spread: 2.4pp  |  Most: The Morning  |  Least: The Island
#     Daily News: 1.6% | The Morning: 3.5% | Daily FT: 3.4% | The Island: 1.1%
#
# 11. Industrial sector recovery
#     Spread: 2.3pp  |  Most: Daily News  |  Least: The Morning
#     Daily News: 5.2% | The Morning: 2.9% | Daily FT: 3.9% | The Island: 3.2%
#
# 12. IMF Emergency Aid Request
#     Spread: 1.7pp  |  Most: Daily FT  |  Least: The Island
#     Daily News: 1.8% | The Morning: 2.2% | Daily FT: 3.4% | The Island: 1.8%
#
# 13. Disaster Preparedness Critique
#     Spread: 1.8pp  |  Most: Daily FT  |  Least: Daily News
#     Daily News: 1.4% | The Morning: 1.8% | Daily FT: 3.2% | The Island: 1.8%
#
# 14. India's Humanitarian Aid
#     Spread: 1.5pp  |  Most: Daily News  |  Least: Daily FT
#     Daily News: 4.4% | The Morning: 4.1% | Daily FT: 2.9% | The Island: 3.5%
#
# 15. Chinese aid and support
#     Spread: 0.9pp  |  Most: The Island  |  Least: The Morning
#     Daily News: 3.0% | The Morning: 2.6% | Daily FT: 3.4% | The Island: 3.5%
