# %% [markdown]
# # Per-Outlet Topic Modeling & Cross-Outlet Comparison
#
# This notebook runs BERTopic **independently per newspaper outlet**, then cross-identifies matching topics
# and compares how outlets frame the same topics differently.
#
# ## Approach
# 1. Load pre-computed embeddings (same `google/embeddinggemma-300m` space across all outlets)
# 2. Fit separate BERTopic models per outlet with adjusted parameters for smaller corpora
# 3. Match topics across outlets using a 3-method ensemble (centroid similarity, keyword overlap, c-TF-IDF)
# 4. Use the Hungarian algorithm for optimal 1-to-1 matching per outlet pair
# 5. Group matched topics transitively via Union-Find
# 6. Visualize coverage differences, keyword divergence, and selection bias signals

# %% [markdown]
# ## 1. Setup & Data Loading

# %%
import sys
import json
import warnings
import numpy as np
import pandas as pd
from collections import defaultdict
from itertools import combinations

from scipy.optimize import linear_sum_assignment
from scipy.spatial.distance import cosine

import plotly.graph_objects as go
import plotly.express as px

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS
from sentence_transformers import SentenceTransformer

warnings.filterwarnings('ignore')
sys.path.append('..')

from src.db import get_db
from src.llm import get_llm
from dashboard.components.source_mapping import SOURCE_NAMES, SOURCE_COLORS

print("All imports successful")
# Out:
# All imports successful

# %%
# Configuration
OUTLETS = ["dailynews_en", "themorning_en", "ft_en", "island_en"]
RANDOM_SEED = 42
EMBEDDING_MODEL = "google/embeddinggemma-300m"

# BERTopic parameters adjusted for smaller per-outlet corpora (~500 articles each)
MIN_TOPIC_SIZE = 5
MIN_DF = 2
UMAP_N_NEIGHBORS = 10

# Cross-outlet matching parameters
WEIGHT_CENTROID = 1.0
WEIGHT_CTFIDF = 0
WEIGHT_KEYWORD = 0
MATCH_THRESHOLD = 0.75
KEYWORD_TOP_N = 30

# LLM aspect labelling
N_TOPICS = 15       # top topics per outlet to label
TOP_ARTICLES = 10   # representative articles per topic for LLM prompt

# %%
# Verify embeddings exist for the configured model
with get_db() as db:
    emb_count = db.get_embedding_count(embedding_model=EMBEDDING_MODEL)

if emb_count == 0:
    raise RuntimeError(
        f"No embeddings found for model '{EMBEDDING_MODEL}'. "
        f"Generate them first:\n"
        f"  python3 scripts/embeddings/01_generate_embeddings.py --model {EMBEDDING_MODEL}"
    )

print(f"Found {emb_count} embeddings for model '{EMBEDDING_MODEL}'")
# Out:
# Found 1657 embeddings for model 'google/embeddinggemma-300m'

# %%
# Load all embeddings by model name and split by outlet
print("Loading embeddings from database...")
with get_db() as db:
    all_data = db.get_all_embeddings(embedding_model=EMBEDDING_MODEL)

print(f"Total articles loaded: {len(all_data)}")

outlet_data = {}
for outlet in OUTLETS:
    records = [d for d in all_data if d['source_id'] == outlet]
    outlet_data[outlet] = {
        'documents': [f"{d['title']}\n\n{d['content']}" for d in records],
        'contents': [d['content'] for d in records],
        'embeddings': np.array([d['embedding'] for d in records]),
        'article_ids': [d['article_id'] for d in records],
        'titles': [d['title'] for d in records],
    }
    print(f"  {SOURCE_NAMES[outlet]}: {len(records)} articles")

del all_data
# Out:
# Loading embeddings from database...
# Total articles loaded: 1657
#   Daily News: 502 articles
#   The Morning: 491 articles
#   Daily FT: 380 articles
#   The Island: 284 articles

# %% [markdown]
# ## 2. Per-Outlet BERTopic Modeling

# %%
# Load embedding model once, share across all fits
print(f"Loading SentenceTransformer model ({EMBEDDING_MODEL})...")
embedding_model = SentenceTransformer(EMBEDDING_MODEL)

custom_stop_words = sorted(set(ENGLISH_STOP_WORDS) | {"sri", "lanka", "lankan", "lankans"})

outlet_results = {}

for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    data = outlet_data[outlet]
    n_docs = len(data['documents'])
    print(f"\n{'='*60}")
    print(f"Fitting BERTopic for {name} ({n_docs} articles)")
    print(f"{'='*60}")

    umap_model = UMAP(
        n_neighbors=UMAP_N_NEIGHBORS,
        n_components=5,
        min_dist=0.0,
        metric='cosine',
        random_state=RANDOM_SEED,
    )

    hdbscan_model = HDBSCAN(
        min_cluster_size=MIN_TOPIC_SIZE,
        metric='euclidean',
        cluster_selection_method='eom',
        prediction_data=True,
        core_dist_n_jobs=1,
    )

    vectorizer = CountVectorizer(
        ngram_range=(1, 3),
        stop_words=custom_stop_words,
        min_df=MIN_DF,
    )

    model = BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer,
        # representation_model=KeyBERTInspired(),
        top_n_words=30,
        verbose=False,
    )

    topics, probs = model.fit_transform(data['documents'], data['embeddings'])
    topic_info = model.get_topic_info()

    n_topics = len(topic_info[topic_info['Topic'] != -1])
    n_outliers = sum(1 for t in topics if t == -1)
    print(f"  Topics: {n_topics}, Outliers: {n_outliers}/{n_docs}")

    outlet_results[outlet] = {
        'model': model,
        'topics': topics,
        'probs': probs,
        'topic_info': topic_info,
        'documents': data['documents'],
        'embeddings': data['embeddings'],
        'article_ids': data['article_ids'],
    }

print("\nAll models fitted successfully.")
# Out:
# Loading SentenceTransformer model (google/embeddinggemma-300m)...
#
# ============================================================
# Fitting BERTopic for Daily News (502 articles)
# ============================================================
#   Topics: 28, Outliers: 52/502
#
# ============================================================
# Fitting BERTopic for The Morning (491 articles)
# ============================================================
#   Topics: 24, Outliers: 75/491
#
# ============================================================
# Fitting BERTopic for Daily FT (380 articles)
# ============================================================
#   Topics: 16, Outliers: 43/380
#
# ============================================================
# Fitting BERTopic for The Island (284 articles)
# ============================================================
#   Topics: 17, Outliers: 66/284
#
# All models fitted successfully.

# %%
# Summary table
summary_rows = []
for outlet in OUTLETS:
    r = outlet_results[outlet]
    ti = r['topic_info']
    n_topics = len(ti[ti['Topic'] != -1])
    n_outliers = sum(1 for t in r['topics'] if t == -1)
    summary_rows.append({
        'Outlet': SOURCE_NAMES[outlet],
        'Articles': len(r['documents']),
        'Topics': n_topics,
        'Outliers': n_outliers,
        'Outlier %': f"{100*n_outliers/len(r['documents']):.1f}%",
    })

summary_df = pd.DataFrame(summary_rows)
print("Per-Outlet Topic Modeling Summary")
display(summary_df)
# Out:
# Per-Outlet Topic Modeling Summary
#         Outlet  Articles  Topics  Outliers Outlier %
# 0   Daily News       502      28        52     10.4%
# 1  The Morning       491      24        75     15.3%
# 2     Daily FT       380      16        43     11.3%
# 3   The Island       284      17        66     23.2%

# %% [markdown]
# ## 3. Per-Outlet Topic Overview

# %%
# List all topics per outlet with top 30 keywords/ngrams
TOP_N_WORDS = 30

for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    r = outlet_results[outlet]
    ti = r['topic_info']
    ti_topics = ti[ti['Topic'] != -1].sort_values('Count', ascending=False)

    print(f"\n{'='*100}")
    print(f"  {name} — {len(ti_topics)} topics, {len(r['documents'])} articles")
    print(f"{'='*100}")

    for _, row in ti_topics.iterrows():
        tid = row['Topic']
        count = row['Count']
        words = r['model'].get_topic(tid)
        if words:
            keyword_str = ', '.join(w for w, _ in words[:TOP_N_WORDS])
        else:
            keyword_str = '(no keywords)'
        print(f"\n  Topic {tid} ({count} articles)")
        print(f"    {keyword_str}")
# Out:
# ====================================================================================================
#   Daily News — 28 topics, 502 articles
# ====================================================================================================
#
#   Topic 0 (58 articles)
#     disaster, climate, people, disasters, time, government, ditwah, natural, country, need, public, lives, relief, media, systems, global, world, cyclone, countries, rescue, affected, economic, like, tsunami, change, floods, response, early, national, infrastructure
#
#   Topic 1 (35 articles)
#     fund, rebuilding fund, rebuilding, rs, million, group, plc, donates, kumanayake, nandika, nandika sanath, dr nandika sanath, nandika sanath kumanayake, dr nandika, sanath kumanayake, fund established, presidential secretariat, sanath, dr, rebuilding fund established, cheque, presidential, donates rs, government rebuilding, government rebuilding fund, established, handed, president, contribution, secretariat
#
#   Topic 2 (33 articles)
#     said, minister, government, parliament, rs, disaster, country, opposition, billion, president, cabinet, 000, taken, people, budget, management, committee, affected, development, yesterday, debate, economic, time, situation, ministry, ministers, steps, finance, cabinet ministers, foreign
#
#   Topic 3 (27 articles)
#     district, deaths, kandy, affected, missing, families, individuals, damage, disaster, cyclone, houses, dmc, children, estimated, districts, reported, kandy district, people, ditwah, persons, number, highest number, cyclone ditwah, said, highest, caused, areas, badulla, department, died
#
#   Topic 4 (26 articles)
#     industry, development, industries, ministry, businesses, affected, entrepreneurship, entrepreneurship development, bank, banks, small, industrialists, entrepreneurs, industrial, industry entrepreneurship development, industry entrepreneurship, enterprises, scale, boi, data, ministry industry, business, medium, cyclone, loan, sector, financial, export, central bank, provide
#
#   Topic 5 (25 articles)
#     indian, india, force, sagar bandhu, sagar, bandhu, operation sagar, operation sagar bandhu, operation, relief, air, army, air force, assistance, aircraft, medical, support, bridge, operations, indian army, indian air force, indian air, cyclone, humanitarian, personnel, team, cyclone ditwah, rescue, ndrf, ditwah
#
#   Topic 6 (17 articles)
#     farmers, hectares, paddy, fields, damaged, paddy fields, fisheries, irrigation, rs, agriculture, sand, destroyed, livestock, 000, soil, losses, cultivation, maize, cyclone, mahaweli, agricultural, cultivated, authority, water, crops, minister, mahaweli authority, department, sector, rs 150 000
#
#   Topic 7 (17 articles)
#     schools, education, school, students, district, prime minister, prime, minister, colombo district, december, education ministry, ministry, 16, reopen, colombo, january, steps, dr harini, teachers, stated, harini, cyclone, minister dr harini, affected, term, amarasuriya, held, minister dr, december 16, authorities
#
#   Topic 8 (17 articles)
#     road, nuwara, eliya, nuwara eliya, roads, damaged, nuwara eliya district, eliya district, officials, president, rda, district, repair, train, railway, road development, bridges, road development authority, development authority, development, cyclone, highways, cyclone ditwah, dissanayake, authority, services, damaged roads, transport highways, train services, ditwah
#
#   Topic 9 (16 articles)
#     showers, north, provinces, western, occur, central, strong winds, expected, winds, mm, likely, thundershowers, northern, heavy, western provinces, northern north central, areas, northern north, north central, places, sabaragamuwa, strong, thundershowers occur, department, rainfall, meteorology, mm likely, times, trincomalee, 50
#
#   Topic 10 (16 articles)
#     tourism, airlines, destination, travel, srilankan, embassy, tourists, srilankan airlines, tourist, arrivals, 2025, airline, visitors, world, travellers, international, colombo, industry, year, christmas, employment, cultural, stakeholders, welcoming, air, milestone, record, ambassador, ride, hospitality
#
#   Topic 11 (15 articles)
#     imf, bank, development, digital, support, world bank, project, economic, eff, services, loan, partners, adb, emergency, million, development partners, world, country, fund, recovery, growth, expected, cyclone, financing, review, sector, facility, term, discussions, government
#
#   Topic 12 (13 articles)
#     opposition, opposition leader, leader, sjb, premadasa, said, sajith, mps, government, disaster, leader sajith, opposition leader sajith, leader sajith premadasa, sajith premadasa, country, relief, cyclone, opposition mps, committee, people, jana balawegaya, balawegaya, samagi jana balawegaya, opposition leader said, low pressure, leader said, pressure, jana, samagi, samagi jana
#
#   Topic 13 (12 articles)
#     sumatra, indonesia, floods, said, people, say, landslides, agency, death toll, thailand, toll, death, tropical, dead, rain, senyar, north, floods landslides, flooding, malaysia, aid, west, missing, killed, worst, told, swept, rare, asia, monsoon
#
#   Topic 14 (12 articles)
#     european, union, unesco, european union, assistance, support, eu, myanmar, justice, humanitarian, cyclone, disaster, aid, herath, foreign, recovery, director, million, emergency, ambassador, employment, efforts, euro, following, cyclone ditwah, 000, minister, international, plan, civil
#
#   Topic 15 (12 articles)
#     pakistan, relief, ndma, high, minister, prime minister, pakistani, prime, islamabad, high commissioner, commissioner, government pakistan, humanitarian, relief items, high commission, disaster management authority, management authority, healthcare, national disaster management, commission, management authority ndma, authority ndma, rear, rear admiral, admiral, directives, rtd, support, items, consignment
#
#   Topic 16 (11 articles)
#     japan, jica, team, medical, isomata, assistance, emergency, medical team, japanese, ambassador, relief, items, cyclone, shelter, akio, unicef, grant, affected, personnel, food, water, response, akio isomata, provide, representative, international, general, wfp, assist, people
#
#   Topic 17 (10 articles)
#     electricity, mobitel, slt mobitel, slt, power, telecommunication, network, restored, connectivity, solar, fibre, operators, networks, areas, users, restoration, ceb, free, access, service, customers, mahiyanganaya, country, transmission, electricity board, connected, restore, connections, supply, telecom
#
#   Topic 18 (9 articles)
#     insurance, families, group, service, initiative, affected, relief, commitment, customers, company, managing director, police, plc, chamber, managing, ape, warakapola, communities, branch, management, ditwah, cyclone, supporting communities, supporting, customer, corporate, cyclone ditwah, finance plc, ensuring, bank
#
#   Topic 19 (9 articles)
#     jaishankar, indian, minister, india, prime minister, prime, visit, dr jaishankar, affairs, dr, external affairs, external, external affairs minister, secretary, affairs minister, affairs minister dr, indian prime minister, indian prime, minister dr, modi, narendra, narendra modi, cooperation, bilateral, special, envoy, president, french, official visit, special envoy
#
#   Topic 20 (9 articles)
#     navy, clean, programme, children, mental, sln, school, initiative, centres, keells, relief centres, badulla, pre, launched, recovery, support, project, secretariat, mental health, training, schools, affected, health, launch, personnel, badulla district, maha, government officials, district, development
#
#   Topic 21 (8 articles)
#     religious, thera, ven, religious cultural, cultural, cultural affairs, religious cultural affairs, sites, kalutara, affairs, chapter, buddhasasana religious, buddhasasana, leaders, held, mahanayake, buddhasasana religious cultural, blessings, sangha, religious places, religious sites, fund, programmes, maha, muslim, venerable, minister, gangaramaya, temples, lost
#
#   Topic 22 (8 articles)
#     australia, australian, million, support, wfp, partners, australia stands, aid, response, humanitarian, communities, assistant minister, urgent, high, aus, million support, region, affected, assistant, education, needs, cyclone, urgent needs, stands, zealand, new zealand, devastating, hill, support recovery, matthew duckworth
#
#   Topic 23 (8 articles)
#     condolences, russia, president, message, russian, saudi, friendly, egypt, humanitarian, humanitarian aid, king, cyclone, anura, injured, envoy, speedy, anura kumara dissanayake, caused, kumara dissanayake, president anura kumara, anura kumara, president anura, 35, kumara, states, wishes, expressed condolences, victims, aid, natural
#
#   Topic 24 (7 articles)
#     india, jaishankar, indian, minister, package, external affairs, modi, external affairs minister, assistance, 450, affairs minister, 450 million, external, high commissioner, commissioner, affairs, high, dr jaishankar, indian external, indian external affairs, visit, support, said, president, reconstruction, jha, million, minister narendra, minister narendra modi, prime minister narendra
#
#   Topic 25 (7 articles)
#     suriyapperuma, businesses, rs, overseas, dr suriyapperuma, rebuilding, dr, secretary, insurance, finance, finance secretary, property, million, fund, stated, harshana suriyapperuma, dr harshana suriyapperuma, received, funds, dr harshana, harshana, contributions, support, damaged businesses, institutions, rebuilding fund, compensation, businesses property, bank, insurance companies
#
#   Topic 26 (7 articles)
#     chinese, china, chinese government, ambassador, minister, national, lifesaving, affairs, foreign, government, wang, intermediate, chinese ambassador, qi, people, foreign affairs, jvp, college, support, electric, women, committee, zhenhong, qi zhenhong, congress, charging, national people, men, diplomatic, chairman
#
#   Topic 27 (6 articles)
#     rescue relief, clearing, gamage, tri forces, rescue, cleaning, tri, volunteers, ranjith, rescue relief efforts, pictures, forces, town, hatton, relief, picture, cyclone, badulla, ditwah, nuwara eliya, nuwara, eliya, matara, cyclone ditwah, engaged, operations, following cyclone ditwah, following cyclone, relief efforts, personnel
#
# ====================================================================================================
#   The Morning — 24 topics, 491 articles
# ====================================================================================================
#
#   Topic 0 (93 articles)
#     relief, india, support, indian, assistance, humanitarian, cyclone, aid, japan, ditwah, efforts, cyclone ditwah, supplies, affected, minister, air, including, rescue, force, million, operation, tonnes, response, operation sagar, operation sagar bandhu, sagar bandhu, bandhu, sagar, government, air force
#
#   Topic 1 (31 articles)
#     district, affected, districts, families, missing, fibre, disaster, areas, kandy, communication, restored, badulla, power, reported, puttalam, restoration, kurunegala, services, eliya, damaged, weather, ditwah, road, 000, people, dmc, damage, operations, cyclone, individuals
#
#   Topic 2 (23 articles)
#     climate, disaster, resilience, data, risk, preparedness, ai, people, need, systems, women, level, families, management, planning, community, disasters, early, water, change, flood, floods, ditwah, household, communities, animals, warning, national, disaster management, said
#
#   Topic 3 (22 articles)
#     schools, education, students, school, children, ministry, examination, affected, teachers, reopen, said, 16, december, learning, cyclone, 16 december, ditwah, january, unicef, resume, authorities, education ministry, ministry education, level, reopening, support, cyclone ditwah, higher education, examinations, minister
#
#   Topic 4 (22 articles)
#     imf, recovery, bank, million, adb, emergency, support, financing, review, partners, rapid, request, board, fiscal, finance, rfi, fund, facility, executive board, eff, cyclone, world bank, instrument, said, disaster, international, billion, financial, cyclone ditwah, executive
#
#   Topic 5 (21 articles)
#     fund, account, rebuilding, million, rebuilding fund, rs, bank, support, secretary, united, drivers, plc, finance, suriyapperuma, company, received, recovery, contributions, communities, financial, cyclone, cyclone ditwah, dr, leasing, affected, donations, ditwah, relief, harshana suriyapperuma, harshana
#
#   Topic 6 (19 articles)
#     road, roads, rda, damaged, vehicles, traffic, reopened, train, repairs, dmt, cyclone ditwah, cyclone, ditwah, bridges, services, repair, repaired, sltb, road development, road development authority, caused, authority, development authority, roadways, nawalapitiya, procurement, said, train services, passengers, kandy
#
#   Topic 7 (17 articles)
#     nbro, construction, houses, housing, areas, government, landslide, risk, affected, unauthorised, land, disaster, said, building, identified, relocation, locations, prone, landslides, national building, organisation, ministry, people, zones, resettlement, process, building research, national building research, high risk, officials
#
#   Topic 8 (16 articles)
#     shortage, paddy, farmers, food, crops, hectares, cultivation, vegetable, 000 hectares, food security, 000, floods, agriculture, livestock, vegetables, compensation, security, maize, cyclone, affected, cultivated, rice, daily, supply, ministry, damaged, compensate, daily morning, commerce food, commerce food security
#
#   Topic 9 (16 articles)
#     hrcsl, emergency, rights, disaster, provisions, said, president, regulations, human rights, certain, party leaders, public, constitutional, gn, parliamentary, government, november, psc, human, failure, natural, ers, state, issued, measures, leaders, taken, ditwah, party, attorney
#
#   Topic 10 (14 articles)
#     debt, growth, economic, imf, economy, fiscal, billion, recovery, fdi, cyclone, inflation, year, restructuring, reconstruction, infrastructure, country, immediate, spending, government, ditwah, million, foreign, investment, development, damage, likely, economists, gdp, disaster, 2022
#
#   Topic 11 (14 articles)
#     political, disaster, government, state, public, media, governance, maritime, national, social, institutional, writer, cyclone, crisis, social media, information, management, people, politics, opposition, act, country, disaster management, india, ditwah, security, citizens, society, merely, response
#
#   Topic 12 (12 articles)
#     christmas, year, hope, festive, season, said, family, people, new year, waste, celebrate, new, lost, shared, just, time, spirit, festive season, celebration, celebrations, don, affected, home, like, floods, nation, come, country, giving, compassion
#
#   Topic 13 (12 articles)
#     businesses, enterprises, loan, industries, ministry, msme, export, sector, affected, msmes, smes, industry, boi, ministry industry, medium, data, impact, business, loans, information, 16, support, rate, period, development, entrepreneurship development, entrepreneurship, rs, industry entrepreneurship development, industry entrepreneurship
#
#   Topic 14 (12 articles)
#     health, hospitals, medical, dr, hospital, medicines, equipment, services, chilaw, affected, diseases, healthcare, essential, patients, care, ministry, water, facilities, essential medicines, dgh, mahiyangana, base hospital, mental, health ministry, disaster, health sector, jasinghe, staff, base, public health
#
#   Topic 15 (11 articles)
#     winds, north, mm, strong winds, kmph, strong, showers, central, areas, northern north central, expected, northern north, sea, rainfall, trincomalee, provinces, northern, north central, sea areas, department, km, forecast, meteorology, parts, department meteorology, advised, heavy, western, hours, 60
#
#   Topic 16 (11 articles)
#     irrigation, reservoirs, water, officials, paddy, rainfall, damaged, fields, paddy fields, district, reservoir, mahaweli, gates, said, ditwah, cyclone ditwah, water levels, repairs, canals, department, measures, restoration, kotmale, levels, land irrigation, agricultural, cyclone, water supply, stated, protect
#
#   Topic 17 (10 articles)
#     tourism, tourist, arrivals, tourists, hotels, noted, sltda, travel, nuwara eliya, nuwara, said, eliya, experiences, wildlife, industry, development, nature, registered, morning, kandy, damage, cinnamon, central, sunday morning, destinations, impact, informal, country, hotel, sunday
#
#   Topic 18 (8 articles)
#     farmers, pension, post offices, payment, payments, agrarian, pensions, offices, payment period, rs, ha, post, agrarian insurance, agrarian insurance board, agricultural agrarian insurance, agricultural agrarian, insurance board, extended, cyclone, 31, board, granted, month, december, fishermen, period, disbursed, paddy, affected cyclone ditwah, affected
#
#   Topic 19 (8 articles)
#     children, child, parents, emotional, mental, said, health, mental health, women, affected, child protection, lost, protection, orphaned, children lost, probation, shelters, teachers, centres, disaster, daily, stress, children affected, support, dr, affected children, camps, unicef, child affairs, hospital
#
#   Topic 20 (7 articles)
#     sc, cricket, week, game, domestic, slr, national, players, competition, 2026, federation, resume, played, dec, set, 26, army, cyclone, structure, vs, country, 2025, competitive, clash, police, 14, scheduled, nation, announced, ditwah
#
#   Topic 21 (6 articles)
#     police, public, personal, messages, individuals, information, media, fake, scams, bia, investigation, police media, email, links, channels, fraudulent, ministry, urged public, officers, police media spokesperson, bomb, received, share, wootler, media spokesperson, superintendent police, superintendent, social media, ministry said, urged
#
#   Topic 22 (6 articles)
#     labour, workers, employment, affected, tea, losses, organisation, sectors, agriculture, brief, fisheries, impact, 48, emergency cash, medium, income losses, livelihoods, ditwah, landslides, intensive, social protection, protection, medium term, month, 000, potential, income, decent, recovery programmes, data
#
#   Topic 23 (5 articles)
#     party, government, rs, parliament, opposition, president, akd, sjb, slfp, disaster, minister, relief, billion, members, rebuilding, funds, unp, fund, 000, leader, national, wickremesinghe, meeting, noted, political, cyclone, affected, country, mp, committee
#
# ====================================================================================================
#   Daily FT — 16 topics, 380 articles
# ====================================================================================================
#
#   Topic 0 (100 articles)
#     disaster, government, public, national, climate, country, cyclone, economic, management, ditwah, people, political, time, disasters, risk, relief, recovery, state, systems, emergency, president, water, tax, development, cyclone ditwah, resilience, infrastructure, response, disaster management, social
#
#   Topic 1 (58 articles)
#     relief, support, affected, cyclone, rebuilding, communities, rs, ditwah, cyclone ditwah, rebuilding fund, million, efforts, fund, group, commitment, families, recovery, company, donation, sanath, director, colombo, affected cyclone, secretary president, dr nandika sanath, nandika sanath, nandika, nandika sanath kumanayake, sanath kumanayake, kumanayake
#
#   Topic 2 (22 articles)
#     support, humanitarian, uk, assistance, affected, cyclone, cyclone ditwah, relief, ditwah, efforts, million, emergency, response, aid, condolences, red, solidarity, red cross, people, cross, china, families, high commissioner, communities, norway, commissioner, wfp, high, 000, partners
#
#   Topic 3 (20 articles)
#     tourism, industry, visitors, travel, travellers, tourists, tourism industry, destination, arrivals, sector, insurance, world, hotels, city, colombo, country, cultural, said, tourism sector, hewawasam, dreams, city dreams, cinnamon, global, cinnamon life, strong, confidence, coffee, 2025, risk
#
#   Topic 4 (18 articles)
#     imf, said, debt, rfi, dr, fiscal, financing, reforms, eff, recovery, review, cyclone, economic, investment, reform, fund, program, million, cbsl, stability, term, monetary, disaster, mel, supported, international, ditwah, support, government, spending
#
#   Topic 5 (16 articles)
#     rs, billion, 2026, 2025, said, rs 500, estimate, gdp, year, 500, government, supplementary, trillion, budget, fiscal, 500 billion, expenditure, rs 500 billion, supplementary estimate, revenue, growth, yoy, primary, parliament, surplus, ditwah, deficit, 000, finance, dr
#
#   Topic 6 (15 articles)
#     president, officials, compensation, instructed, affected, district, estate, dissanayake, said, kumara, meeting, government, president anura kumara, president anura, houses, disaster, kumara dissanayake, anura kumara dissanayake, anura kumara, restoration, damaged, damage, anura, ministry, ensure, essential, officers, sector, water, minister
#
#   Topic 7 (14 articles)
#     world bank, suriyapperuma, bank, said, world, dr, insurance, dr suriyapperuma, damage, recovery, digital, treasury, government, project, rs, rebuilding, billion, support, insurers, services, bank group, world bank group, motor, grade, premiums, suriyapperuma said, sector, secretary, dr suriyapperuma said, including
#
#   Topic 8 (13 articles)
#     india, relief, indian, medical, bandhu, sagar bandhu, operation sagar bandhu, operation sagar, sagar, operation, rescue, ins, support, aircraft, supplies, tonnes, assistance, air, helicopters, force, iaf, team, operations, ongoing, air force, bridge, field, army, pakistan, consignment
#
#   Topic 9 (13 articles)
#     industry, enterprises, bank, boi, tea, industries, ministry, businesses, development, banks, affected, sme, entrepreneurship development, entrepreneurship, scale, industry entrepreneurship, industry entrepreneurship development, cyclone, support, operations, loan, scale enterprises, association, small, ditwah, commercial, data, commercial bank, industrial, impact
#
#   Topic 10 (11 articles)
#     market, rs, 15, rate, week, billion, 10, bond, 01, maturity, trading, secondary, day, auction, rates, net, 28, money, yields, bank, points, average, respectively, 25, seen, 03, total, central bank, 06, 29
#
#   Topic 11 (8 articles)
#     families, districts, persons, centres, reported, dmc, kandy, closed, affected, missing, weather, conditions, deaths, colombo, recorded, flood, remain, people, badulla, river, gampaha, alert, number, highest, issued, report, affected persons, residents, yesterday, puttalam
#
#   Topic 12 (8 articles)
#     japan, ambassador, iom, medical, assistance, relief, team, medical team, jica, emergency, jdr, relief goods, goods, emergency relief, japanese, disaster, 200, kits, representative, government japan, united nations, people, provide, cyclone, wfp, handed, japan disaster relief, japan disaster, disaster relief, unicef
#
#   Topic 13 (8 articles)
#     india, indian, dr jaishankar, jaishankar, assistance, minister, modi, ins, dr, support, cyclone, prime minister, prime, reconstruction, medical, relations, rescue, people, relief, ditwah, countries, vikrant, said, affairs, economic, affairs minister, cyclone ditwah, humanitarian, herath, ins vikrant
#
#   Topic 14 (8 articles)
#     health, women, unfpa, girls, response, emergency, women girls, children, cyclone, unicef, support, life saving, services, humanitarian, saving, affected, australia, cyclone ditwah, pregnant, partners, pregnant women, life, dignity, ditwah, nutritional, essential, safety, kits, needs, nutrition
#
#   Topic 15 (5 articles)
#     president, dissanayake, china, president dissanayake, support, affairs, united states, national people congress, people congress, congress, vice chairman, states, national people, people, diplomatic, secretary, vice, chairman, united, expressed, development, committee vice, wang, national, chinese, emphasised, president anura kumara, minister, president anura, tariff
#
# ====================================================================================================
#   The Island — 17 topics, 284 articles
# ====================================================================================================
#
#   Topic 0 (35 articles)
#     climate, disaster, ditwah, cyclone, management, national, systems, disasters, country, change, cyclone ditwah, disaster management, weather, water, global, areas, communities, landslides, human, children, climate change, government, future, like, natural, need, environmental, health, education, tsunami
#
#   Topic 1 (27 articles)
#     relief, support, humanitarian, affected, assistance, emergency, cyclone, aid, korea, million, ditwah, wfp, japan, cyclone ditwah, said, 000, foreign, response, minister, international, people, needs, supplies, australia, usd, ambassador, communities, tents, efforts, embassy
#
#   Topic 2 (25 articles)
#     support, bank, banks, relief, cyclone ditwah, cyclone, rs, ditwah, affected, recovery, fund, pvt, national, communities, rebuild, chamber, efforts, port city, million, commercial, commitment, rebuilding, rebuilding fund, financial, city, commercial bank, foundation, port, association, contribution
#
#   Topic 3 (14 articles)
#     north, showers, issued, heavy, november, cyclonic storm, warning, likely, near, cyclonic, storm, storm ditwah, sea, ditwah, cyclonic storm ditwah, island, weather, 00, western provinces, km, places, areas, cyclone, november 2025, requested, areas island, equator, provinces, department, western
#
#   Topic 4 (13 articles)
#     indian, india, air, relief, air force, force, medical, assistance, support, high, efforts, united states, cyclone, aircraft, response, essential, cyclone ditwah, states, affected, high commissioner, ditwah, iaf, commissioner, united, operation, bandhu, sagar, sagar bandhu, supplies, tonnes
#
#   Topic 5 (12 articles)
#     bank, world bank, digital, development, support, finance, imf, project, recovery, world, cyclone, services, million, economic, partners, government, international, pathfinder foundation, pathfinder, said, country, public, fund, disaster, group, loan, sector, fiscal, emergency, help
#
#   Topic 6 (11 articles)
#     missing, dmc, dead, district, families, kandy, centres, deaths, said, management centre dmc, centre dmc, reported, persons, nbro, eliya, nuwara eliya, nuwara, disaster, disaster management centre, districts, management centre, badulla, number, relief centres, people, ditwah, total, cyclone ditwah, centre, kurunegala
#
#   Topic 7 (11 articles)
#     government, said, disaster, opposition, budget, 2026, parliament, budget 2026, premadasa, sjb, electricity, cyclone, consumers, revenue, said government, leader, expenditure, yesterday, freedom, act, gammanpila, failed, media, urged, house, ditwah, government failed, cyclone ditwah, govt, funds
#
#   Topic 8 (10 articles)
#     said, people, indonesia, worst, floods, 000, aceh, water, dmc, missing, flood, flooding, house, dmc said, waters, areas, killed, toll, rains, slaf, rain, thousands, air, shelters, told, cyclone, food, bbc, resident, death toll
#
#   Topic 9 (10 articles)
#     president, minister, district, prime minister, prime, religious, stated, officials, instructed, officers, export, entrusted, kumara, ministry, anura, army, disaster, secretary, compensation, government, kumara dissanayake, president anura kumara, president anura, anura kumara dissanayake, awards, motherland, anura kumara, special, dissanayake, steps
#
#   Topic 10 (10 articles)
#     tourism, tea, travellers, confidence, tourist, safe, year, travel, international, srilankan airlines, srilankan, industry, airlines, cyclone, 2025, port, christmas, market, ready, ditwah, sector, quality, december, cyclone ditwah, hotel, global, resilience, open, key, hospitality
#
#   Topic 11 (9 articles)
#     china, secretary, delegation, unesco, ambassador, committee, support, holy, president, chinese, assistance, relations, chairman, dr, meeting, lawmakers, visit, secretary president, vice, affected, cooperation, french, briefed, secretariat, member, national people, jvp, singapore, programme, tuesday
#
#   Topic 12 (8 articles)
#     government, opposition, political, disaster, npp, warnings, victims, jvp, floods, unp, country, power, disasters, weather, politicians, leaders, yahapalana, attacks, disaster victims, economy, easter, yahapalana government, houses, terror, self, relief, weather disasters, failure, psc, parties
#
#   Topic 13 (8 articles)
#     km, railway, officials, rail, polonnaruwa, wildlife, elephant, road, damaged, electric, committee, cyclone, kandy, roads, ditwah, informed, network, garden, trace, services, development, department, said, meeting, water supply, line, bridges, damage, alternative, transport
#
#   Topic 14 (5 articles)
#     government, national, disaster, relief, international, economic, victims, crisis, political, country, corruption, parallel, civil, assistance, society, president, donor, needs, funds, civil society, people, systems, donors, support, rebuilding, agencies, important, reach, money, opposition
#
#   Topic 15 (5 articles)
#     mobitel, slt mobitel, slt, access, network, users, connectivity, medical, restoration, national, public, company, service, guide, services, tours, fibre, 247, blue, information, emergency, support, efforts, critical, online, disaster, recovery, operations, affected, cyclone
#
#   Topic 16 (5 articles)
#     npp, government, jvp, president, dissanayake, wickremesinghe, opposition, leader, unp, political, india, premadasa, jvp npp, sajith, rajapaksa, police, parliament, party, ranwala, president dissanayake, sajith premadasa, ranil, having, mahinda, sjb, parliamentary, namal, 2024, country, administration

# %%
# Intra-model topic similarity heatmaps (c-TF-IDF cosine similarity)
for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    model = outlet_results[outlet]['model']
    n_topics = len(model.get_topic_info()[model.get_topic_info()['Topic'] != -1])
    fig = model.visualize_heatmap(top_n_topics=n_topics, title=f"{name} — Inter-Topic Similarity")
    fig.show()

# %%
# Load article URLs from database
print("Loading article URLs...")
with get_db() as db:
    # Adjust this query based on your schema
    articles_with_urls = {
        row['id']: row.get('url', row.get('link', f"ID:{row['id']}"))
        for row in db.get_articles()  # or whatever method fetches articles
    }

# List articles with URLs under each topic
for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    r = outlet_results[outlet]
    ti = r['topic_info']
    ti_topics = ti[ti['Topic'] != -1].sort_values('Count', ascending=False)
    
    print(f"\n{'='*100}")
    print(f"  {name} — Articles by Topic")
    print(f"{'='*100}")
    
    for _, row in ti_topics.iterrows():
        tid = row['Topic']
        words = r['model'].get_topic(tid)
        keyword_str = ', '.join(w for w, _ in words[:20]) if words else ''
        
        print(f"\n  Topic {tid}: {keyword_str}")
        
        topic_mask = np.array(r['topics']) == tid
        article_indices = np.where(topic_mask)[0]
        
        for idx in article_indices:
            article_id = r['article_ids'][idx]
            title = outlet_data[outlet]['titles'][idx]
            url = articles_with_urls.get(article_id, 'No URL')
            print(f"    • {title[:70]}")
            print(f"      {url}")
# Out:
# Loading article URLs...
#
# ====================================================================================================
#   Daily News — Articles by Topic
# ====================================================================================================
#
#   Topic 0: disaster, climate, people, disasters, time, government, ditwah, natural, country, need, public, lives, relief, media, systems, global, world, cyclone, countries, rescue
#     • New paradigm for climate multilateralism in South Asia
#       https://dailynews.lk/2025/11/28/features/903627/new-paradigm-for-climate-multilateralism-in-south-asia/
#     • Climate Change at work
#       https://dailynews.lk/2025/11/29/editorial/904474/climate-change-at-work/
#     • The storm speaks!
#       https://dailynews.lk/2025/11/29/sachitra-mahendra/904492/the-storm-speaks/
#     • Double down to tackle Sri Lanka’s freshwater tsunami
#       https://dailynews.lk/2025/12/01/features/905494/double-down-to-tackle-sri-lankas-freshwater-tsunami/
#     • Vigilance, the best weapon
#       https://dailynews.lk/2025/12/01/general-opinion/905430/vigilance-the-best-weapon-2/
#     • Ditwah’s wake-up call
#       https://dailynews.lk/2025/12/02/general-opinion/906117/ditwahs-wake-up-call/
#     • From emergency relief to long-term resilience
#       https://dailynews.lk/2025/12/02/general-opinion/906129/from-emergency-relief-to-long-term-resilience/
#     • The road ahead
#       https://dailynews.lk/2025/12/03/editorial/906802/the-road-ahead/
#     • When nature strikes, we need unity, not debate
#       https://dailynews.lk/2025/12/03/features/906828/when-nature-strikes-we-need-unity-not-debate/
#     • Rescue without borders
#       https://dailynews.lk/2025/12/03/features/906831/rescue-without-borders/
#     • Are we climate-resilient enough?
#       https://dailynews.lk/2025/12/03/general-opinion/906848/are-we-climate-resilient-enough/
#     • In the eye of Ditwah
#       https://dailynews.lk/2025/12/04/features/907685/in-the-eye-of-ditwah/
#     • Disaster education a must
#       https://dailynews.lk/2025/12/04/editorial/907682/disaster-education-a-must/
#     • Many suns of solidarity will cut through grief’s dense darkness
#       https://dailynews.lk/2025/12/04/general-opinion/907699/many-suns-of-solidarity-will-cut-through-griefs-dense-darkness/
#     • Forecast that fell short
#       https://dailynews.lk/2025/12/05/features/908304/forecast-that-fell-short/
#     • Rising from the ruins
#       https://dailynews.lk/2025/12/05/general-opinion/908346/rising-from-the-ruins/
#     • Strengthening disaster management and policy governance in the central
#       https://dailynews.lk/2025/12/05/features/908352/strengthening-disaster-management-and-policy-governance-in-the-central-province/
#     • The heavy cost of the disaster
#       https://dailynews.lk/2025/12/06/editorial/909005/the-heavy-cost-of-the-disaster/
#     • Small things matter
#       https://dailynews.lk/2025/12/08/features/909596/small-things-matter/
#     • Key strategies for effective disaster management
#       https://dailynews.lk/2025/12/08/general-opinion/909656/key-strategies-for-effective-disaster-management/
#     • Hope amidst the deadly waters
#       https://dailynews.lk/2025/12/08/features/909653/hope-amidst-the-deadly-waters/
#     • The burden of neglect
#       https://dailynews.lk/2025/12/09/editorial/910661/the-burden-of-neglect/
#     • China–Japan tensions and what they mean for Sri Lanka and the region
#       https://dailynews.lk/2025/12/09/general-opinion/910774/china-japan-tensions-and-what-they-mean-for-sri-lanka-and-the-region/
#     • Need meets deed
#       https://dailynews.lk/2025/12/10/ishara-jayawardane/911438/need-meets-deed/
#     • Cyclone Ditwah Every cloud has a silver lining
#       https://dailynews.lk/2025/12/10/tissa-mihindupura/911470/cyclone-ditwah-every-cloud-has-a-silver-lining/
#     • Land Reclamation Act 2025
#       https://dailynews.lk/2025/12/11/features/912159/land-reclamation-act-2025/
#     • Beyond the deluge
#       https://dailynews.lk/2025/12/11/features/912178/beyond-the-deluge/
#     • The ill-timed Cyclone Ditwah
#       https://dailynews.lk/2025/12/11/general-opinion/912186/the-ill-timed-cyclone-ditwah/
#     • Hands-on recovery effort
#       https://dailynews.lk/2025/12/11/features/912215/hands-on-recovery-effort/
#     • Driving on roads after a major natural disaster
#       https://dailynews.lk/2025/12/12/features/913203/driving-on-roads-after-a-major-natural-disaster/
#     • Genuine political desire for disaster management cooperation in South
#       https://dailynews.lk/2025/12/12/features/913181/genuine-political-desire-for-disaster-management-cooperation-in-south-asia/
#     • Rebuilding Housing Post-Ditwah
#       https://dailynews.lk/2025/12/12/general-opinion/913258/rebuilding-housing-post-ditwah/
#     • POETRY CORNER
#       https://dailynews.lk/2025/12/13/culture-art/913818/poetry-corner-68/
#     • Healing for the submerged soul
#       https://dailynews.lk/2025/12/15/features/914455/healing-for-the-submerged-soul/
#     • Turning point for a climate-smart, AI-driven plantation economy
#       https://dailynews.lk/2025/12/16/general-opinion/915290/turning-point-for-a-climate-smart-ai-driven-plantation-economy/
#     • Prelude to a national discourse
#       https://dailynews.lk/2025/12/16/general-opinion/915287/prelude-to-a-national-discourse/
#     • When the rain would not stop
#       https://dailynews.lk/2025/12/17/general-opinion/916396/when-the-rain-would-not-stop/
#     • Bondi beach attack: a reminder for Sri Lanka
#       https://dailynews.lk/2025/12/17/general-opinion/916405/bondi-beach-attack-a-reminder-for-sri-lanka/
#     • A well thought out move
#       https://dailynews.lk/2025/12/19/editorial/917866/a-well-thought-out-move-4/
#     • Cultural afterlife of disaster
#       https://dailynews.lk/2025/12/20/general-opinion/918490/cultural-afterlife-of-disaster/
#     • From DitwaH to data
#       https://dailynews.lk/2025/12/22/features/919268/from-ditwah-to-data/
#     • America’s Xmas gift to humankind
#       https://dailynews.lk/2025/12/23/features/920090/americas-xmas-gift-to-humankind/
#     • When Neighbourhood Solidarity Became Regional Leadership
#       https://dailynews.lk/2025/12/23/general-opinion/920121/when-neighbourhood-solidarity-became-regional-leadership/
#     • Can Govt bet Rs.500 Bn on economic recovery?
#       https://dailynews.lk/2025/12/24/general-opinion/921072/can-govt-bet-rs-500-bn-on-economic-recovery/
#     • Diplomacy after disaster
#       https://dailynews.lk/2025/12/24/general-opinion/921055/diplomacy-after-disaster/
#     • A reasonable request
#       https://dailynews.lk/2025/12/24/editorial/921123/a-reasonable-request/
#     • A time for Giving
#       https://dailynews.lk/2025/12/25/editorial/921567/a-time-for-giving/
#     • Let us dispel the darkest era and illuminate the World with the Lamp o
#       https://dailynews.lk/2025/12/25/local/922244/let-us-dispel-the-darkest-era-and-illuminate-the-world-with-the-lamp-of-hope/
#     • Serving others as we follow Christ
#       https://dailynews.lk/2025/12/25/features/921537/serving-others-as-we-follow-christ/
#     • Christmas Messages
#       https://dailynews.lk/2025/12/25/local/921718/christmas-messages/
#     • The need for external financing
#       https://dailynews.lk/2025/12/25/general-opinion/921585/the-need-for-external-financing/
#     • Facing natural disasters
#       https://dailynews.lk/2025/12/26/editorial/922049/facing-natural-disasters/
#     • After Cyclone Ditwah
#       https://dailynews.lk/2025/12/27/features/922471/after-cyclone-ditwah/
#     • Disaster journalism, not disastrous
#       https://dailynews.lk/2025/12/29/features/923060/disaster-journalism-not-disastrous/
#     • A nation remade by trial
#       https://dailynews.lk/2025/12/30/general-opinion/923803/a-nation-remade-by-trial/
#     • A busy quarter-century mark
#       https://dailynews.lk/2025/12/31/features/924667/a-busy-quarter-century-mark/
#     • 2025 in retrospect
#       https://dailynews.lk/2025/12/31/general-opinion/924689/2025-in-retrospect/
#     • Sri Lanka should build better in 2026
#       https://dailynews.lk/2025/12/31/general-opinion/924652/sri-lanka-should-build-better-in-2026/
#
#   Topic 1: fund, rebuilding fund, rebuilding, rs, million, group, plc, donates, kumanayake, nandika, nandika sanath, dr nandika sanath, nandika sanath kumanayake, dr nandika, sanath kumanayake, fund established, presidential secretariat, sanath, dr, rebuilding fund established
#     • Rs. 10 Million contribution to the ‘Rebuilding Sri Lanka’ fund
#       https://dailynews.lk/2025/12/04/local/908374/rs-10-million-contribution-to-the-rebuilding-sri-lanka-fund/
#     • SLC donates Rs. 300 Million to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/04/local/908638/slc-donates-rs-300-million-to-rebuilding-sri-lanka-fund/
#     • SLC donates Rs. 300M to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/05/sports/908516/slc-donates-rs-300m-to-rebuilding-sri-lanka-fund/
#     • Gangaramaya donates Rs. 30 M to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/05/local/908867/gangaramaya-donates-rs-30-m-to-rebuilding-sri-lanka-fund/
#     • BNMF donates Rs. 250 Mn for recovery efforts
#       https://dailynews.lk/2025/12/10/local/911389/bnmf-donates-rs-250-mn-for-recovery-efforts/
#     • Naturub Group of Companies donates Rs. 100 Million to ‘Rebuilding Sri
#       https://dailynews.lk/2025/12/11/local/912356/naturub-group-of-companies-donates-rs-100-million-to-rebuilding-sri-lanka-fund/
#     • People’s Leasing and Finance contribute Rs. 10 M to “Rebuilding Sri La
#       https://dailynews.lk/2025/12/12/local/913534/peoples-leasing-and-finance-contribute-rs-10-m-to-rebuilding-sri-lanka/
#     • Macksons Holdings donates Rs.15 Mn to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/12/business/912925/macksons-holdings-donates-rs-15-mn-to-rebuilding-sri-lanka-fund/
#     • Thilakawardena Textiles donates to the ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/12/local/913724/thilakawardena-textiles-donates-to-the-rebuilding-sri-lanka-fund/
#     • Lakbima Rice Mills (Pvt) Ltd donates Rs. 100Mn to ‘Rebuilding Sri Lank
#       https://dailynews.lk/2025/12/15/local/914605/lakbima-rice-mills-pvt-ltd-donates-rs-100mn-to-rebuilding-sri-lanka-fund/
#     • EFITA donates Rs. 20 Mn to strengthen ‘Rebuilding Sri Lanka’ Fund foll
#       https://dailynews.lk/2025/12/16/local/915606/efita-donates-rs-20-mn-to-strengthen-rebuilding-sri-lanka-fund-following-ditwah-devastation/
#     • Union Chemicals donates Rs. 1 Mn to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/17/local/916526/union-chemicals-donates-rs-1-mn-to-rebuilding-sri-lanka-fund/
#     • Hatton National Bank donates Rs. 100 Mn to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/17/local/916535/hatton-national-bank-donates-rs-100-mn-to-rebuilding-sri-lanka-fund/
#     • Multiple Financial contributions to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/18/local/917261/multiple-financial-contributions-to-rebuilding-sri-lanka-fund/
#     • People’s Leasing Group donates Rs. 10 Mn to ‘Rebuilding Sri Lanka’ Fun
#       https://dailynews.lk/2025/12/18/business/916945/peoples-leasing-group-donates-rs-10-mn-to-rebuilding-sri-lanka-fund/
#     • Swedish donor contributes USD 33,000 to ‘Rebuilding Sri Lanka’ fund
#       https://dailynews.lk/2025/12/18/local/917575/swedish-donor-contributes-usd-33000-to-rebuilding-sri-lanka-fund/
#     • HNB donates Rs. 100 Mn towards Rebuild Sri Lanka Fund
#       https://dailynews.lk/2025/12/19/business/917730/hnb-donates-rs-100-mn-towards-rebuild-sri-lanka-fund/
#     • RDB contributes Rs. 25 million to the ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/20/local/918843/rdb-contributes-rs-25-million-to-the-rebuilding-sri-lanka-fund/
#     • Tiesh by Lakmini Kandy backs national relief efforts
#       https://dailynews.lk/2025/12/20/local/918850/tiesh-by-lakmini-kandy-backs-national-relief-efforts/
#     • Two financial contributions received for the ‘Rebuilding Sri Lanka’
#       https://dailynews.lk/2025/12/20/local/918857/two-financial-contributions-received-for-the-rebuilding-sri-lanka/
#     • RDB contributes Rs. 25 Mn to ‘Rebuilding Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/22/local/919357/rdb-contributes-rs-25-mn-to-rebuilding-sri-lanka-fund/
#     • Royal College Past Teachers donate Rs. 1 Mn to Rebuild Sri Lanka Fund
#       https://dailynews.lk/2025/12/22/local/919298/royal-college-past-teachers-donate-rs-1-mn-to-rebuild-sri-lanka-fund/
#     • Pyramid Wilmar donates LKR 50 Mn to Presidential Secretariat for Flood
#       https://dailynews.lk/2025/12/22/business/919118/pyramid-wilmar-donates-lkr-50-mn-to-presidential-secretariat-for-flood-relief/
#     • Containers Transport Owners Assn., SriLankan Airlines Licensed Aircraf
#       https://dailynews.lk/2025/12/22/local/919368/containers-transport-owners-assn-srilankan-airlines-licensed-aircraft-engineers-assn-provide-financial-assistance-to-rebuilding-sri-lanka-fund/
#     • The Technocity donates Rs. 50 Mn as humanitarian response to Cyclone D
#       https://dailynews.lk/2025/12/23/business/919854/the-technocity-donates-rs-50-mn-as-humanitarian-response-to-cyclone-ditwah/
#     • MKS Group donates towards ‘Rebuilding Sri Lanka’
#       https://dailynews.lk/2025/12/24/local/920861/mks-group-donates-towards-rebuilding-sri-lanka/
#     • Business community extends support to “Rebuild Sri Lanka” fund
#       https://dailynews.lk/2025/12/24/local/921887/business-community-extends-support-to-rebuild-sri-lanka-programme/
#     • MKS Group donates to ‘Rebuilding Sri Lanka’ Flood Relief Fund
#       https://dailynews.lk/2025/12/26/local/922113/mks-group-donates-to-rebuilding-sri-lanka-flood-relief-fund/
#     • Hill Country Malayagam community donates Rs. 1 Mn to ‘Rebuilding Sri L
#       https://dailynews.lk/2025/12/26/local/922013/hill-country-malayagam-community-donates-rs-1-mn-to-rebuilding-sri-lanka-fund/
#     • United Motors Lanka PLC donates Rs. 10 million to ‘Rebuilding Sri Lank
#       https://dailynews.lk/2025/12/29/local/923499/united-motors-lanka-plc-donates-rs-10-million-to-rebuilding-sri-lanka-fund/
#     • Construction resumes at Jaffna Int’l Cricket Stadium
#       https://dailynews.lk/2025/12/30/sports/924072/construction-resumes-at-jaffna-intl-cricket-stadium/
#     • United Motors Lanka PLC Donates Rs. 10 Mn to ‘Rebuilding Sri Lanka’ Fu
#       https://dailynews.lk/2025/12/30/local/924098/united-motors-lanka-plc-donates-rs-10-mn-to-rebuilding-sri-lanka-fund/
#     • SITC Campus donates Rs. 1 Mn to ‘Rebuild Sri Lanka’ Fund
#       https://dailynews.lk/2025/12/30/business/923866/sitc-campus-donates-rs-1-mn-to-rebuild-sri-lanka-fund/
#     • SLIIT donates Rs. 20 million to the “Rebuilding Sri Lanka” Fund
#       https://dailynews.lk/2025/12/31/local/925100/sliit-donates-rs-20-million-to-the-rebuilding-sri-lanka-fund/
#     • George Keyt Foundation contributes to national disaster relief efforts
#       https://dailynews.lk/2025/12/31/business/924453/george-keyt-foundation-contributes-to-national-disaster-relief-efforts/
#
#   Topic 2: said, minister, government, parliament, rs, disaster, country, opposition, billion, president, cabinet, 000, taken, people, budget, management, committee, affected, development, yesterday
#     • PARLIAMENT
#       https://dailynews.lk/2025/12/02/politics/906321/parliament-82/
#     • Government raises flood-relief home cleaning assistance
#       https://dailynews.lk/2025/12/02/local/907069/government-raises-flood-relief-home-cleaning-assistance/
#     • Decisions taken at the Cabinet meeting held on December 1
#       https://dailynews.lk/2025/12/03/politics/907084/decisions-taken-at-the-cabinet-meeting-held-on-december-1/
#     • Shed differences and unite to recover from this national disaster- NMS
#       https://dailynews.lk/2025/12/03/local/906944/shed-differences-and-unite-to-recover-from-this-national-disaster-nmsj-leader-karu-jayasuriya/
#     • Urgent relief for disaster affected
#       https://dailynews.lk/2025/12/03/local/907178/urgent-relief-for-disaster-affected/
#     • PARLIAMENT
#       https://dailynews.lk/2025/12/04/politics/907865/parliament-83/
#     • 2026 Budget passed by majority of 157 votes
#       https://dailynews.lk/2025/12/05/local/908938/2026-budget-passed-by-majority-of-158-votes/
#     • Parliament to hold third reading of 2026 Budget today
#       https://dailynews.lk/2025/12/05/local/908717/parliament-to-hold-third-reading-of-2026-budget-today/
#     • Govt will not withdraw from IMF agreement – President
#       https://dailynews.lk/2025/12/06/local/909166/govt-will-not-withdraw-from-imf-agreement-president/
#     • Compensation in cash for disaster hit persons – Minister
#       https://dailynews.lk/2025/12/06/breaking-news/909176/compensation-in-cash-for-disaster-hit-persons-minister/
#     • Government has managed expenditure, minimised waste and established fi
#       https://dailynews.lk/2025/12/06/breaking-news/909190/government-has-managed-expenditure-minimised-waste-and-established-fiscal-discipline-minister/
#     • Country will emerge stronger than ever, despite obstacles –Deputy Mini
#       https://dailynews.lk/2025/12/06/local/909115/country-will-emerge-stronger-than-ever-despite-obstacles-deputy-minister-pradeep-sundaralingam/
#     • Minister Anil Jayantha urges global community to join Sri Lanka’s rebu
#       https://dailynews.lk/2025/12/09/local/911147/minister-anil-jayantha-urges-global-community-to-join-sri-lankas-rebuilding-efforts-in-al-jazeera-interview/
#     • Committee to ensure foreign aid goes to intended people
#       https://dailynews.lk/2025/12/09/breaking-news/910912/committee-to-ensure-foreign-aid-goes-to-intended-people/
#     • Relief to people, restoration utmost priority – Deputy Minister
#       https://dailynews.lk/2025/12/10/breaking-news/911618/relief-to-people-restoration-utmost-priority-deputy-minister/
#     • “We will rebuild better” – President outlines economic and disaster re
#       https://dailynews.lk/2025/12/10/local/911797/we-will-rebuild-better-president-outlines-economic-and-disaster-recovery-plans/
#     • International Lankan Scholars must be involved in future Disaster Mana
#       https://dailynews.lk/2025/12/10/local/911435/international-lankan-scholars-must-be-involved-in-future-disaster-management-nmsj/
#     • Foreign aid received after cyclone is being efficiently utilised by Go
#       https://dailynews.lk/2025/12/11/local/912532/foreign-aid-received-after-cyclone-is-being-efficiently-utilised-by-govt-ven-omalpe-sobhitha-thera/
#     • Cabinet Decisions
#       https://dailynews.lk/2025/12/12/local/913350/cabinet-decisions-103/
#     • National Council for Disaster Management convenes under President’s pa
#       https://dailynews.lk/2025/12/16/local/915523/national-council-for-disaster-management-convenes-under-presidents-patronage/
#     • Two thousand families to receive Rs. 25,000 each for cleaning their ho
#       https://dailynews.lk/2025/12/17/local/916205/two-thousand-families-to-receive-rs-25000-each-for-cleaning-their-houses/
#     • International donor conference in January – Minister
#       https://dailynews.lk/2025/12/18/local/917358/international-donor-conference-in-january-minister/
#     • Long road after Ditwah
#       https://dailynews.lk/2025/12/18/features/917129/long-road-after-ditwah/
#     • PM presents Rs. 500 Bn Supplementary Estimate to Parliament
#       https://dailynews.lk/2025/12/19/local/918053/pm-presents-rs-500-bn-supplementary-estimate-to-parliament/
#     • PARLIAMENT
#       https://dailynews.lk/2025/12/19/politics/917955/parliament-84/
#     • Over 250,000 families have received Rs. 25,000 allowance
#       https://dailynews.lk/2025/12/19/breaking-news/918070/over-250000-families-have-received-rs-25000-allowance/
#     • COPF approves a Rs. 500Bn SE to restore livelihoods and infrastructure
#       https://dailynews.lk/2025/12/20/local/918593/copf-approves-a-rs-500bn-se-to-restore-livelihoods-and-infrastructure-ruined-by-ditwah/
#     • 257,000 families out of 493,000 get Rs. 25,000 to clean their houses –
#       https://dailynews.lk/2025/12/20/local/918586/257000-families-out-of-493000-get-rs-25000-to-clean-their-houses-minister-ananda-wijepala/
#     • ‘SL working to protect its water sources to better prepare for climate
#       https://dailynews.lk/2025/12/23/local/920211/sl-working-to-protect-its-water-sources-to-better-prepare-for-climate-related-risks/
#     • Steady steps in recovery and governance
#       https://dailynews.lk/2025/12/25/features/921561/steady-steps-in-recovery-and-governance/
#     • Rs. 25,000 disaster relief paid to 82.8% of eligible victims
#       https://dailynews.lk/2025/12/27/local/922755/rs-25000-disaster-relief-paid-to-82-8-of-eligible-victims/
#     • Govt has met all revenue targets for 2025 – Minister
#       https://dailynews.lk/2025/12/30/local/923975/govt-has-met-all-revenue-targets-for-2025-minister/
#     • “Government optimistic of USD 18 Bn export target, USD 300 Bn economy”
#       https://dailynews.lk/2025/12/30/business/923869/government-optimistic-of-usd-18-bn-export-target-usd-300-bn-economy/
#
#   Topic 3: district, deaths, kandy, affected, missing, families, individuals, damage, disaster, cyclone, houses, dmc, children, estimated, districts, reported, kandy district, people, ditwah, persons
#     • Cyclonic storm ‘Ditwah’ hits country
#       https://dailynews.lk/2025/11/28/local/903874/cyclonic-storm-ditwah-hits-country/
#     • Over 60 deaths, 21 missing from Ditwah cyclone
#       https://dailynews.lk/2025/11/29/local/904548/over-60-deaths-21-missing-from-ditwah-cyclone/
#     • Extreme weather claims 123 lives, 130 still missing – DMC
#       https://dailynews.lk/2025/11/29/local/904740/extreme-weather-claims-123-lives-130-still-missing-dmc/
#     • Cyclone Ditwah: Three die in rain-related incidents in Tamil Nadu
#       https://dailynews.lk/2025/12/01/world/905470/cyclone-ditwah-three-die-in-rain-related-incidents-in-tamil-nadu/
#     • Over 330 deaths, 370 missing in cyclone
#       https://dailynews.lk/2025/12/01/breaking-news/905626/over-330-deaths-370-missing-in-cyclone/
#     • 355 deaths and 370 missing persons recorded so far – DMC
#       https://dailynews.lk/2025/12/02/breaking-news/906386/355-deaths-and-370-missing-persons-recorded-so-far-dmc/
#     • Sri Lanka’s disaster toll reaches 465
#       https://dailynews.lk/2025/12/02/local/907101/sri-lankas-disaster-toll-reaches-465/
#     • Cyclone Ditwah: 22 Districts declared national disaster areas
#       https://dailynews.lk/2025/12/03/local/907508/cyclone-ditwah-22-districts-declared-national-disaster-areas/
#     • Driver suspended for attempting to sell donated water bottles to resta
#       https://dailynews.lk/2025/12/05/local/908831/driver-suspended-for-attempting-to-sell-donated-water-bottles-to-restaurant/
#     • 4,517 houses completely destroyed in cyclone – DMC
#       https://dailynews.lk/2025/12/08/local/910015/4517-houses-completely-destroyed-in-cyclone-dmc/
#     • One-fifth of Sri Lanka flooded by Cyclone Ditwah, affecting 2.3 millio
#       https://dailynews.lk/2025/12/09/local/911234/one-fifth-of-sri-lanka-flooded-by-cyclone-ditwah-affecting-2-3-million-people-undp/
#     • Cyclone Ditwah leaves over 5,000 Homes destroyed and thousands displac
#       https://dailynews.lk/2025/12/09/local/911124/cyclone-ditwa-leaves-over-5000-homes-destroyed-and-thousands-displaced/
#     • Coroners to forgo allowance for cyclone victim inquests
#       https://dailynews.lk/2025/12/09/breaking-news/910939/coroners-to-forgo-allowance-for-cyclone-victim-inquests/
#     • Death toll rises to 639; 211 still missing in Cyclone Ditwah
#       https://dailynews.lk/2025/12/12/local/913541/death-toll-rises-to-639-211-still-missing-in-cyclone-ditwah/
#     • Cyclone Ditwah Disaster: Death toll rises to 640
#       https://dailynews.lk/2025/12/13/local/914120/cyclone-ditwah-disaster-death-toll-rises-to-640/
#     • Ministry cautions against sharing info of children affected by cyclone
#       https://dailynews.lk/2025/12/15/breaking-news/914773/ministry-cautions-against-sharing-info-of-children-affected-by-cyclone/
#     • Kandy records highest number of deaths
#       https://dailynews.lk/2025/12/15/local/914734/kandy-records-highest-number-of-deaths/
#     • Police warn against individuals attempting to exploit situation target
#       https://dailynews.lk/2025/12/16/local/915650/police-warn-against-individuals-attempting-to-exploit-situation-targeting-vulnerable-children/
#     • cyclone causes Rs. 75 billion in damages to RDA
#       https://dailynews.lk/2025/12/17/local/916558/cyclone-causes-rs-75-billion-in-damages-to-rda/
#     • Damage from Cyclone Ditwah estimated at US$ 4.1 Bn – World Bank
#       https://dailynews.lk/2025/12/23/local/920342/damage-from-cyclone-ditwah-estimated-at-us-4-1-bn-world-bank/
#     • Cyclone Ditwah damage equivalent to 4 % of Sri Lanka’s GDP-WBG
#       https://dailynews.lk/2025/12/24/business/921028/cyclone-ditwah-damage-equivalent-to-4-of-sri-lankas-gdp-wbg/
#     • Over 800 kms of electric fences damaged due to cyclone
#       https://dailynews.lk/2025/12/25/local/921856/over-800-kms-of-electric-fences-damaged-due-to-cyclone/
#     • Thirty two children lose fathers after cyclone in Kandy
#       https://dailynews.lk/2025/12/25/local/921768/thirty-two-children-lose-fathers-after-cyclone-in-kandy/
#     • Sri Lanka commemorates 21st anniversary of Boxing Day tsunami
#       https://dailynews.lk/2025/12/26/breaking-news/922181/sri-lanka-commemorates-21st-anniversary-of-boxing-day-tsunami/
#     • Victims of 2004 tsunami commemorated in Peraliya
#       https://dailynews.lk/2025/12/27/breaking-news/922609/victims-of-2004-tsunami-commemorated-in-peraliya/
#     • Over 85,000 children affected by cyclone in Colombo district
#       https://dailynews.lk/2025/12/30/local/924003/over-85000-children-affected-by-cyclone-in-colombo-district/
#     • Cyclone Ditwah inflicts Rs. 21 bn loss on Sri Lanka’s health sector
#       https://dailynews.lk/2025/12/30/local/924234/cyclone-ditwah-inflicts-rs-21-bn-loss-on-sri-lankas-health-sector/
#
#   Topic 4: industry, development, industries, ministry, businesses, affected, entrepreneurship, entrepreneurship development, bank, banks, small, industrialists, entrepreneurs, industrial, industry entrepreneurship development, industry entrepreneurship, enterprises, scale, boi, data
#     • Ceylon Chamber affirms support for national recovery efforts following
#       https://dailynews.lk/2025/12/02/business/906256/ceylon-chamber-affirms-support-for-national-recovery-efforts-following-cyclone-ditwah/
#     • Ministry of Industries launches data collection for Cyclone Ditwah-aff
#       https://dailynews.lk/2025/12/03/uncategorized/907664/ministry-of-industries-launches-data-collection-for-cyclone-ditwah-affected-industries/
#     • President reviews relief and support plans for cyclone affected indust
#       https://dailynews.lk/2025/12/04/breaking-news/908554/president-reviews-relief-and-support-plans-for-cyclone-affected-industries/
#     • Banks Association pledges strong support for economic revival
#       https://dailynews.lk/2025/12/05/business/908210/banks-association-pledges-strong-support-for-economic-revival/
#     • Ministry of Industry launches immediate data collection drive to resto
#       https://dailynews.lk/2025/12/05/business/908220/ministry-of-industry-launches-immediate-data-collection-drive-to-restore-ditwaa-cyclone-affected-industries/
#     • Comprehensive plan to restore industrial sector affected by cyclone su
#       https://dailynews.lk/2025/12/06/local/909236/comprehensive-plan-to-restore-industrial-sector-affected-by-cyclone-submitted-to-president/
#     • Government offers Rs. 200,000 to disaster affected industries for rapi
#       https://dailynews.lk/2025/12/08/local/910346/government-offers-rs-200000-to-disaster-affected-industries-for-rapid-recovery/
#     • Rs. 200,000 to be provided to restart industries hit by Cyclone Ditwah
#       https://dailynews.lk/2025/12/09/business/910735/rs-200000-to-be-provided-to-restart-industries-hit-by-cyclone-ditwah/
#     • Rapid stabilization of Ceylon Tea Industry post-Cyclone Ditwah
#       https://dailynews.lk/2025/12/12/business/913037/rapid-stabilization-of-ceylon-tea-industry-post-cyclone-ditwah/
#     • New loan schemes to assist SMEs hit by cyclone
#       https://dailynews.lk/2025/12/12/local/913384/new-loan-schemes-to-assist-smes-hit-by-cyclone/
#     • Food Security Committee meets at Presidential Secretariat
#       https://dailynews.lk/2025/12/12/business/913052/food-security-committee-meets-at-presidential-secretariat/
#     • Top corporates join hands with Govt. to revive industries affected by
#       https://dailynews.lk/2025/12/15/business/914388/top-corporates-join-hands-with-govt-to-revive-industries-affected-by-cyclone-ditwah/
#     • ComBank leads Sri Lanka’s SME lending for fifth consecutive year
#       https://dailynews.lk/2025/12/16/business/915116/combank-leads-sri-lankas-sme-lending-for-fifth-consecutive-year/
#     • Eighteen thousand businesses affected by Cyclone Ditwah
#       https://dailynews.lk/2025/12/16/local/915260/eighteen-thousand-businesses-affected-by-cyclone-ditwah/
#     • Rapid financial relief for disaster-affected businesses: Loan repaymen
#       https://dailynews.lk/2025/12/18/local/917300/rapid-financial-relief-for-disaster-affected-businesses-loan-repayment-periods-extended/
#     • Rapid Financial Relief for Disaster-Affected Businesses: Loan repaymen
#       https://dailynews.lk/2025/12/19/business/917826/rapid-financial-relief-for-disaster-affected-businesses-loan-repayment-periods-extended-2/
#     •
#       https://dailynews.lk/2025/12/22/local/919470/919470/
#     • Entrepreneurs urged to benefit from Rs 2 Bn relief assistance
#       https://dailynews.lk/2025/12/22/business/919097/entrepreneurs-urged-to-benefit-from-rs-2-bn-relief-assistance/
#     • 573 exporters adversely affected by cyclone Ditwah
#       https://dailynews.lk/2025/12/23/local/920248/573-exporters-adversely-affected-by-cyclone-ditwah/
#     • People’s Bank grants first loan to rehabilitate MSMEs affected by Cycl
#       https://dailynews.lk/2025/12/23/business/919905/peoples-bank-grants-first-loan-to-rehabilitate-msmes-affected-by-cyclone-ditwah/
#     • BOI intensifies engagement with affected enterprises
#       https://dailynews.lk/2025/12/23/business/919923/boi-intensifies-engagement-with-affected-enterprises/
#     • Govt. disburses Rs 106.2 Mn to 531 affected industrialists in first ph
#       https://dailynews.lk/2025/12/24/business/921009/govt-disburses-rs-106-2-mn-to-531-affected-industrialists-in-first-phase/
#     • JICA to provide technical assistance to small-scale entrepreneurs in N
#       https://dailynews.lk/2025/12/24/local/920827/jica-to-provide-technical-assistance-to-small-scale-entrepreneurs-in-ncp/
#     • BOI establishes 24-hour advisory and relief unit
#       https://dailynews.lk/2025/12/24/business/921039/boi-establishes-24-hour-advisory-and-relief-unit/
#     • MSME Chamber asks the Gov. for financial facilities at low interest ra
#       https://dailynews.lk/2025/12/29/business/922979/msme-chamber-asks-the-gov-for-financial-facilities-at-low-interest-rates/
#     • SME entrepreneurs request more days to register
#       https://dailynews.lk/2025/12/29/business/923047/sme-entrepreneurs-request-more-days-to-register/
#
#   Topic 5: indian, india, force, sagar bandhu, sagar, bandhu, operation sagar, operation sagar bandhu, operation, relief, air, army, air force, assistance, aircraft, medical, support, bridge, operations, indian army
#     • Cyclone Ditwah: PM Modi announces assistance under ‘Operation Sagar Ba
#       https://dailynews.lk/2025/12/01/local/905272/cyclone-ditwah-pm-modi-announces-assistance-under-operation-sagar-bandhu/
#     • India intensifies support to Sri Lanka under ‘Operation Sagar Bandhu’
#       https://dailynews.lk/2025/12/01/local/905567/india-intensifies-support-to-sri-lanka-under-operation-sagar-bandhu/
#     • India allows Pakistani aircraft to carry cyclone aid over its airspace
#       https://dailynews.lk/2025/12/02/local/906454/india-allows-pakistani-aircraft-to-carry-cyclone-aid-over-its-airspace-to-sri-lanka/
#     • India assists search and rescue efforts under Operation Sagar Bandhu
#       https://dailynews.lk/2025/12/02/local/906205/india-assists-search-and-rescue-efforts-under-operation-sagar-bandhu/
#     • India’s NDRF joins forces with SL to tackle cyclone devastation
#       https://dailynews.lk/2025/12/02/local/906348/indias-ndrf-joins-forces-with-sl-to-tackle-cyclone-devastation/
#     • India’s humanitarian assistance continues with Operation Sagar Bandhu
#       https://dailynews.lk/2025/12/03/local/907107/indias-humanitarian-assistance-continues-with-operation-sagar-bandhu/
#     • US donates fourth Coast Guard cutter to Sri Lanka Navy
#       https://dailynews.lk/2025/12/03/local/907526/us-donates-fourth-coast-guard-cutter-to-sri-lanka-navy/
#     • Indian relief flight arrives with Bailey bridge units and engineering
#       https://dailynews.lk/2025/12/04/local/908337/indian-relief-flight-arrives-with-bailey-bridge-units-and-engineering-teams/
#     • India extends timely assistance with medical team and essential suppli
#       https://dailynews.lk/2025/12/04/local/908120/india-extends-timely-assistance-with-medical-team-and-essential-supplies-to-sri-lanka/
#     • Indian relief flight arrives with Bailey bridge units
#       https://dailynews.lk/2025/12/05/breaking-news/908576/indian-relief-flight-arrives-with-bailey-bridge-units/
#     • Tamil Nadu dispatches 950 tonnes of aid for cyclone victims of Sri Lan
#       https://dailynews.lk/2025/12/06/local/909328/tamil-nadu-dispatches-300-tonnes-of-aid-for-cyclone-victims-of-sri-lanka/
#     • US Air Force C-130 aircraft arrive in Sri Lanka for relief operations
#       https://dailynews.lk/2025/12/07/local/909602/us-air-force-c-130-aircraft-arrive-in-sri-lanka-for-relief-operations/
#     • Indian Army’s Integrated Task Force to aid Sri Lanka
#       https://dailynews.lk/2025/12/08/local/910038/indian-armys-integrated-task-force-to-aid-sri-lanka/
#     • India delivers major relief shipment to Sri Lanka
#       https://dailynews.lk/2025/12/08/local/910983/india-delivers-major-relief-shipment-to-sri-lanka/
#     • Indian Air Force airlifts 65-tonne Bailey Bridge to Colombo
#       https://dailynews.lk/2025/12/08/local/909950/indian-air-force-airlifts-65-tonne-bailey-bridge-to-colombo/
#     • Two U.S. Air Force C-130J Super Hercules aircraft here
#       https://dailynews.lk/2025/12/08/photo-of-the-day/910051/two-u-s-air-force-c-130j-super-hercules-aircraft-here/
#     • India delivers 300 tonnes in humanitarian relief under Operation Sagar
#       https://dailynews.lk/2025/12/10/local/911403/india-delivers-300-tonnes-in-humanitarian-relief-under-operation-sagar-bandhu/
#     • US military deploys foreign disaster relief support to affected commun
#       https://dailynews.lk/2025/12/11/business/912218/us-military-deploys-foreign-disaster-relief-support-to-affected-communities/
#     • Indian Army team restores communication network in Mahiyanganaya, unde
#       https://dailynews.lk/2025/12/12/local/913162/indian-army-team-restores-communication-network-in-mahiyanganaya-under-operation-sagar-bandhu/
#     • Indian field hospital in Mahiyanganaya
#       https://dailynews.lk/2025/12/13/local/914008/indian-field-hospital-in-mahiyanganaya/
#     • Indian Army field hospital concludes its mission
#       https://dailynews.lk/2025/12/15/local/914696/indian-army-field-hospital-concludes-its-mission/
#     • India airlifts essential Medicines to Sri Lanka
#       https://dailynews.lk/2025/12/15/local/914589/india-airlifts-essential-medicines-to-sri-lanka/
#     • Lankan Army appreciates work of Indian Army Engineers in bridge-restor
#       https://dailynews.lk/2025/12/16/local/915588/lankan-army-appreciates-work-of-indian-army-engineers-in-bridge-restoration-in-jaffna/
#     • India delivers relief as Army Field Hospital concludes mission here
#       https://dailynews.lk/2025/12/17/local/916268/india-delivers-relief-as-army-field-hospital-concludes-mission-here/
#     • Army Engineers restore connectivity after Nayaru Bridge collapse
#       https://dailynews.lk/2025/12/18/local/917270/army-engineers-restore-connectivity-after-nayaru-bridge-collapse/
#
#   Topic 6: farmers, hectares, paddy, fields, damaged, paddy fields, fisheries, irrigation, rs, agriculture, sand, destroyed, livestock, 000, soil, losses, cultivation, maize, cyclone, mahaweli
#     • Water Resources Board begins cleaning flood damaged Wells
#       https://dailynews.lk/2025/12/04/local/908684/water-resources-board-begins-cleaning-flood-damaged-wells/
#     • Restoration of disaster-hit agricultural fields begins across Sri Lank
#       https://dailynews.lk/2025/12/07/local/909623/restoration-of-disaster-hit-agricultural-fields-begins-across-sri-lanka-with-gsmb-approval/
#     • GSMB permits Mahaweli Authority to remove sand accumulated in paddy fi
#       https://dailynews.lk/2025/12/08/local/910029/gsmb-permits-mahaweli-authority-to-remove-sand-accumulated-in-paddy-fields-after-deluge/
#     • Irrigation Department works to restore water supply for agriculture
#       https://dailynews.lk/2025/12/08/local/910220/irrigation-department-works-to-restore-water-supply-for-agriculture/
#     • Fisheries Minister inspects flood-hit shrimp farms in Puttalam
#       https://dailynews.lk/2025/12/08/local/910041/fisheries-minister-inspects-flood-hit-shrimp-farms-in-puttalam/
#     • Farmers to be compensated for loss of crops
#       https://dailynews.lk/2025/12/09/breaking-news/910931/farmers-to-be-compensated-for-loss-of-crops/
#     • Expert warns against dumping soil from landslides near waterways
#       https://dailynews.lk/2025/12/11/local/912551/expert-warns-against-dumping-soil-from-landslides-near-waterways/
#     • ‘Ninety-five thousand hectares of damaged paddy fields can be replante
#       https://dailynews.lk/2025/12/15/local/914556/ninety-five-thousand-hectares-of-damaged-paddy-fields-can-be-replanted/
#     • Uma Ela anicut damaged by Cyclone nears restoration
#       https://dailynews.lk/2025/12/16/local/915401/uma-ela-anicut-damaged-by-cyclone-nears-restoration/
#     • Government grants special leave to officials affected by floods and la
#       https://dailynews.lk/2025/12/16/local/915778/government-grants-special-leave-to-officials-affected-by-floods-and-landslide/
#     • Rebuilding damaged irrigation systems
#       https://dailynews.lk/2025/12/18/photo-of-the-day/917331/rebuilding-damaged-irrigation-systems/
#     • Cyclone destroyed over 106,800 hectares of paddy- Minister
#       https://dailynews.lk/2025/12/20/breaking-news/918714/cyclone-destroyed-over-106800-hectares-of-paddy-minister/
#     • Fisheries sector losses from cyclone estimated at Rs.8 Bn
#       https://dailynews.lk/2025/12/24/local/921190/fisheries-sector-losses-from-cyclone-estimated-at-rs-8-bn/
#     • Over Rs. 20 Bn damages from cyclone Ditwah in fisheries sector
#       https://dailynews.lk/2025/12/25/breaking-news/921850/over-rs-20-bn-damages-from-cyclone-ditwah-in-fisheries-sector/
#     • Govt. provides over Rs. 381Mn as special compensation to disaster-affe
#       https://dailynews.lk/2025/12/29/local/923199/govt-provides-over-rs-381mn-as-special-compensation-to-disaster-affected-farmers/
#     • NLDB to promote unique Sri Lankan coffee variety to tourists
#       https://dailynews.lk/2025/12/30/local/924263/nldb-to-promote-unique-sri-lankan-coffee-variety-to-tourists/
#     • Farmers and fishermen displaced by Ditwah given till January 31, to co
#       https://dailynews.lk/2025/12/30/local/924118/farmers-and-fishermen-displaced-by-ditwah-given-till-january-31-to-collect-december-pension/
#
#   Topic 7: schools, education, school, students, district, prime minister, prime, minister, colombo district, december, education ministry, ministry, 16, reopen, colombo, january, steps, dr harini, teachers, stated
#     • Remaining GCE A/Level Exams in January
#       https://dailynews.lk/2025/12/03/local/907094/remaining-gce-a-level-exams-in-january/
#     • Over 150 schools in CP affected by cyclone
#       https://dailynews.lk/2025/12/05/local/908616/over-150-schools-in-cp-affected-by-cyclone/
#     • Cyclone Ditwah damages nearly 1,000 Schools
#       https://dailynews.lk/2025/12/08/local/910123/cyclone-ditwah-damages-nearly-1000-schools/
#     • No more unauthorized constructions in Colombo – PM
#       https://dailynews.lk/2025/12/10/local/911925/no-more-unauthorized-constructions-in-colombo-pm/
#     • Remaining A/L Exam subjects from January 12 to 20
#       https://dailynews.lk/2025/12/10/breaking-news/911655/remaining-a-l-exam-subjects-from-january-12-to-20/
#     • Will not allow unauthorised constructions in Colombo District- PM
#       https://dailynews.lk/2025/12/11/local/912410/will-not-allow-unauthorised-constructions-in-colombo-district-pm/
#     • Education Ministry strengthens E-Thaksalawa digital learning platform
#       https://dailynews.lk/2025/12/11/local/912770/education-ministry-strengthens-e-thaksalawa-digital-learning-platform/
#     • “Prathishta” program launched to rebuild Schools damaged by Cyclone Di
#       https://dailynews.lk/2025/12/12/local/913685/prathishtha-program-launched-to-rebuild-schools-damaged-by-cyclone-ditwah/
#     • Education should not be a burden to cyclone-hit children – PM
#       https://dailynews.lk/2025/12/15/local/914640/education-should-not-be-a-burden-to-cyclone-hit-children-pm/
#     • Education: The post-Ditwah scenario
#       https://dailynews.lk/2025/12/15/editorial/914458/education-the-post-ditwah-scenario/
#     • Most schools will reopen today
#       https://dailynews.lk/2025/12/16/breaking-news/915553/most-schools-will-reopen-today/
#     • Schools in six provinces reopen
#       https://dailynews.lk/2025/12/17/local/916223/schools-in-six-provinces-reopen/
#     • 1,382 schools directly affected by Ditwah mostly in Central, Uva and S
#       https://dailynews.lk/2025/12/20/local/918583/1382-schools-directly-affected-by-ditwah-mostly-in-central-uva-and-sabaragamuwa-provinces-pm-dr-harini-amarasooriya/
#     • Construction in Hatton-Dickoya UC limits halted after cyclone
#       https://dailynews.lk/2025/12/23/local/920217/construction-in-hatton-dickoya-uc-limits-halted-after-cyclone/
#     • Steps underway to relocate schools in high-risk areas, PM says
#       https://dailynews.lk/2025/12/24/local/921655/steps-underway-to-relocate-schools-in-high-risk-areas-pm-says/
#     • Candidates must report address changes for A/L Exams – Exams Dept
#       https://dailynews.lk/2025/12/24/local/920947/candidates-must-report-address-changes-for-a-l-exams-exams-dept/
#     • Schools in risk prone areas will be relocated to safe locations – PM
#       https://dailynews.lk/2025/12/25/local/921836/schools-in-risk-prone-areas-will-be-relocated-to-safe-locations-pm/
#
#   Topic 8: road, nuwara, eliya, nuwara eliya, roads, damaged, nuwara eliya district, eliya district, officials, president, rda, district, repair, train, railway, road development, bridges, road development authority, development authority, development
#     • President declares state of emergency
#       https://dailynews.lk/2025/11/29/local/904848/president-declares-state-of-emergency/
#     • Free travel period ends; Expressway tolls back in effect
#       https://dailynews.lk/2025/12/04/local/908114/free-travel-period-ends-expressway-tolls-back-in-effect/
#     • ‘Prioritize restoration of damaged road networks’ – Prez
#       https://dailynews.lk/2025/12/04/local/908468/prioritize-restoration-of-damaged-road-networks-prez/
#     • Sustainable solutions needed – President
#       https://dailynews.lk/2025/12/05/local/908579/sustainable-solutions-needed-president/
#     • All access roads to Nuwara Eliya reopened after Cyclone Ditwah
#       https://dailynews.lk/2025/12/07/local/909524/all-access-roads-to-nuwara-eliya-reopened-after-cyclone-ditwah/
#     • RDA to open all cyclone hit roads this week
#       https://dailynews.lk/2025/12/08/local/909982/rda-to-open-all-cyclone-hit-roads-this-week/
#     • President calls for urgent road restoration in Nuwara Eliya
#       https://dailynews.lk/2025/12/08/local/910263/president-calls-for-urgent-road-restoration-in-nuwara-eliya/
#     • President visits Nuwara Eliya and Badulla
#       https://dailynews.lk/2025/12/09/local/910968/president-visits-nuwara-eliya-and-badulla/
#     • President chairs Nuwara Eliya District Coordinating Committee meeting
#       https://dailynews.lk/2025/12/09/local/910791/president-chairs-nuwara-eliya-district-coordinating-committee-meeting/
#     • Ganesan seeks meeting with President
#       https://dailynews.lk/2025/12/15/politics/914770/ganesan-seeks-meeting-with-president/
#     • Landslide-hit Nawalapitiya Kandy road reopened after 18 days
#       https://dailynews.lk/2025/12/15/local/914920/landslide-hit-nawalapitiya-kandy-road-reopened-after-18-days/
#     • ‘road-lk.org’ gives real-time condition of roads
#       https://dailynews.lk/2025/12/16/local/915580/road-lk-org-gives-real-time-condition-of-roads/
#     • Damaged Nayawala Bridge to be repaired
#       https://dailynews.lk/2025/12/17/local/916301/damaged-nayawala-bridge-to-be-repaired/
#     • Trains to N-E to resume on January 1
#       https://dailynews.lk/2025/12/19/local/918039/trains-to-n-e-to-resume-on-january-1/
#     • Train services resume on Upcountry, North, East lines
#       https://dailynews.lk/2025/12/22/photo-of-the-day/919476/train-services-resume-on-upcountry-north-east-lines/
#     • Nuwara Eliya ready to welcome visitors now – Mayor
#       https://dailynews.lk/2025/12/27/breaking-news/922635/nuwara-eliya-ready-to-welcome-visitors-now-mayor/
#     • Presidential Task Force appointed to lead post-Cyclone Ditwah recovery
#       https://dailynews.lk/2025/12/31/breaking-news/925729/presidential-task-force-appointed-to-lead-post-cyclone-ditwah-recovery/
#
#   Topic 9: showers, north, provinces, western, occur, central, strong winds, expected, winds, mm, likely, thundershowers, northern, heavy, western provinces, northern north central, areas, northern north, north central, places
#     • Deep depression near Sri Lanka upgraded to cyclone ‘Ditwah’
#       https://dailynews.lk/2025/11/27/breaking-news/903683/deep-depression-near-sri-lanka-upgraded-to-cyclone-ditwah/
#     • Cyclone ‘Ditwa’ moves closer to Sri Lanka’s east coast
#       https://dailynews.lk/2025/11/28/local/903976/cyclone-ditwa-moves-closer-to-sri-lankas-east-coast/
#     • Cyclone “Ditwah” intensifies; heavy rain and strong winds to persist a
#       https://dailynews.lk/2025/11/28/local/904000/cyclone-ditwah-intensifies-heavy-rain-and-strong-winds-to-persist-across-sri-lanka/
#     • Heavy showers, strong winds to continue
#       https://dailynews.lk/2025/11/28/local/903886/heavy-showers-strong-winds-to-continue/
#     • Cyclone “Ditwah” moves towards India as Sri Lanka warned of heavy show
#       https://dailynews.lk/2025/11/29/local/904646/cyclone-ditwah-near-trinco-strong-winds-and-heavy-rain-forecast-across-several-provinces/
#     • Cyclone moves away, but weather threats continue – Met Dept issues fre
#       https://dailynews.lk/2025/11/29/local/904815/cyclone-moves-away-but-weather-threats-continue-met-dept-issues-fresh-warning/
#     • More showers over 200 mm expected today
#       https://dailynews.lk/2025/11/29/breaking-news/904541/more-showers-over-200-mm-expected-today/
#     • Cyclone Ditwah moving towards Tamil Nadu; rainfall to ease in Sri Lank
#       https://dailynews.lk/2025/11/29/local/904948/cyclone-ditwah-moving-towards-tamil-nadu-rainfall-to-ease-in-sri-lanka/
#     • Weather Update: Sri Lanka Tonight and Tomorrow
#       https://dailynews.lk/2025/11/29/local/904863/weather-update-sri-lanka-tonight-and-tomorrow/
#     • Cyclone “Ditwah” shifts north of Jaffna as rainfall gradually reduces
#       https://dailynews.lk/2025/11/30/local/904955/cyclone-ditwah-shifts-north-of-jaffna-as-rainfall-gradually-reduces/
#     • Ditwah likely to move away from SL today
#       https://dailynews.lk/2025/12/01/local/905592/ditwah-likely-to-move-away-from-sl-today/
#     • Refrain from returning home at this time – Met DG
#       https://dailynews.lk/2025/12/01/breaking-news/905661/refrain-from-returning-home-at-this-time-met-dg/
#     • More showers expected, landslide warning for areas in four districts
# ...
#       http://island.lk/sri-lankan-economy-still-vulnerable-imf/
#
#   Topic 6: missing, dmc, dead, district, families, kandy, centres, deaths, said, management centre dmc, centre dmc, reported, persons, nbro, eliya, nuwara eliya, nuwara, disaster, disaster management centre, districts
#     • Cyclone Ditwah: 355 deaths, 366 missing as at 9 am Monday
#       http://island.lk/cyclone-ditwah-355-deaths-366-missing-as-at-9-am-monday/
#     • Cyclone death toll crosses 410
#       http://island.lk/cyclone-death-toll-crosses-410/
#     • DMC: 474 dead and 356 missing
#       http://island.lk/dmc-474-dead-and-356-missing/
#     • CEB worker dies restoring power
#       http://island.lk/ceb-worker-dies-restoring-power/
#     • New landslide alerts as Ditwah aftermath worsens
#       http://island.lk/new-landslide-alerts-as-ditwah-aftermath-worsens/
#     • Disaster: 635 bodies found so far, 192 listed as missing
#       http://island.lk/disaster-635-bodies-found-so-far-192-listed-as-missing/
#     • Disaster death toll rises to 638
#       http://island.lk/disaster-death-toll-rises-to-638/
#     • Ditwah Disaster: 211 people still missing
#       http://island.lk/ditwah-disaster-211-people-still-missing/
#     • Cyclone Ditwah: 643 dead, 184 missing
#       http://island.lk/cyclone-ditwah-643-dead-184-missing/
#     • Bulk of disaster displaced centres in Kandy
#       http://island.lk/bulk-of-disaster-displaced-centres-in-kandy/
#     • NBRO identifies landslide risks in 14 districts
#       http://island.lk/nbro-identifies-landslide-risks-in-14-districts/
#
#   Topic 7: government, said, disaster, opposition, budget, 2026, parliament, budget 2026, premadasa, sjb, electricity, cyclone, consumers, revenue, said government, leader, expenditure, yesterday, freedom, act
#     • Opposition stages walkout in Parliament, claiming govt. ignored cyclon
#       http://island.lk/opposition-stages-walkout-in-parliament-claiming-govt-ignored-cyclone-warning/
#     • Govt. urged to suspend parate executions
#       http://island.lk/govt-urged-to-suspend-parate-executions/
#     • Cyclone: SLPP calls for PSC on govt.’s failure to take precautions
#       http://island.lk/cyclone-slpp-calls-for-psc-on-govt-s-failure-to-take-precautions/
#     • Sajith asks govt. to withdraw Budget 2026, present fresh one
#       http://island.lk/sajith-asks-govt-to-withdraw-budget-2026-present-fresh-one/
#     • Cyclone-hit budget
#       http://island.lk/cyclone-hit-budget/
#     • Opposition blames govt. inaction for severity of disaster impact
#       http://island.lk/opposition-blames-govt-inaction-for-severity-of-disaster-impact/
#     • IFJ urges Lanka to protect freedom of expression amid emergency law co
#       http://island.lk/ifj-urges-lanka-to-protect-freedom-of-expression-amid-emergency-law-concerns/
#     • Parliament to have special sitting to approve emergency funding
#       http://island.lk/parliament-to-have-special-sitting-to-approve-emergency-funding/
#     • Sajith: Met Dept. officials under virtual house arrest
#       http://island.lk/sajith-met-dept-officials-under-virtual-house-arrest/
#     • Electricity consumers oppose going to WB to cover CEB losses from Ditw
#       http://island.lk/electricity-consumers-oppose-going-to-wb-to-cover-ceb-losses-from-ditwah-instead-of-using-funds-in-its-kitty/
#     • Lawyer petitions SC accusing authorities of failing to take preventive
#       http://island.lk/lawyer-petitions-sc-accusing-authorities-of-failing-to-take-preventive-measures-to-minimise-impact-of-cyclone-ditwah/
#
#   Topic 8: said, people, indonesia, worst, floods, 000, aceh, water, dmc, missing, flood, flooding, house, dmc said, waters, areas, killed, toll, rains, slaf
#     • Country reels under worst weather in living memory
#       http://island.lk/country-reels-under-worst-weather-in-living-memory/
#     • ‘Neighbourhoods buried under mud’: Sri Lanka floods death toll reaches
#       http://island.lk/neighbourhoods-buried-under-mud-sri-lanka-floods-death-toll-reaches-334/
#     • Flooding across Asia leaves 600 dead and hundreds missing
#       http://island.lk/flooding-across-asia-leaves-600-dead-and-hundreds-missing/
#     • Lanka deploys troops as floodwaters rise, death toll hits 69
#       http://island.lk/lanka-deploys-troops-as-floodwaters-rise-death-toll-hits-69/
#     • SLAF warns against unauthorised drone operations over cyclone-hit area
#       http://island.lk/slaf-warns-against-unauthorised-drone-operations-over-cyclone-hit-areas/
#     • Death toll in Indonesia floods passes 500
#       http://island.lk/death-toll-in-indonesia-floods-passes-500/
#     • Cyclone catastrophe in Sri Lanka awakens volunteer spirit
#       http://island.lk/cyclone-catastrophe-in-sri-lanka-awakens-volunteer-spirit/
#     • Lunuwila tragedy not caused by those videoing Bell 212: SLAF
#       http://island.lk/lunuwila-tragedy-not-caused-by-those-videoing-bell-212-slaf/
#     • Heavy rains hamper recovery as death toll from floods in Asia exceeds
#       http://island.lk/heavy-rains-hamper-recovery-as-death-toll-from-floods-in-asia-exceeds-1750/
#     • Defying the eye of storm: A priest steers his community to safety
#       http://island.lk/defying-the-eye-of-storm-a-priest-steers-his-community-to-safety/
#
#   Topic 9: president, minister, district, prime minister, prime, religious, stated, officials, instructed, officers, export, entrusted, kumara, ministry, anura, army, disaster, secretary, compensation, government
#     • Keep the public continuously informed by releasing updated weather and
#       http://island.lk/keep-the-public-continuously-informed-by-releasing-updated-weather-and-disaster-information-to-the-media-president/
#     • President chairs Nuwara Eliya District Special Coordinating Committee
#       http://island.lk/president-chairs-nuwara-eliya-district-special-coordinating-committee-meeting/
#     • “We cannot allow flooding to become a part of the daily lives of the p
#       http://island.lk/we-cannot-allow-flooding-to-become-a-part-of-the-daily-lives-of-the-people-in-the-colombo-district-pm/
#     • The government is taking steps to streamline trade facilitation, custo
#       http://island.lk/he-government-is-taking-steps-to-streamline-trade-facilitation-customs-processes-investment-approvals-and-improving-export-facilities-prime-minister/
#     • Prioritize rebuilding the livelihoods of disaster-affected communities
#       http://island.lk/prioritize-rebuilding-the-livelihoods-of-disaster-affected-communities-president/
#     • “The future needs leaders who can adapt, learn, and respond to change
#       http://island.lk/the-future-needs-leaders-who-can-adapt-learn-and-respond-to-change-without-losing-ethical-direction-prime-minister/
#     • Swift restoration of Religious, Cultural and Archaeological sites dama
#       http://island.lk/swift-restoration-of-religious-cultural-and-archaeological-sites-damaged-by-the-disaster/
#     • National progress can be achieved only when everyone fulfills the resp
#       http://island.lk/national-progress-can-be-achieved-only-when-everyone-fulfills-the-responsibilities-entrusted-to-them-with-steadfast-determination-unity-of-purpose-and-resilience-in-the-face-of-any-challenge-presid/
#     • Steps are being taken to relocate schools in risk prone Areas to Safe
#       http://island.lk/steps-are-being-taken-to-relocate-schools-in-risk-prone-areas-to-safe-locations-prime-minister/
#     • Lanka to observe National Safety Day today
#       http://island.lk/lanka-to-observe-national-safety-day-today/
#
#   Topic 10: tourism, tea, travellers, confidence, tourist, safe, year, travel, international, srilankan airlines, srilankan, industry, airlines, cyclone, 2025, port, christmas, market, ready, ditwah
#     • ABBA scene in Doha … Ishini in the spotlight
#       http://island.lk/abba-scene-in-doha-ishini-in-the-spotlight/
#     • Tourist Board reassures: Sri Lanka safe, open and ready
#       http://island.lk/tourist-board-reassures-sri-lanka-safe-open-and-ready/
#     • H’tota Port: Maiden visit of mega cruise ship Mein Schiff 6
#       http://island.lk/htota-port-maiden-visit-of-mega-cruise-ship-mein-schiff-6/
#     • Suzi … missing Sri Lanka
#       http://island.lk/suzi-missing-sri-lanka/
#     • Tourist arrivals satisfactory – SLTDA
#       http://island.lk/tourist-arrivals-satisfactory-sltda/
#     • SriLankan Airlines leads digital push to rebuild tourist confidence af
#       http://island.lk/srilankan-airlines-leads-digital-push-to-rebuild-tourist-confidence-after-cyclone/
#     • Tea market grappling with headwinds as 2025 comes to an end
#       http://island.lk/tea-market-grappling-with-headwinds-as-2025-comes-to-an-end/
#     • Post-Ditwah tourism: Govt. to retain UK interest in SL as key destinat
#       http://island.lk/post-ditwah-tourism-govt-to-retain-uk-interest-in-sl-as-key-destination/
#     • ‘Tea industry largely spared cyclone damage’
#       http://island.lk/tea-industry-largely-spared-cyclone-damage/
#     • Sri Lanka Tourism surpasses historic milestone with record tourist arr
#       http://island.lk/sri-lanka-tourism-surpasses-historic-milestone-with-record-tourist-arrivals-in-2025/
#
#   Topic 11: china, secretary, delegation, unesco, ambassador, committee, support, holy, president, chinese, assistance, relations, chairman, dr, meeting, lawmakers, visit, secretary president, vice, affected
#     • Delegation from Singapore and Malaysia Meets President’s Secretary
#       http://island.lk/delegation-from-singapore-and-malaysia-meets-presidents-secretary/
#     • On behalf of Lanka,US lawmakers appeal to Secretary of State
#       http://island.lk/on-behalf-of-lankaus-lawmakers-appeal-to-secretary-of-state/
#     • French Ambassador pledges support for relief efforts
#       http://island.lk/french-ambassador-pledges-support-for-relief-efforts/
#     • Opposition Leader discusses with Russian Ambassador more emergency rel
#       http://island.lk/opposition-leader-discusses-with-russian-ambassador-more-emergency-relief/
#     • China pledges full support for Lanka’s recovery
#       http://island.lk/china-pledges-full-support-for-lankas-recovery/
#     • Pope fires broadside: ‘The Holy See won’t be a silent bystander to the
#       http://island.lk/pope-fires-broadside-the-holy-see-wont-be-a-silent-bystander-to-the-grave-disparities-injustices-and-fundamental-human-rights-violations/
#     • China pledges support as Lanka recovers from cyclone
#       http://island.lk/china-pledges-support-as-lanka-recovers-from-cyclone/
#     • Govt. seeks emergency assistance from UNESCO
#       http://island.lk/govt-seeks-emergency-assistance-from-unesco/
#     • CPC delegation meets JVP leadership in Colombo
#       http://island.lk/cpc-delegation-meets-jvp-leadership-in-colombo/
#
#   Topic 12: government, opposition, political, disaster, npp, warnings, victims, jvp, floods, unp, country, power, disasters, weather, politicians, leaders, yahapalana, attacks, disaster victims, economy
#     • Elusive unity in crisis
#       http://island.lk/elusive-unity-in-crisis/
#     • Politics of disaster and disaster of politics
#       http://island.lk/politics-of-disaster-and-disaster-of-politics/
#     • Relief and reality
#       http://island.lk/relief-and-reality/
#     • National tragedies and absurd sideshows
#       http://island.lk/national-tragedies-and-absurd-sideshows/
#     • Experience vs. Inexperience
#       http://island.lk/experience-vs-inexperience/
#     • The reality facing Sri Lankans, govt. and Opposition
#       http://island.lk/the-reality-facing-sri-lankans-govt-and-opposition/
#     • Misplaced priorities
#       http://island.lk/misplaced-priorities-2/
#     • Desperate political sandbagging
#       http://island.lk/desperate-political-sandbagging/
#
#   Topic 13: km, railway, officials, rail, polonnaruwa, wildlife, elephant, road, damaged, electric, committee, cyclone, kandy, roads, ditwah, informed, network, garden, trace, services
#     • Only one-third of railway network operational
#       http://island.lk/only-one-third-of-railway-network-operational/
#     • SL Railways suffers staggering losses; more than 2/3 of rail tracks ou
#       http://island.lk/sl-railways-suffers-staggering-losses-more-than-2-3-of-rail-tracks-out-of-service/
#     • Post-Ditwah recovery efforts: Rs. 190 bn needed to restore roads and b
#       http://island.lk/post-ditwah-recovery-efforts-rs-190-bn-needed-to-restore-roads-and-bridges-countrywide/
#     • 200 km of the 340 km of damaged electric fences in the Polonnaruwa Wil
#       http://island.lk/200-km-of-the-340-km-of-damaged-electric-fences-in-the-polonnaruwa-wildlife-zone-reactivated/
#     • 200 km of damaged elephant fences in Polonnaruwa reactivated; urgent r
#       http://island.lk/200-km-of-damaged-elephant-fences-in-polonnaruwa-reactivated-urgent-repairs-underway-this-week/
#     • Cyclone-damaged Hakgala Botanical Garden reopened with safety measures
#       http://island.lk/cyclone-damaged-hakgala-botanical-garden-reopened-with-safety-measures/
#     • In the wake of Cyclone Ditwah SLSTL, IESL call for high-capacity rail
#       http://island.lk/in-the-wake-of-cyclone-ditwah-slstl-iesl-call-for-high-capacity-rail-corridor-to-kandy/
#     • Colombo-Puttalam railway line restored
#       http://island.lk/colombo-puttalam-railway-line-restored/
#
#   Topic 14: government, national, disaster, relief, international, economic, victims, crisis, political, country, corruption, parallel, civil, assistance, society, president, donor, needs, funds, civil society
#     • A national and international partnership catalysed by a national trage
#       http://island.lk/a-national-and-international-partnership-catalysed-by-a-national-tragedy/
#     • Disaster, relief, and challenges
#       http://island.lk/disaster-relief-and-challenges/
#     • Rebuilding Sri Lanka for the long term
#       http://island.lk/rebuilding-sri-lanka-for-the-long-term/
#     • Flood Relief Should Help Victims, Not Bureaucracies
#       http://island.lk/flood-relief-should-help-victims-not-bureaucracies/
#     • Rebuilding Sri Lanka Through Inclusive Governance
#       http://island.lk/rebuilding-sri-lanka-through-inclusive-governance/
#
#   Topic 15: mobitel, slt mobitel, slt, access, network, users, connectivity, medical, restoration, national, public, company, service, guide, services, tours, fibre, 247, blue, information
#     • SLT-MOBITEL launches free ‘247 Helpline’ to support flood-affected com
#       http://island.lk/slt-mobitel-launches-free-247-helpline-to-support-flood-affected-communities/
#     • TikTok launches guide to combat misinformation during floods in Sri La
#       http://island.lk/tiktok-launches-guide-to-combat-misinformation-during-floods-in-sri-lanka/
#     • Blue Lanka Tours donates motorboats to aid flood relief efforts
#       http://island.lk/blue-lanka-tours-donates-motorboats-to-aid-flood-relief-efforts/
#     • CERT issues alert on sharp jump in online scams
#       http://island.lk/cert-issues-alert-on-sharp-jump-in-online-scams/
#     • Leading the Nation’s Connectivity Recovery Amid Unprecedented Challeng
#       http://island.lk/leading-the-nations-connectivity-recovery-amid-unprecedented-challenges/
#
#   Topic 16: npp, government, jvp, president, dissanayake, wickremesinghe, opposition, leader, unp, political, india, premadasa, jvp npp, sajith, rajapaksa, police, parliament, party, ranwala, president dissanayake
#     • Maha Jana Handa at Nugegoda, cyclone destruction, and contenders posit
#       http://island.lk/maha-jana-handa-at-nugegoda-cyclone-destruction-and-contenders-positioning-for-power-in-post-npp-sri-lanka-i/
#     • The Maha Jana Handa at Nugegoda, cyclone destruction, and contenders p
#       http://island.lk/the-maha-jana-handa-at-nugegoda-cyclone-destruction-and-contenders-positioning-for-power-in-post-npp-sri-lanka-ii/
#     • Cops as whipping boys?
#       http://island.lk/cops-as-whipping-boys/
#     • Year ends with the NPP govt. on the back foot
#       http://island.lk/year-ends-with-the-npp-govt-on-the-back-foot/
#     • Digambaram draws a broad brush canvas of SL’s existing political situa
#       http://island.lk/digambaram-draws-a-broad-brush-canvas-of-sls-existing-political-situation/

# %% [markdown]
# ## 3b. LLM Aspect Labelling
#
# For each outlet, select the top 15 topics by article count, extract keywords and representative
# articles, then use an LLM to generate a short aspect label (2-5 words) and description per topic.
# This makes cross-outlet comparisons and visualizations much more readable.

# %%
# Extract topic details per outlet for LLM labelling
outlet_topic_details = {}

for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    r = outlet_results[outlet]
    ti = r['topic_info']

    # Select top N_TOPICS by article count (excluding outliers)
    top_topics = (
        ti[ti['Topic'] != -1]
        .sort_values('Count', ascending=False)
        .head(N_TOPICS)
    )

    topics_arr = np.array(r['topics'])
    probs_arr = np.array(r['probs']) if r['probs'] is not None else None

    details = []
    for _, row in top_topics.iterrows():
        tid = row['Topic']

        # Get keywords with scores
        words = r['model'].get_topic(tid)
        keywords = [(w, float(s)) for w, s in words[:KEYWORD_TOP_N]] if words else []

        # Get articles assigned to this topic, sorted by probability
        mask = topics_arr == tid
        indices = np.where(mask)[0]

        if probs_arr is not None and probs_arr.ndim == 2 and probs_arr.shape[1] > 0:
            topic_ids_sorted = sorted(set(r['topics']) - {-1})
            if tid in topic_ids_sorted:
                col_idx = topic_ids_sorted.index(tid)
                topic_probs = probs_arr[indices, col_idx] if col_idx < probs_arr.shape[1] else np.ones(len(indices))
            else:
                topic_probs = np.ones(len(indices))
            sorted_order = np.argsort(-topic_probs)
        elif probs_arr is not None and probs_arr.ndim == 1:
            topic_probs = probs_arr[indices]
            sorted_order = np.argsort(-topic_probs)
        else:
            sorted_order = np.arange(len(indices))

        top_indices = indices[sorted_order[:TOP_ARTICLES]]

        rep_articles = []
        for idx in top_indices:
            rep_articles.append({
                'article_id': r['article_ids'][idx],
                'title': outlet_data[outlet]['titles'][idx],
                'excerpt': outlet_data[outlet]['contents'][idx][:500],
            })

        details.append({
            'topic_id': tid,
            'article_count': int(row['Count']),
            'keywords': keywords,
            'representative_articles': rep_articles,
        })

    outlet_topic_details[outlet] = details
    print(f"{name}: extracted details for {len(details)} topics")

print(f"\nTotal topics to label: {sum(len(d) for d in outlet_topic_details.values())}")
# Out:
# Daily News: extracted details for 15 topics
# The Morning: extracted details for 15 topics
# Daily FT: extracted details for 15 topics
# The Island: extracted details for 15 topics
#
# Total topics to label: 60

# %%
# LLM aspect labelling per outlet
llm = get_llm()
print(f"LLM loaded: {llm.model} ({type(llm).__name__})")

SYSTEM_PROMPT = """You are an expert media analyst studying how Sri Lankan English newspapers covered \
Cyclone Ditwah (November 2025 - December 2025). The cyclone caused significant damage in Sri Lanka, \
triggering government response, international aid, and extensive media coverage across multiple outlets.

You are analysing topics discovered by BERTopic from a single outlet's coverage (~300-500 articles). \
For each topic, you will receive its top keywords (with importance scores) and representative \
article titles and excerpts.

Your task is to identify what specific aspect of the Ditwah cyclone event this topic captures."""

outlet_llm_labels = {}   # outlet -> list of result dicts
aspect_lookup = {}       # (outlet, tid) -> aspect string

for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    details = outlet_topic_details[outlet]
    print(f"\n{'='*60}")
    print(f"  Labelling {name} ({len(details)} topics)")
    print(f"{'='*60}")

    results = []
    for i, d in enumerate(details):
        print(f"  Topic {d['topic_id']} ({i+1}/{len(details)})...", end=' ')

        # Build keyword section
        kw_lines = [f"  {w} (score: {s:.4f})" for w, s in d['keywords']]
        kw_section = "\n".join(kw_lines)

        # Build articles section
        art_lines = []
        for j, art in enumerate(d['representative_articles'], 1):
            art_lines.append(f"  Article {j}:")
            art_lines.append(f"    Title: {art['title']}")
            art_lines.append(f"    Excerpt: {art['excerpt'][:400]}")
        art_section = "\n".join(art_lines)

        prompt = f"""Below is a topic discovered from {name}'s coverage of Cyclone Ditwah.

TOPIC {d['topic_id']} ({d['article_count']} articles)

Top {KEYWORD_TOP_N} keywords (with BERTopic importance scores):
{kw_section}

Top {len(d['representative_articles'])} representative articles:
{art_section}

Based on the keywords and articles above, provide:
1. A short aspect phrase (2-5 words) that captures what this topic is about
2. A 1-2 sentence description explaining what this topic covers in the context of Cyclone Ditwah coverage

Respond with JSON in this exact format:
{{"aspect": "short phrase here", "description": "1-2 sentence description here"}}"""

        try:
            response = llm.generate(prompt, system_prompt=SYSTEM_PROMPT, json_mode=True)
            result = json.loads(response.content)
            aspect = result.get('aspect', 'Unknown')
            description = result.get('description', '')
            print(f"-> {aspect}")
        except Exception as e:
            print(f"LLM error: {e}")
            aspect = ', '.join(w for w, _ in d['keywords'][:3])
            description = f"Topic characterised by keywords: {', '.join(w for w, _ in d['keywords'][:8])}"
            print(f"  Fallback: {aspect}")

        aspect_lookup[(outlet, d['topic_id'])] = aspect
        results.append({
            'topic_id': d['topic_id'],
            'aspect': aspect,
            'description': description,
            'article_count': d['article_count'],
            'keywords': d['keywords'],
        })

    outlet_llm_labels[outlet] = results

    # Display results table for this outlet
    rows = [{'Topic': r['topic_id'], 'Aspect': r['aspect'], 'Articles': r['article_count'],
             'Description': r['description']} for r in results]
    display(pd.DataFrame(rows))

print(f"\nAll outlets labelled. Total labels: {len(aspect_lookup)}")
# Out:
# LLM loaded: gpt-4o (OpenAILLM)
#
# ============================================================
#   Labelling Daily News (15 topics)
# ============================================================
#   Topic 0 (1/15)...
# -> Climate Impact and Response
#   Topic 1 (2/15)... -> Rebuilding Sri Lanka Fund
#   Topic 2 (3/15)... -> Government response and budget
#   Topic 3 (4/15)... -> Casualties and Damage Assessment
#   Topic 4 (5/15)... -> Industry Recovery Efforts
#   Topic 5 (6/15)... -> Indian humanitarian assistance
#   Topic 6 (7/15)... -> Agricultural damage and recovery
#   Topic 7 (8/15)... -> Impact on education sector
#   Topic 8 (9/15)... -> Road and Transport Restoration
#   Topic 9 (10/15)... -> Weather impacts and forecasts
#   Topic 10 (11/15)... -> Tourism and Recovery Efforts
#   Topic 11 (12/15)... -> International financial aid
#   Topic 12 (13/15)... -> Opposition's response to cyclone
#   Topic 13 (14/15)... -> Regional impact in Southeast Asia
#   Topic 14 (15/15)... -> International aid response
#     Topic                             Aspect  Articles  \
# 0       0        Climate Impact and Response        58
# 1       1          Rebuilding Sri Lanka Fund        35
# 2       2     Government response and budget        33
# 3       3   Casualties and Damage Assessment        27
# 4       4          Industry Recovery Efforts        26
# 5       5     Indian humanitarian assistance        25
# 6       6   Agricultural damage and recovery        17
# 7       7         Impact on education sector        17
# 8       8     Road and Transport Restoration        17
# 9       9      Weather impacts and forecasts        16
# 10     10       Tourism and Recovery Efforts        16
# 11     11        International financial aid        15
# 12     12   Opposition's response to cyclone        13
# 13     13  Regional impact in Southeast Asia        12
# 14     14         International aid response        12
#
#                                           Description
# 0   This topic covers the broader implications of ...
# 1   This topic covers the financial contributions ...
# 2   This topic covers the Sri Lankan government's ...
# 3   This topic covers the human toll and destructi...
# 4   This topic covers the initiatives and financia...
# 5   This topic covers India's extensive humanitari...
# 6   This topic covers the extensive damage Cyclone...
# 7   This topic covers the disruption and recovery ...
# 8   This topic covers the restoration and reopenin...
# 9   This topic covers the meteorological updates a...
# 10  This topic covers the impact of Cyclone Ditwah...
# 11  This topic covers the financial assistance and...
# 12  This topic covers the actions and statements o...
# 13  This topic covers the widespread devastation c...
# 14  This topic covers the international aid and as...
# ============================================================
#   Labelling The Morning (15 topics)
# ============================================================
#   Topic 0 (1/15)... -> International relief efforts
#   Topic 1 (2/15)... -> Impact on districts
#   Topic 2 (3/15)... -> Disaster resilience and management
#   Topic 3 (4/15)... -> Education Disruptions and Recovery
#   Topic 4 (5/15)... -> IMF Emergency Financing
#   Topic 5 (6/15)... -> Rebuilding Sri Lanka Fund
#   Topic 6 (7/15)... -> Transportation Infrastructure Recovery
#   Topic 7 (8/15)... -> Post-cyclone housing resettlement
#   Topic 8 (9/15)... -> Agricultural impact and food security
#   Topic 9 (10/15)... -> Emergency regulations and accountability
#   Topic 10 (11/15)... -> Economic impact and recovery
#   Topic 11 (12/15)... -> Political implications of disaster
#   Topic 12 (13/15)... -> Festive season resilience
#   Topic 13 (14/15)... -> Business recovery efforts
#   Topic 14 (15/15)... -> Healthcare system impact
#     Topic                                    Aspect  Articles  \
# 0       0              International relief efforts        93
# 1       1                       Impact on districts        31
# 2       2        Disaster resilience and management        23
# 3       3        Education Disruptions and Recovery        22
# 4       4                   IMF Emergency Financing        22
# 5       5                 Rebuilding Sri Lanka Fund        21
# 6       6    Transportation Infrastructure Recovery        19
# 7       7         Post-cyclone housing resettlement        17
# 8       8     Agricultural impact and food security        16
# 9       9  Emergency regulations and accountability        16
# 10     10              Economic impact and recovery        14
# 11     11        Political implications of disaster        14
# 12     12                 Festive season resilience        12
# 13     13                 Business recovery efforts        12
# 14     14                  Healthcare system impact        12
#
#                                           Description
# 0   This topic covers the international humanitari...
# 1   This topic covers the extensive impact of Cycl...
# 2   This topic covers the challenges and shortcomi...
# 3   This topic covers the impact of Cyclone Ditwah...
# 4   This topic covers the International Monetary F...
# 5   This topic covers the financial contributions ...
# 6   This topic covers the impact of Cyclone Ditwah...
# 7   This topic covers the government's efforts to ...
# 8   This topic covers the impact of Cyclone Ditwah...
# 9   This topic covers the political and legal disc...
# 10  This topic covers the economic repercussions o...
# 11  This topic explores the political dynamics and...
# 12  This topic covers how the festive season, part...
# 13  This topic covers the impact of Cyclone Ditwah...
# 14  This topic covers the significant impact Cyclo...
# ============================================================
#   Labelling Daily FT (15 topics)
# ============================================================
#   Topic 0 (1/15)... -> Government disaster response
#   Topic 1 (2/15)... -> Rebuilding and Relief Efforts
#   Topic 2 (3/15)... -> International humanitarian aid
#   Topic 3 (4/15)... -> Tourism resilience post-cyclone
#   Topic 4 (5/15)... -> IMF Financial Assistance
#   Topic 5 (6/15)... -> Fiscal Impact and Response
#   Topic 6 (7/15)... -> Presidential response and recovery
#   Topic 7 (8/15)... -> Financial aid and recovery
#   Topic 8 (9/15)... -> Indian humanitarian aid
#   Topic 9 (10/15)... -> Industrial impact and recovery
#   Topic 10 (11/15)... -> Financial market impact
#   Topic 11 (12/15)... -> Impact and Casualties
#   Topic 12 (13/15)... -> Japanese aid response
#   Topic 13 (14/15)... -> India's aid to Sri Lanka
#   Topic 14 (15/15)... -> Health and Humanitarian Aid
#     Topic                              Aspect  Articles  \
# 0       0        Government disaster response       100
# 1       1       Rebuilding and Relief Efforts        58
# 2       2      International humanitarian aid        22
# 3       3     Tourism resilience post-cyclone        20
# 4       4            IMF Financial Assistance        18
# 5       5          Fiscal Impact and Response        16
# 6       6  Presidential response and recovery        15
# 7       7          Financial aid and recovery        14
# 8       8             Indian humanitarian aid        13
# 9       9      Industrial impact and recovery        13
# 10     10             Financial market impact        11
# 11     11               Impact and Casualties         8
# 12     12               Japanese aid response         8
# 13     13            India's aid to Sri Lanka         8
# 14     14         Health and Humanitarian Aid         8
#
#                                           Description
# 0   This topic covers the Sri Lankan government's ...
# 1   This topic covers the financial contributions ...
# 2   This topic covers the international humanitari...
# 3   This topic covers the impact of Cyclone Ditwah...
# 4   This topic covers the International Monetary F...
# 5   This topic covers the financial implications o...
# 6   This topic covers President Anura Kumara Dissa...
# 7   This topic covers the financial aid and recove...
# 8   This topic covers India's extensive humanitari...
# 9   This topic covers the impact of Cyclone Ditwah...
# 10  This topic covers the impact of Cyclone Ditwah...
# 11  This topic covers the extensive impact and hum...
# 12  This topic covers the Japanese government's hu...
# 13  This topic covers the significant assistance a...
# 14  This topic covers the health and humanitarian ...
# ============================================================
#   Labelling The Island (15 topics)
# ============================================================
#   Topic 0 (1/15)... -> Climate Change and Disaster Management
#   Topic 1 (2/15)... -> International aid response
#   Topic 2 (3/15)... -> Financial Contributions to Relief
#   Topic 3 (4/15)... -> Weather warnings and forecasts
#   Topic 4 (5/15)... -> International relief efforts
#   Topic 5 (6/15)... -> International financial aid
#   Topic 6 (7/15)... -> Casualties and Missing Persons
#   Topic 7 (8/15)... -> Government response criticism
#   Topic 8 (9/15)... -> Severe flooding impact
#   Topic 9 (10/15)... -> Government leadership response
#   Topic 10 (11/15)... -> Tourism and Economic Resilience
#   Topic 11 (12/15)... -> International diplomatic support
#   Topic 12 (13/15)... -> Political tensions post-cyclone
#   Topic 13 (14/15)... -> Infrastructure and Wildlife Damage
#   Topic 14 (15/15)... -> Government and Relief Efforts
#     Topic                                  Aspect  Articles  \
# 0       0  Climate Change and Disaster Management        35
# 1       1              International aid response        27
# 2       2       Financial Contributions to Relief        25
# 3       3          Weather warnings and forecasts        14
# 4       4            International relief efforts        13
# 5       5             International financial aid        12
# 6       6          Casualties and Missing Persons        11
# 7       7           Government response criticism        11
# 8       8                  Severe flooding impact        10
# 9       9          Government leadership response        10
# 10     10         Tourism and Economic Resilience        10
# 11     11        International diplomatic support         9
# 12     12         Political tensions post-cyclone         8
# 13     13      Infrastructure and Wildlife Damage         8
# 14     14           Government and Relief Efforts         5
#
#                                           Description
# 0   This topic covers the impact of Cyclone Ditwah...
# 1   This topic covers the international humanitari...
# 2   This topic covers the financial contributions ...
# 3   This topic covers the issuance of weather warn...
# 4   This topic covers the international assistance...
# 5   This topic covers the international financial ...
# 6   This topic covers the human toll of Cyclone Di...
# 7   This topic covers the criticism and scrutiny f...
# 8   This topic covers the severe flooding and its ...
# 9   This topic covers the leadership and actions t...
# 10  This topic covers the impact of Cyclone Ditwah...
# 11  This topic covers the international diplomatic...
# 12  This topic covers the political discord betwee...
# 13  This topic covers the extensive damage caused ...
# 14  This topic covers the Sri Lankan government's ...
# All outlets labelled. Total labels: 60

# %% [markdown]
# ## 4. Cross-Outlet Topic Matching (3 Methods)

# %%
def get_topic_ids(outlet):
    """Get non-outlier topic IDs for an outlet."""
    ti = outlet_results[outlet]['topic_info']
    return sorted(ti[ti['Topic'] != -1]['Topic'].tolist())


def compute_topic_centroids(outlet):
    """Compute mean embedding per topic."""
    r = outlet_results[outlet]
    centroids = {}
    for tid in get_topic_ids(outlet):
        mask = np.array(r['topics']) == tid
        if mask.sum() > 0:
            centroids[tid] = r['embeddings'][mask].mean(axis=0)
    return centroids


# Method 1: Centroid embedding similarity
print("Computing topic centroids per outlet...")
outlet_centroids = {o: compute_topic_centroids(o) for o in OUTLETS}


def centroid_similarity(outlet_a, tid_a, outlet_b, tid_b):
    """Cosine similarity between two topic centroids."""
    ca = outlet_centroids[outlet_a].get(tid_a)
    cb = outlet_centroids[outlet_b].get(tid_b)
    if ca is None or cb is None:
        return 0.0
    return float(1.0 - cosine(ca, cb))


# Method 2: Keyword Jaccard similarity
def keyword_jaccard(outlet_a, tid_a, outlet_b, tid_b, top_n=KEYWORD_TOP_N):
    """Jaccard similarity of top-N keyword sets."""
    words_a = outlet_results[outlet_a]['model'].get_topic(tid_a)
    words_b = outlet_results[outlet_b]['model'].get_topic(tid_b)
    if not words_a or not words_b:
        return 0.0
    set_a = set(w for w, _ in words_a[:top_n])
    set_b = set(w for w, _ in words_b[:top_n])
    intersection = len(set_a & set_b)
    union = len(set_a | set_b)
    return intersection / union if union > 0 else 0.0


# Method 3: c-TF-IDF similarity in union vocabulary space
def ctfidf_similarity_matrix(outlet_a, outlet_b):
    """Cosine similarity between c-TF-IDF vectors in a shared vocabulary space."""
    model_a = outlet_results[outlet_a]['model']
    model_b = outlet_results[outlet_b]['model']

    vocab_a = model_a.vectorizer_model.get_feature_names_out()
    vocab_b = model_b.vectorizer_model.get_feature_names_out()

    union_vocab = sorted(set(vocab_a) | set(vocab_b))
    word_to_idx = {w: i for i, w in enumerate(union_vocab)}

    def project_ctfidf(model, vocab):
        """Project c-TF-IDF matrix into union vocabulary space."""
        ctfidf = model.c_tf_idf_
        topic_ids = sorted([t for t in model.topic_labels_.keys() if t != -1])
        # BERTopic c_tf_idf_ rows: row 0 = outlier topic (-1), row 1+ = topics 0, 1, ...
        projected = np.zeros((len(topic_ids), len(union_vocab)))
        for i, tid in enumerate(topic_ids):
            row_idx = tid + 1  # offset for outlier row
            if row_idx >= ctfidf.shape[0]:
                continue
            row = ctfidf[row_idx]
            if hasattr(row, 'toarray'):
                row = row.toarray().flatten()
            for j, word in enumerate(vocab):
                if j < len(row) and word in word_to_idx:
                    projected[i, word_to_idx[word]] = row[j]
        return projected, topic_ids

    proj_a, tids_a = project_ctfidf(model_a, vocab_a)
    proj_b, tids_b = project_ctfidf(model_b, vocab_b)

    # Compute pairwise cosine similarity
    sim_matrix = np.zeros((len(tids_a), len(tids_b)))
    for i in range(len(tids_a)):
        norm_a = np.linalg.norm(proj_a[i])
        if norm_a == 0:
            continue
        for j in range(len(tids_b)):
            norm_b = np.linalg.norm(proj_b[j])
            if norm_b == 0:
                continue
            sim_matrix[i, j] = np.dot(proj_a[i], proj_b[j]) / (norm_a * norm_b)

    return sim_matrix, tids_a, tids_b
# Out:
# Computing topic centroids per outlet...

# %% [markdown]
# ## 5. Topic Matching via Hungarian Algorithm

# %%
# Compute pairwise matches for all 6 outlet pairs
outlet_pairs = list(combinations(OUTLETS, 2))
pairwise_matches = {}  # (outlet_a, outlet_b) -> list of (tid_a, tid_b, score)
pairwise_centroid_sims = {}  # for heatmap visualization

for outlet_a, outlet_b in outlet_pairs:
    name_a = SOURCE_NAMES[outlet_a]
    name_b = SOURCE_NAMES[outlet_b]
    print(f"\nMatching: {name_a} <-> {name_b}")

    tids_a = get_topic_ids(outlet_a)
    tids_b = get_topic_ids(outlet_b)

    if not tids_a or not tids_b:
        print("  Skipping: one outlet has no topics.")
        pairwise_matches[(outlet_a, outlet_b)] = []
        continue

    # Build ensemble score matrix
    n_a, n_b = len(tids_a), len(tids_b)

    # Method 1: Centroid similarity
    centroid_sim = np.zeros((n_a, n_b))
    for i, ta in enumerate(tids_a):
        for j, tb in enumerate(tids_b):
            centroid_sim[i, j] = centroid_similarity(outlet_a, ta, outlet_b, tb)

    pairwise_centroid_sims[(outlet_a, outlet_b)] = (centroid_sim, tids_a, tids_b)

    # Method 2: Keyword Jaccard
    keyword_sim = np.zeros((n_a, n_b))
    for i, ta in enumerate(tids_a):
        for j, tb in enumerate(tids_b):
            keyword_sim[i, j] = keyword_jaccard(outlet_a, ta, outlet_b, tb)

    # Method 3: c-TF-IDF similarity
    ctfidf_sim, ctfidf_tids_a, ctfidf_tids_b = ctfidf_similarity_matrix(outlet_a, outlet_b)

    # Align c-TF-IDF matrix to match tids_a/tids_b ordering
    ctfidf_aligned = np.zeros((n_a, n_b))
    tid_a_idx = {t: i for i, t in enumerate(ctfidf_tids_a)}
    tid_b_idx = {t: i for i, t in enumerate(ctfidf_tids_b)}
    for i, ta in enumerate(tids_a):
        for j, tb in enumerate(tids_b):
            if ta in tid_a_idx and tb in tid_b_idx:
                ctfidf_aligned[i, j] = ctfidf_sim[tid_a_idx[ta], tid_b_idx[tb]]

    # Weighted ensemble
    ensemble = (
        WEIGHT_CENTROID * centroid_sim
        + WEIGHT_CTFIDF * ctfidf_aligned
        + WEIGHT_KEYWORD * keyword_sim
    )

    # Hungarian algorithm (minimize cost = maximize similarity)
    cost = 1.0 - ensemble
    row_ind, col_ind = linear_sum_assignment(cost)

    matches = []
    for r, c in zip(row_ind, col_ind):
        score = ensemble[r, c]
        if score >= MATCH_THRESHOLD:
            matches.append((tids_a[r], tids_b[c], float(score)))
            print(f"  Match: T{tids_a[r]} <-> T{tids_b[c]} (score: {score:.3f})")

    pairwise_matches[(outlet_a, outlet_b)] = matches
    print(f"  Total matches: {len(matches)} (threshold: {MATCH_THRESHOLD})")

# Show ensemble score distribution for threshold calibration
all_scores = []
for matches in pairwise_matches.values():
    all_scores.extend([s for _, _, s in matches])

if all_scores:
    fig = px.histogram(
        x=all_scores, nbins=30,
        title='Ensemble Match Score Distribution (matched pairs only)',
        labels={'x': 'Ensemble Score', 'y': 'Count'},
    )
    fig.add_vline(x=MATCH_THRESHOLD, line_dash='dash', line_color='red',
                  annotation_text=f'Threshold={MATCH_THRESHOLD}')
    fig.update_layout(height=350)
    fig.show()
# Out:
# Matching: Daily News <-> The Morning
#   Match: T0 <-> T2 (score: 0.971)
#   Match: T1 <-> T5 (score: 0.978)
#   Match: T2 <-> T23 (score: 0.935)
#   Match: T3 <-> T1 (score: 0.978)
#   Match: T4 <-> T13 (score: 0.981)
#   Match: T5 <-> T0 (score: 0.970)
#   Match: T6 <-> T8 (score: 0.942)
#   Match: T7 <-> T3 (score: 0.983)
#   Match: T8 <-> T6 (score: 0.969)
#   Match: T9 <-> T15 (score: 0.983)
#   Match: T10 <-> T17 (score: 0.904)
#   Match: T11 <-> T4 (score: 0.987)
#   Match: T12 <-> T9 (score: 0.948)
#   Match: T14 <-> T22 (score: 0.860)
#   Match: T16 <-> T14 (score: 0.855)
#   Match: T17 <-> T16 (score: 0.891)
#   Match: T18 <-> T12 (score: 0.832)
#   Match: T20 <-> T19 (score: 0.872)
#   Match: T21 <-> T7 (score: 0.859)
#   Match: T22 <-> T18 (score: 0.768)
#   Match: T24 <-> T11 (score: 0.788)
#   Match: T25 <-> T10 (score: 0.862)
#   Match: T26 <-> T20 (score: 0.820)
#   Total matches: 23 (threshold: 0.75)
#
# Matching: Daily News <-> Daily FT
#   Match: T0 <-> T0 (score: 0.981)
#   Match: T1 <-> T1 (score: 0.982)
#   Match: T2 <-> T5 (score: 0.949)
#   Match: T3 <-> T11 (score: 0.961)
#   Match: T4 <-> T9 (score: 0.980)
#   Match: T5 <-> T8 (score: 0.987)
#   Match: T8 <-> T6 (score: 0.947)
#   Match: T10 <-> T3 (score: 0.956)
#   Match: T11 <-> T4 (score: 0.965)
#   Match: T14 <-> T14 (score: 0.920)
#   Match: T16 <-> T12 (score: 0.985)
#   Match: T22 <-> T2 (score: 0.943)
#   Match: T24 <-> T13 (score: 0.946)
#   Match: T25 <-> T7 (score: 0.957)
#   Match: T26 <-> T15 (score: 0.937)
#   Total matches: 15 (threshold: 0.75)
#
# Matching: Daily News <-> The Island
#   Match: T0 <-> T0 (score: 0.974)
#   Match: T1 <-> T2 (score: 0.977)
#   Match: T2 <-> T16 (score: 0.850)
#   Match: T3 <-> T6 (score: 0.974)
#   Match: T5 <-> T4 (score: 0.985)
#   Match: T6 <-> T7 (score: 0.883)
#   Match: T7 <-> T9 (score: 0.918)
#   Match: T8 <-> T13 (score: 0.948)
#   Match: T9 <-> T3 (score: 0.958)
#   Match: T10 <-> T10 (score: 0.954)
#   Match: T11 <-> T5 (score: 0.982)
#   Match: T12 <-> T12 (score: 0.874)
#   Match: T13 <-> T8 (score: 0.923)
#   Match: T14 <-> T1 (score: 0.975)
#   Match: T18 <-> T15 (score: 0.921)
#   Match: T24 <-> T14 (score: 0.822)
#   Match: T26 <-> T11 (score: 0.952)
#   Total matches: 17 (threshold: 0.75)
#
# Matching: The Morning <-> Daily FT
#   Match: T0 <-> T8 (score: 0.965)
#   Match: T1 <-> T2 (score: 0.875)
#   Match: T2 <-> T0 (score: 0.962)
#   Match: T3 <-> T12 (score: 0.816)
#   Match: T4 <-> T10 (score: 0.792)
#   Match: T5 <-> T1 (score: 0.977)
#   Match: T7 <-> T6 (score: 0.931)
#   Match: T9 <-> T15 (score: 0.857)
#   Match: T10 <-> T4 (score: 0.929)
#   Match: T11 <-> T13 (score: 0.843)
#   Match: T13 <-> T9 (score: 0.964)
#   Match: T14 <-> T14 (score: 0.858)
#   Match: T15 <-> T11 (score: 0.934)
#   Match: T16 <-> T7 (score: 0.905)
#   Match: T17 <-> T3 (score: 0.956)
#   Match: T23 <-> T5 (score: 0.915)
#   Total matches: 16 (threshold: 0.75)
#
# Matching: The Morning <-> The Island
#   Match: T0 <-> T4 (score: 0.976)
#   Match: T1 <-> T6 (score: 0.958)
#   Match: T2 <-> T0 (score: 0.967)
#   Match: T3 <-> T9 (score: 0.920)
#   Match: T4 <-> T5 (score: 0.974)
#   Match: T5 <-> T2 (score: 0.972)
#   Match: T6 <-> T13 (score: 0.947)
#   Match: T7 <-> T8 (score: 0.855)
#   Match: T9 <-> T7 (score: 0.972)
#   Match: T10 <-> T14 (score: 0.894)
#   Match: T11 <-> T12 (score: 0.927)
#   Match: T13 <-> T11 (score: 0.859)
#   Match: T14 <-> T15 (score: 0.872)
#   Match: T15 <-> T3 (score: 0.946)
#   Match: T16 <-> T1 (score: 0.862)
#   Match: T17 <-> T10 (score: 0.940)
#   Match: T23 <-> T16 (score: 0.874)
#   Total matches: 17 (threshold: 0.75)
#
# Matching: Daily FT <-> The Island
#   Match: T0 <-> T12 (score: 0.918)
#   Match: T1 <-> T2 (score: 0.991)
#   Match: T2 <-> T15 (score: 0.870)
#   Match: T3 <-> T10 (score: 0.964)
#   Match: T4 <-> T5 (score: 0.960)
#   Match: T5 <-> T7 (score: 0.896)
#   Match: T6 <-> T9 (score: 0.960)
#   Match: T7 <-> T0 (score: 0.867)
#   Match: T8 <-> T4 (score: 0.976)
#   Match: T9 <-> T13 (score: 0.895)
#   Match: T11 <-> T6 (score: 0.957)
#   Match: T12 <-> T1 (score: 0.951)
#   Match: T13 <-> T14 (score: 0.876)
#   Match: T14 <-> T8 (score: 0.833)
#   Match: T15 <-> T11 (score: 0.949)
#   Total matches: 15 (threshold: 0.75)

# %% [markdown]
# ## 6. Transitive Topic Grouping (Union-Find)

# %%
# Union-Find data structure
class UnionFind:
    def __init__(self):
        self.parent = {}
        self.rank = {}

    def find(self, x):
        if x not in self.parent:
            self.parent[x] = x
            self.rank[x] = 0
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        rx, ry = self.find(x), self.find(y)
        if rx == ry:
            return
        if self.rank[rx] < self.rank[ry]:
            rx, ry = ry, rx
        self.parent[ry] = rx
        if self.rank[rx] == self.rank[ry]:
            self.rank[rx] += 1


# Build union-find from pairwise matches
# Keys are (outlet, topic_id) tuples
uf = UnionFind()

# Register all topics
for outlet in OUTLETS:
    for tid in get_topic_ids(outlet):
        uf.find((outlet, tid))

# Union matched topics
for (outlet_a, outlet_b), matches in pairwise_matches.items():
    for tid_a, tid_b, score in matches:
        uf.union((outlet_a, tid_a), (outlet_b, tid_b))

# Extract groups
groups = defaultdict(list)
for outlet in OUTLETS:
    for tid in get_topic_ids(outlet):
        root = uf.find((outlet, tid))
        groups[root].append((outlet, tid))

# Classify groups
topic_groups = []
for group_id, (root, members) in enumerate(sorted(groups.items(), key=lambda x: -len(x[1]))):
    outlets_in_group = set(o for o, _ in members)

    # Build label from LLM aspect labels if available, else fall back to keywords
    member_aspects = [aspect_lookup[(o, tid)] for o, tid in members if (o, tid) in aspect_lookup]
    if member_aspects:
        # Pick the most common aspect across members
        from collections import Counter
        aspect_counts = Counter(member_aspects)
        # Join unique aspects (most common first)
        unique_aspects = [a for a, _ in aspect_counts.most_common()]
        label = unique_aspects[0] if len(unique_aspects) == 1 else ' / '.join(unique_aspects[:3])
    else:
        # Fallback: keyword-based label
        all_keywords = []
        for o, tid in members:
            words = outlet_results[o]['model'].get_topic(tid)
            if words:
                all_keywords.extend([w for w, _ in words[:5]])
        keyword_counts = Counter(all_keywords)
        top_keywords = [w for w, _ in keyword_counts.most_common(5)]
        label = ', '.join(top_keywords) if top_keywords else 'Unknown'

    topic_groups.append({
        'group_id': group_id,
        'label': label,
        'members': members,
        'n_outlets': len(outlets_in_group),
        'outlets': outlets_in_group,
        'is_shared': len(outlets_in_group) >= 2,
    })

shared_groups = [g for g in topic_groups if g['is_shared']]
unique_groups = [g for g in topic_groups if not g['is_shared']]

print(f"Total topic groups: {len(topic_groups)}")
print(f"  Shared (2+ outlets): {len(shared_groups)}")
print(f"  Unique (1 outlet):   {len(unique_groups)}")

print(f"\nShared Topic Groups:")
for g in shared_groups:
    outlet_names = [SOURCE_NAMES[o] for o in sorted(g['outlets'])]
    print(f"  Group {g['group_id']}: [{', '.join(outlet_names)}] - {g['label']}")

# Distribution by outlet count
dist = Counter(g['n_outlets'] for g in topic_groups)
print(f"\nGroups by outlet count:")
for n in sorted(dist.keys(), reverse=True):
    print(f"  In {n} outlet(s): {dist[n]} groups")
# Out:
# Total topic groups: 10
#   Shared (2+ outlets): 5
#   Unique (1 outlet):   5
#
# Shared Topic Groups:
#   Group 0: [Daily News, Daily FT, The Island, The Morning] - International financial aid / International aid response / Climate Impact and Response
#   Group 1: [Daily News, Daily FT, The Island, The Morning] - Rebuilding Sri Lanka Fund / Rebuilding and Relief Efforts / Financial Contributions to Relief
#   Group 2: [Daily News, Daily FT, The Island, The Morning] - International relief efforts / Indian humanitarian assistance / Indian humanitarian aid
#   Group 3: [Daily News, Daily FT, The Island, The Morning] - Tourism and Recovery Efforts / Tourism resilience post-cyclone / Tourism and Economic Resilience
#   Group 4: [Daily News, The Morning] - children, mental, navy, clean, programme
#
# Groups by outlet count:
#   In 4 outlet(s): 4 groups
#   In 2 outlet(s): 1 groups
#   In 1 outlet(s): 5 groups

# %% [markdown]
# ## 7. Visualizations

# %% [markdown]
# ### 7a. Cross-Outlet Similarity Heatmaps

# %%
# One heatmap per outlet pair showing centroid cosine similarity
for (outlet_a, outlet_b), (sim_matrix, tids_a, tids_b) in pairwise_centroid_sims.items():
    name_a = SOURCE_NAMES[outlet_a]
    name_b = SOURCE_NAMES[outlet_b]

    # Build topic labels (LLM aspect if available, else keywords)
    def topic_label(outlet, tid):
        aspect = aspect_lookup.get((outlet, tid))
        if aspect:
            return f"T{tid}: {aspect}"
        words = outlet_results[outlet]['model'].get_topic(tid)
        kw = ', '.join([w for w, _ in words[:3]]) if words else ''
        return f"T{tid}: {kw}"

    labels_a = [topic_label(outlet_a, t) for t in tids_a]
    labels_b = [topic_label(outlet_b, t) for t in tids_b]

    fig = px.imshow(
        sim_matrix,
        x=labels_b,
        y=labels_a,
        color_continuous_scale='RdYlGn',
        zmin=0, zmax=1,
        labels=dict(x=name_b, y=name_a, color='Cosine Sim'),
        title=f'Topic Centroid Similarity: {name_a} vs {name_b}',
    )
    fig.update_layout(height=500, width=800)
    fig.show()

# %% [markdown]
# ### 7b. Keyword Divergence Analysis

# %%
# For shared topic groups, show shared vs distinctive keywords per outlet
for g in shared_groups[:8]:  # limit to first 8 groups
    group_label = g['label']
    members = g['members']

    # Collect keywords per outlet in this group
    outlet_keywords = {}
    for o, tid in members:
        words = outlet_results[o]['model'].get_topic(tid)
        if words:
            outlet_keywords[SOURCE_NAMES[o]] = {w: s for w, s in words[:KEYWORD_TOP_N]}

    if len(outlet_keywords) < 2:
        continue

    # Find shared and distinctive keywords
    all_words = set()
    for kw_dict in outlet_keywords.values():
        all_words |= set(kw_dict.keys())

    shared_kws = set.intersection(*[set(kw.keys()) for kw in outlet_keywords.values()])

    # Build figure: side-by-side bars for each outlet
    fig = go.Figure()
    outlet_names = sorted(outlet_keywords.keys())

    for oname in outlet_names:
        kw_dict = outlet_keywords[oname]
        # Sort by score descending
        sorted_kw = sorted(kw_dict.items(), key=lambda x: x[1], reverse=True)
        words = [w for w, _ in sorted_kw]
        scores = [s for _, s in sorted_kw]
        colors = [SOURCE_COLORS[oname] if w not in shared_kws else '#888888' for w in words]

        fig.add_trace(go.Bar(
            name=oname,
            y=words[::-1],
            x=scores[::-1],
            orientation='h',
            marker_color=colors[::-1],
        ))

    fig.update_layout(
        title=f'Keyword Divergence: Group "{group_label}"<br><sub>Grey = shared keywords, colored = distinctive</sub>',
        barmode='group',
        height=400,
        xaxis_title='Keyword Score',
    )
    fig.show()

# %% [markdown]
# ### 7c. Coverage Volume Comparison

# %%
# Grouped bar chart: article counts per outlet per matched topic group
coverage_rows = []
for g in shared_groups:
    for outlet in OUTLETS:
        # Count articles in this group for this outlet
        member_tids = [tid for o, tid in g['members'] if o == outlet]
        count = 0
        if member_tids:
            topics_arr = np.array(outlet_results[outlet]['topics'])
            for tid in member_tids:
                count += int((topics_arr == tid).sum())
        coverage_rows.append({
            'Group': f"G{g['group_id']}: {g['label'][:30]}",
            'group_id': g['group_id'],
            'Outlet': SOURCE_NAMES[outlet],
            'Articles': count,
        })

coverage_df = pd.DataFrame(coverage_rows)

fig = px.bar(
    coverage_df,
    x='Group',
    y='Articles',
    color='Outlet',
    barmode='group',
    color_discrete_map=SOURCE_COLORS,
    title='Article Coverage per Outlet per Shared Topic Group',
)
fig.update_layout(height=500, xaxis_tickangle=-30)
fig.show()

# %% [markdown]
# ### 7d. Topic Proportion Heatmap

# %%
# % of each outlet's coverage devoted to each topic group, sorted by variance
prop_rows = []
for g in shared_groups:
    row = {'Group': f"G{g['group_id']}: {g['label'][:35]}"}
    proportions = []
    for outlet in OUTLETS:
        member_tids = [tid for o, tid in g['members'] if o == outlet]
        total_articles = len(outlet_results[outlet]['documents'])
        count = 0
        if member_tids:
            topics_arr = np.array(outlet_results[outlet]['topics'])
            for tid in member_tids:
                count += int((topics_arr == tid).sum())
        prop = count / total_articles if total_articles > 0 else 0
        row[SOURCE_NAMES[outlet]] = prop
        proportions.append(prop)
    row['variance'] = np.var(proportions)
    prop_rows.append(row)

prop_df = pd.DataFrame(prop_rows).sort_values('variance', ascending=False)

outlet_names = [SOURCE_NAMES[o] for o in OUTLETS]
heat_data = prop_df[outlet_names].values

fig = px.imshow(
    heat_data,
    x=outlet_names,
    y=prop_df['Group'].tolist(),
    color_continuous_scale='YlOrRd',
    labels=dict(color='Proportion'),
    title='Topic Coverage Proportions per Outlet<br><sub>Sorted by variance (highest = strongest selection bias signal)</sub>',
    text_auto='.1%',
)
fig.update_layout(height=max(400, len(prop_df) * 35), width=700)
fig.show()

# %% [markdown]
# ### 7e. Sankey Diagram

# %%
# Sankey diagram showing topic correspondences across outlets
# Nodes: each outlet's topics; Links: matched pairs

node_labels = []
node_colors = []
node_map = {}  # (outlet, tid) -> node index

for outlet in OUTLETS:
    color = SOURCE_COLORS[SOURCE_NAMES[outlet]]
    for tid in get_topic_ids(outlet):
        aspect = aspect_lookup.get((outlet, tid))
        if aspect:
            label = f"{SOURCE_NAMES[outlet]}\nT{tid}: {aspect}"
        else:
            words = outlet_results[outlet]['model'].get_topic(tid)
            kw = ', '.join([w for w, _ in words[:3]]) if words else f'T{tid}'
            label = f"{SOURCE_NAMES[outlet]}\nT{tid}: {kw}"
        node_map[(outlet, tid)] = len(node_labels)
        node_labels.append(label)
        node_colors.append(color)

# Links from matches
link_source = []
link_target = []
link_value = []
link_color = []

for (outlet_a, outlet_b), matches in pairwise_matches.items():
    for tid_a, tid_b, score in matches:
        src = node_map.get((outlet_a, tid_a))
        tgt = node_map.get((outlet_b, tid_b))
        if src is not None and tgt is not None:
            link_source.append(src)
            link_target.append(tgt)
            # Value = article count in source topic
            topics_arr = np.array(outlet_results[outlet_a]['topics'])
            val = max(1, int((topics_arr == tid_a).sum()))
            link_value.append(val)
            link_color.append(f'rgba(150,150,150,0.3)')

fig = go.Figure(go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        label=node_labels,
        color=node_colors,
    ),
    link=dict(
        source=link_source,
        target=link_target,
        value=link_value,
        color=link_color,
    ),
))

fig.update_layout(
    title='Cross-Outlet Topic Correspondences',
    height=700,
    width=1000,
    font_size=10,
)
fig.show()

# %% [markdown]
# ### 7f. Unique vs Shared Topics

# %%
# Stacked bar chart: shared vs unique topics per outlet
shared_unique_rows = []
for outlet in OUTLETS:
    name = SOURCE_NAMES[outlet]
    all_tids = set(get_topic_ids(outlet))

    # Topics that appear in shared groups
    shared_tids = set()
    for g in shared_groups:
        for o, tid in g['members']:
            if o == outlet:
                shared_tids.add(tid)

    unique_tids = all_tids - shared_tids
    shared_unique_rows.append({'Outlet': name, 'Type': 'Shared', 'Count': len(shared_tids)})
    shared_unique_rows.append({'Outlet': name, 'Type': 'Unique', 'Count': len(unique_tids)})

su_df = pd.DataFrame(shared_unique_rows)

fig = px.bar(
    su_df, x='Outlet', y='Count', color='Type',
    barmode='stack',
    color_discrete_map={'Shared': '#4CAF50', 'Unique': '#FF9800'},
    title='Shared vs Unique Topics per Outlet',
)
fig.update_layout(height=400)
fig.show()

# List unique topics with LLM aspect labels (or keywords as fallback)
print("\nUnique Topics (only in one outlet):")
print("=" * 80)
for g in unique_groups:
    outlet, tid = g['members'][0]
    aspect = aspect_lookup.get((outlet, tid))
    words = outlet_results[outlet]['model'].get_topic(tid)
    kw = ', '.join([w for w, _ in words[:8]]) if words else 'N/A'
    topics_arr = np.array(outlet_results[outlet]['topics'])
    count = int((topics_arr == tid).sum())
    if aspect:
        print(f"  {SOURCE_NAMES[outlet]:15s} | T{tid:2d} ({count:3d} articles) | {aspect}")
        print(f"  {'':15s} |     keywords: {kw}")
    else:
        print(f"  {SOURCE_NAMES[outlet]:15s} | T{tid:2d} ({count:3d} articles) | {kw}")
# Out:
# Unique Topics (only in one outlet):
# ================================================================================
#   Daily News      | T15 ( 12 articles) | pakistan, relief, ndma, high, minister, prime minister, pakistani, prime
#   Daily News      | T19 (  9 articles) | jaishankar, indian, minister, india, prime minister, prime, visit, dr jaishankar
#   Daily News      | T23 (  8 articles) | condolences, russia, president, message, russian, saudi, friendly, egypt
#   Daily News      | T27 (  6 articles) | rescue relief, clearing, gamage, tri forces, rescue, cleaning, tri, volunteers
#   The Morning     | T21 (  6 articles) | police, public, personal, messages, individuals, information, media, fake

# %% [markdown]
# ### 7g. Selection Bias Metric

# %%
# Rank topic groups by coverage proportion variance across outlets
bias_rows = []
for g in shared_groups:
    proportions = {}
    for outlet in OUTLETS:
        member_tids = [tid for o, tid in g['members'] if o == outlet]
        total_articles = len(outlet_results[outlet]['documents'])
        count = 0
        if member_tids:
            topics_arr = np.array(outlet_results[outlet]['topics'])
            for tid in member_tids:
                count += int((topics_arr == tid).sum())
        proportions[SOURCE_NAMES[outlet]] = count / total_articles if total_articles > 0 else 0

    props = list(proportions.values())
    variance = np.var(props)
    max_outlet = max(proportions, key=proportions.get)
    min_outlet = min(proportions, key=proportions.get)

    bias_rows.append({
        'Group': f"G{g['group_id']}",
        'Label': g['label'][:40],
        'Variance': variance,
        'Max Coverage': f"{max_outlet} ({proportions[max_outlet]:.1%})",
        'Min Coverage': f"{min_outlet} ({proportions[min_outlet]:.1%})",
        'Spread': proportions[max_outlet] - proportions[min_outlet],
        **{f"{k} %": f"{v:.1%}" for k, v in proportions.items()},
    })

bias_df = pd.DataFrame(bias_rows).sort_values('Variance', ascending=False)

print("Selection Bias Indicators (by coverage variance)")
print("=" * 80)
display(bias_df)

# Bar chart of spread
fig = px.bar(
    bias_df.head(15),
    x='Label',
    y='Spread',
    title='Topic Coverage Spread (max - min proportion) Across Outlets<br><sub>Higher spread = stronger selection bias signal</sub>',
    labels={'Spread': 'Max-Min Proportion Spread', 'Label': 'Topic Group'},
    color='Spread',
    color_continuous_scale='Reds',
)
fig.update_layout(height=450, xaxis_tickangle=-30)
fig.show()
# Out:
# Selection Bias Indicators (by coverage variance)
# ================================================================================
#   Group                                     Label  Variance  \
# 2    G2  International relief efforts / Indian hu  0.004038
# 1    G1  Rebuilding Sri Lanka Fund / Rebuilding a  0.001639
# 0    G0  International financial aid / Internatio  0.001368
# 3    G3  Tourism and Recovery Efforts / Tourism r  0.000134
# 4    G4  children, mental, navy, clean, programme  0.000074
#
#           Max Coverage         Min Coverage    Spread Daily News %  \
# 2  The Morning (18.9%)      Daily FT (3.4%)  0.155199         5.0%
# 1     Daily FT (15.3%)   The Morning (4.3%)  0.109862         7.0%
# 0   Daily News (65.7%)  The Morning (56.6%)  0.091179        65.7%
# 3      Daily FT (5.3%)   The Morning (2.0%)  0.032265         3.2%
# 4    Daily News (1.8%)      Daily FT (0.0%)  0.017928         1.8%
#
#   The Morning % Daily FT % The Island %
# 2         18.9%       3.4%         4.6%
# 1          4.3%      15.3%         8.8%
# 0         56.6%      64.7%        59.9%
# 3          2.0%       5.3%         3.5%
# 4          1.6%       0.0%         0.0%

# %% [markdown]
# ## 8. Summary

# %%
print("=" * 70)
print("PER-OUTLET TOPIC COMPARISON SUMMARY")
print("=" * 70)

# Per-outlet statistics
print("\n1. Per-Outlet Statistics")
print("-" * 50)
for outlet in OUTLETS:
    r = outlet_results[outlet]
    ti = r['topic_info']
    n_topics = len(ti[ti['Topic'] != -1])
    n_outliers = sum(1 for t in r['topics'] if t == -1)
    n_docs = len(r['documents'])
    print(f"  {SOURCE_NAMES[outlet]:15s}: {n_docs:4d} articles, {n_topics:3d} topics, "
          f"{n_outliers:3d} outliers ({100*n_outliers/n_docs:.1f}%)")

# Cross-outlet group distribution
print(f"\n2. Cross-Outlet Topic Group Distribution")
print("-" * 50)
dist = Counter(g['n_outlets'] for g in topic_groups)
for n in sorted(dist.keys(), reverse=True):
    label = 'outlet' if n == 1 else 'outlets'
    print(f"  In {n} {label}: {dist[n]} groups")

# Selection bias indicators
print(f"\n3. Selection Bias Indicators")
print("-" * 50)
if len(bias_df) > 0:
    # Per-outlet: how many unique topics
    for outlet in OUTLETS:
        unique_count = sum(1 for g in unique_groups
                          if g['members'][0][0] == outlet)
        print(f"  {SOURCE_NAMES[outlet]:15s}: {unique_count} unique topics (not matched to other outlets)")

# Most unevenly covered topics (using LLM labels)
print(f"\n4. Most Unevenly Covered Topics")
print("-" * 50)
for _, row in bias_df.head(5).iterrows():
    print(f"  {row['Group']:5s} | {row['Label']:40s} | Spread: {row['Spread']:.1%}")
    print(f"         Max: {row['Max Coverage']:30s} | Min: {row['Min Coverage']}")

print("\n" + "=" * 70)
print("Analysis complete.")
# Out:
# ======================================================================
# PER-OUTLET TOPIC COMPARISON SUMMARY
# ======================================================================
#
# 1. Per-Outlet Statistics
# --------------------------------------------------
#   Daily News     :  502 articles,  28 topics,  52 outliers (10.4%)
#   The Morning    :  491 articles,  24 topics,  75 outliers (15.3%)
#   Daily FT       :  380 articles,  16 topics,  43 outliers (11.3%)
#   The Island     :  284 articles,  17 topics,  66 outliers (23.2%)
#
# 2. Cross-Outlet Topic Group Distribution
# --------------------------------------------------
#   In 4 outlets: 4 groups
#   In 2 outlets: 1 groups
#   In 1 outlet: 5 groups
#
# 3. Selection Bias Indicators
# --------------------------------------------------
#   Daily News     : 4 unique topics (not matched to other outlets)
#   The Morning    : 1 unique topics (not matched to other outlets)
#   Daily FT       : 0 unique topics (not matched to other outlets)
#   The Island     : 0 unique topics (not matched to other outlets)
#
# 4. Most Unevenly Covered Topics
# --------------------------------------------------
#   G2    | International relief efforts / Indian hu | Spread: 15.5%
#          Max: The Morning (18.9%)            | Min: Daily FT (3.4%)
#   G1    | Rebuilding Sri Lanka Fund / Rebuilding a | Spread: 11.0%
#          Max: Daily FT (15.3%)               | Min: The Morning (4.3%)
#   G0    | International financial aid / Internatio | Spread: 9.1%
#          Max: Daily News (65.7%)             | Min: The Morning (56.6%)
#   G3    | Tourism and Recovery Efforts / Tourism r | Spread: 3.2%
#          Max: Daily FT (5.3%)                | Min: The Morning (2.0%)
#   G4    | children, mental, navy, clean, programme | Spread: 1.8%
#          Max: Daily News (1.8%)              | Min: Daily FT (0.0%)
#
# ======================================================================
# Analysis complete.
