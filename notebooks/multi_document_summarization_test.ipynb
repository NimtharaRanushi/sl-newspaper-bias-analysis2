# %% [markdown]
# # Multi-Document Summarization Test
#
# This notebook tests multiple multi-document summarization methods on:
# 1. **Topic groups**: Articles belonging to the same BERTopic-discovered semantic category
# 2. **Event clusters**: Articles covering the same news event across multiple sources
#
# Methods tested:
# - **PRIMERA** (`allenai/primera`) - Designed for multi-doc summarization
# - **LED** (`allenai/led-base-16384`) - Long-context transformer
# - **LongT5** (`google/long-t5-tglobal-base`) - Long-context T5
# - **OpenAI GPT-4o** - LLM-based
# - **Gemini** (2.0 Flash) - LLM-based

# %% [markdown]
# ## Section 1: Setup & Data Loading

# %%
# Cell 1: Imports
import sys
sys.path.append('..')

from src.db import Database
from src.config import load_config
from src.multi_doc_summarization import (
    PRIMERASummarizer,
    LEDMultiDocSummarizer,
    LongT5MultiDocSummarizer,
    OpenAIMultiDocSummarizer,
    GeminiMultiDocSummarizer
)
from dashboard.components.source_mapping import SOURCE_NAMES

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✓ Imports complete")
# Out:
# ✓ Imports complete

# %%
# Cell 2: Cache configuration
import json
import os
from pathlib import Path
from datetime import datetime

# Cache directory for storing results (separate file per model)
CACHE_DIR = Path("cache/multi_doc_summarization")
CACHE_DIR.mkdir(parents=True, exist_ok=True)

USE_CACHE = True  # Set to False to regenerate all summaries

# Methods to test
METHODS = ['primera', 'led', 'longt5', 'openai', 'gemini']

def get_cache_path(method: str, group_type: str) -> Path:
    """Get cache file path for method and group type (topics/clusters)."""
    return CACHE_DIR / f"{method}_{group_type}.json"

def load_cache(method: str, group_type: str) -> dict:
    """Load cached summaries for a specific method if available."""
    cache_path = get_cache_path(method, group_type)
    if not USE_CACHE or not cache_path.exists():
        return None
    
    with open(cache_path, 'r') as f:
        data = json.load(f)
    print(f"  ✓ Loaded {method} {group_type} from cache ({cache_path.name})")
    return data

def save_cache(method: str, group_type: str, results: list, 
               version_id: str, version_name: str, groups_tested: list):
    """Save summaries for a specific method to cache with metadata."""
    cache_path = get_cache_path(method, group_type)
    
    cache_data = {
        "metadata": {
            "method": method,
            "group_type": group_type,
            "version_id": version_id,
            "version_name": version_name,
            "groups_tested": groups_tested,
            "created_at": datetime.now().isoformat(),
            "result_count": len(results)
        },
        "results": results
    }
    
    with open(cache_path, 'w') as f:
        json.dump(cache_data, f, indent=2, default=str)
    print(f"  ✓ Saved {method} {group_type} to cache ({cache_path.name})")

def load_all_topic_results() -> dict:
    """Load all cached topic results."""
    results = {}
    for method in METHODS:
        cache_data = load_cache(method, 'topics')
        if cache_data:
            results[method] = cache_data['results']
    return results if len(results) == len(METHODS) else None

def load_all_cluster_results() -> dict:
    """Load all cached cluster results."""
    results = {}
    for method in METHODS:
        cache_data = load_cache(method, 'clusters')
        if cache_data:
            results[method] = cache_data['results']
    return results if len(results) == len(METHODS) else None

def check_cache_status():
    """Check which cache files exist."""
    print("Cache status:")
    for group_type in ['topics', 'clusters']:
        print(f"\n  {group_type.capitalize()}:")
        for method in METHODS:
            cache_path = get_cache_path(method, group_type)
            status = "✓" if cache_path.exists() else "✗"
            print(f"    {status} {method}")

print(f"Cache directory: {CACHE_DIR}")
print(f"Cache mode: {'ENABLED' if USE_CACHE else 'DISABLED'}\n")
check_cache_status()
# Out:
# Cache directory: cache/multi_doc_summarization
# Cache mode: ENABLED
#
# Cache status:
#
#   Topics:
#     ✗ primera
#     ✗ led
#     ✗ longt5
#     ✗ openai
#     ✗ gemini
#
#   Clusters:
#     ✗ primera
#     ✗ led
#     ✗ longt5
#     ✗ openai
#     ✗ gemini

# %%
# Cell 2: Verify API keys

from src.config import load_config
import os

config = load_config()

openai_key = config.get('openai', {}).get('api_key') or os.environ.get('OPENAI_API_KEY')
if openai_key and openai_key != 'YOUR_OPENAI_API_KEY_HERE':
    print('✓ OPENAI_API_KEY is configured')
else:
    print('⚠️  OPENAI_API_KEY not set (OpenAI cells will fail)')

gemini_key = config.get('gemini', {}).get('api_key') or os.environ.get('GOOGLE_API_KEY')
if gemini_key and gemini_key != 'YOUR_GOOGLE_API_KEY_HERE':
    print('✓ GOOGLE_API_KEY is configured')
else:
    print('⚠️  GOOGLE_API_KEY not set (Gemini cells will fail)')
# Out:
# ✓ OPENAI_API_KEY is configured
# ✓ GOOGLE_API_KEY is configured

# %%
# Cell 3: Load config and connect to database
config = load_config()
db = Database()
db.connect()

print("✓ Database connected")
print(f"Schema: {db.config['schema']}")
# Out:
# ✓ Database connected
# Schema: media_bias

# %%
# Cell 4: Select versions for testing
# Get completed topic versions
schema = db.config['schema']
with db.cursor() as cur:
    cur.execute(f"""
        SELECT id, name, description, configuration, pipeline_status
        FROM {schema}.result_versions
        WHERE analysis_type = 'topics'
          AND (pipeline_status->>'topics')::boolean = true
          AND configuration->'embeddings'->>'model' = 'google/embeddinggemma-300m'
        ORDER BY created_at DESC
        LIMIT 1
    """)
    topic_version = cur.fetchone()

if not topic_version:
    raise ValueError("No completed topic version found with google/embeddinggemma-300m")

topic_version_id = str(topic_version['id'])
print(f"Selected topic version: {topic_version['name']}")
print(f"  ID: {topic_version_id}")
print(f"  Description: {topic_version['description']}")

# Get completed clustering versions
with db.cursor() as cur:
    cur.execute(f"""
        SELECT id, name, description, configuration, pipeline_status
        FROM {schema}.result_versions
        WHERE analysis_type = 'clustering'
          AND (pipeline_status->>'clustering')::boolean = true
        ORDER BY created_at DESC
        LIMIT 1
    """)
    clustering_version = cur.fetchone()

if not clustering_version:
    raise ValueError("No completed clustering version found")

clustering_version_id = str(clustering_version['id'])
print(f"\nSelected clustering version: {clustering_version['name']}")
print(f"  ID: {clustering_version_id}")
print(f"  Description: {clustering_version['description']}")
# Out:
# Selected topic version: v0130-1438
#   ID: 5559335a-50ea-47b5-a7bc-69dc85b54f2c
#   Description:
#
# Selected clustering version: v0128-2256
#   ID: e6fdc5df-7453-4d17-b786-0894ea52150b
#   Description:

# %%
# Cell 5: Load sample topics (10-20 articles per topic)
topics = db.get_all_topics_with_counts(topic_version_id, min_article_count=10)
topics_df = pd.DataFrame(topics)

# Filter to topics with 10-20 articles (not too small, not too large)
topics_df = topics_df[(topics_df['article_count'] >= 10) & (topics_df['article_count'] <= 20)]

print(f"Found {len(topics_df)} topics with 10-20 articles")
print("\nTop 10 topics by article count:")
display(topics_df.head(10)[['name', 'article_count', 'keywords']])

# Select 5 diverse topics for testing
selected_topics = topics_df.head(5)['id'].tolist()
print(f"\nSelected {len(selected_topics)} topics for testing")
# Out:
# Found 19 topics with 10-20 articles
#
# Top 10 topics by article count:
#                                                  name  article_count  \
# 25  Deputy, Imports, Recent Extreme Weather, Commo...             20
# 26    Sector, Yields, Securities, Wealth, Engineering             20
# 27  Incidents, Affairs, Disruptions, Regarding, In...             19
# 28     Flooding, Flood, Sector, Floodwater, Aftermath             19
# 29  Recovery Efforts, Resilience, Economic Recover...             18
# 30  Devastation, Recovery Efforts, Impacted, Const...             18
# 31    Flooding, Flood, Cyclones, Flood Waters, Rescue             17
# 32  Flooding, Flood, Telecommunication, Disruption...             17
# 33  Devastation Caused, Devastation, External Affa...             15
# 34  Diplomatic, Dialogue, Recovery Reconstruction,...             14
#
#                                              keywords
# 25  [deputy, imports, recent extreme weather, comm...
# 26  [sector, yields, securities, wealth, engineeri...
# 27  [incidents, affairs, disruptions, regarding, i...
# 28  [flooding, flood, sector, floodwater, aftermat...
# 29  [recovery efforts, resilience, economic recove...
# 30  [devastation, recovery efforts, impacted, cons...
# 31  [flooding, flood, cyclones, flood waters, resc...
# 32  [flooding, flood, telecommunication, disruptio...
# 33  [devastation caused, devastation, external aff...
# 34  [diplomatic, dialogue, recovery reconstruction...
# Selected 5 topics for testing

# %%
# Cell 6: Load sample event clusters (3-10 articles per cluster)
clusters = db.get_all_clusters_with_counts(clustering_version_id, min_article_count=3)
clusters_df = pd.DataFrame(clusters)

# Filter to clusters with 3-10 articles
clusters_df = clusters_df[(clusters_df['article_count'] >= 3) & (clusters_df['article_count'] <= 10)]

print(f"Found {len(clusters_df)} clusters with 3-10 articles")
print("\nTop 10 clusters by article count:")
display(clusters_df.head(10)[['cluster_name', 'article_count', 'sources_count', 'date_start', 'date_end']])

# Select 5 diverse clusters for testing
selected_clusters = clusters_df.head(5)['id'].tolist()
print(f"\nSelected {len(selected_clusters)} clusters for testing")
# Out:
# Found 180 clusters with 3-10 articles
#
# Top 10 clusters by article count:
#                                          cluster_name  article_count  \
# 62           Sri Lankan economy still vulnerable: IMF             10
# 63  Two financial contributions received for the ‘...             10
# 64  Govt. announces robust post-disaster rebuildin...             10
# 65                              The burden of neglect             10
# 66  World Bank to inject US$120 Mn in emergency su...             10
# 67  A harsh reflection of Sri Lanka’s early-warnin...             10
# 68  SL post-Ditwah: Top economists call for halt t...             10
# 69  Pakistan sends fresh relief cargo and elite re...             10
# 70  Flooding across Asia leaves 600 dead and hundr...             10
# 71                               When the waters rose              9
#
#     sources_count  date_start    date_end
# 62              4  2025-12-22  2025-12-30
# 63              4  2025-12-18  2025-12-29
# 64              3  2025-12-02  2025-12-10
# 65              4  2025-12-04  2025-12-16
# 66              4  2025-12-08  2025-12-18
# 67              3  2025-12-14  2025-12-25
# 68              4  2025-12-17  2025-12-28
# 69              4  2025-12-03  2025-12-16
# 70              2  2025-11-28  2025-12-02
# 71              4  2025-12-01  2025-12-07
# Selected 5 clusters for testing

# %%
# Cell 7: Fetch articles for selected groups
# Store topic groups
topic_groups = {}
for topic_id in selected_topics:
    articles = db.get_articles_by_topic(topic_id, topic_version_id)
    topic_name = topics_df[topics_df['id'] == topic_id].iloc[0]['name']
    topic_groups[topic_name] = articles
    print(f"Topic '{topic_name}': {len(articles)} articles from {len(set(a['source_id'] for a in articles))} sources")

print()

# Store cluster groups
cluster_groups = {}
for cluster_id in selected_clusters:
    articles = db.get_articles_by_cluster(cluster_id, clustering_version_id)
    cluster_name = clusters_df[clusters_df['id'] == cluster_id].iloc[0]['cluster_name']
    cluster_groups[cluster_name] = articles
    print(f"Cluster '{cluster_name}': {len(articles)} articles from {len(set(a['source_id'] for a in articles))} sources")
# Out:
# Topic 'Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent': 20 articles from 3 sources
# Topic 'Sector, Yields, Securities, Wealth, Engineering': 20 articles from 4 sources
# Topic 'Incidents, Affairs, Disruptions, Regarding, Involved': 19 articles from 4 sources
# Topic 'Flooding, Flood, Sector, Floodwater, Aftermath': 19 articles from 4 sources
# Topic 'Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector': 18 articles from 4 sources
#
# Cluster 'Sri Lankan economy still vulnerable: IMF': 10 articles from 4 sources
# Cluster 'Two financial contributions received for the ‘Rebuilding Sri Lanka’': 10 articles from 4 sources
# Cluster 'Govt. announces robust post-disaster rebuilding fund': 10 articles from 3 sources
# Cluster 'The burden of neglect': 10 articles from 4 sources
# Cluster 'World Bank to inject US$120 Mn in emergency support to Sri Lanka': 10 articles from 4 sources

# %% [markdown]
# ## Section 2: Method Comparison on Topics

# %%
# Cell: Load cached topic results or prepare for fresh generation
print("Loading topic results from cache...\n")

# Try to load cached results for each method
primera_topic_results = None
led_topic_results = None
longt5_topic_results = None
openai_topic_results = None
gemini_topic_results = None

if USE_CACHE:
    primera_cache = load_cache('primera', 'topics')
    led_cache = load_cache('led', 'topics')
    longt5_cache = load_cache('longt5', 'topics')
    openai_cache = load_cache('openai', 'topics')
    gemini_cache = load_cache('gemini', 'topics')
    
    if primera_cache:
        primera_topic_results = primera_cache['results']
    if led_cache:
        led_topic_results = led_cache['results']
    if longt5_cache:
        longt5_topic_results = longt5_cache['results']
    if openai_cache:
        openai_topic_results = openai_cache['results']
    if gemini_cache:
        gemini_topic_results = gemini_cache['results']

# Summary
cached = [m for m, r in [('PRIMERA', primera_topic_results), ('LED', led_topic_results), 
                          ('LongT5', longt5_topic_results), ('OpenAI', openai_topic_results),
                          ('Gemini', gemini_topic_results)] if r is not None]
missing = [m for m, r in [('PRIMERA', primera_topic_results), ('LED', led_topic_results), 
                           ('LongT5', longt5_topic_results), ('OpenAI', openai_topic_results),
                           ('Gemini', gemini_topic_results)] if r is None]

print(f"\n✓ Cached: {', '.join(cached) if cached else 'None'}")
print(f"✗ Missing (will generate): {', '.join(missing) if missing else 'None'}")
# Out:
# Loading topic results from cache...
#
#
# ✓ Cached: None
# ✗ Missing (will generate): PRIMERA, LED, LongT5, OpenAI, Gemini

# %%
# Cell 8: Test PRIMERA on topics
if primera_topic_results is not None:
    print("✓ PRIMERA topic results already loaded from cache - skipping generation")
else:
    print("Testing PRIMERA on topic groups...\n")

    # Initialize PRIMERA summarizer
    primera_config = {
        'method': 'primera'
    }
    primera = PRIMERASummarizer(primera_config)

    primera_topic_results = []

    for topic_name, articles in topic_groups.items():
        print(f"\n{'='*80}")
        print(f"Topic: {topic_name}")
        print(f"Articles: {len(articles)}")
        print(f"{'='*80}")
        
        # Extract documents and sources
        documents = [a['content'] for a in articles]
        sources = [SOURCE_NAMES.get(a['source_id'], a['source_id']) for a in articles]
        
        # Show article titles
        print("\nArticles in group:")
        for i, article in enumerate(articles):
            source_name = SOURCE_NAMES.get(article['source_id'], article['source_id'])
            print(f"  {i+1}. [{source_name}] {article['title'][:70]}...")
        
        # Generate summary
        start_time = time.time()
        summary = primera.summarize_multiple(documents, sources)
        processing_time = time.time() - start_time
        
        print(f"\nPRIMERA Summary ({processing_time:.2f}s):")
        print(summary)
        
        primera_topic_results.append({
            'group': topic_name,
            'article_count': len(articles),
            'summary': summary,
            'processing_time': processing_time,
            'word_count': primera.count_words(summary)
        })

    avg_time = sum(r['processing_time'] for r in primera_topic_results) / len(primera_topic_results)
    print(f"\n\nAverage processing time: {avg_time:.2f}s")
    
    # Save immediately after generation
    save_cache('primera', 'topics', primera_topic_results, 
               topic_version_id, topic_version['name'], list(topic_groups.keys()))
# Out:
# Testing PRIMERA on topic groups...
# Token indices sequence length is longer than the specified maximum sequence length for this model (6067 > 4096). Running this sequence through the model will result in indexing errors
# Loaded allenai/primera on CPU (max 4096 tokens)
#
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# Articles: 20
# ================================================================================
#
# Articles in group:
#   1. [Daily FT] Govt. assures steady food supply despite cyclone disruptions...
#   2. [The Morning] Agri. Min.: All affected cultivators to be compensated...
#   3. [The Morning] Expedited crop compensation launched for farmers affected by Cyclone D...
#   4. [The Morning] Seasonal demand: Consumer group wants unaffected areas cultivated...
#   5. [The Morning] Food security: Rice sufficient for few months...
#   6. [The Morning] No critical shortage of essentials as of now...
#   7. [The Morning] Agriculture: Over 200,000 hectares of crops destroyed...
#   8. [The Morning] 25% reduction in vegetable harvest in Nuwara Eliya due to adverse weat...
#   9. [The Morning] Livestock Min: No egg shortage, no imports...
#   10. [The Morning] PHIs raise the alarm: Wet dried grains, thawed-refrozen meats...
#   11. [Daily News] Farmers to be compensated for loss of crops...
#   12. [The Morning] Liquid milk supply drops...
#   13. [Daily News] ‘Ninety-five thousand hectares of damaged paddy fields can be replante...
#   14. [The Morning] Possible Samba rice shortage after Cyclone Ditwah damage...
#   15. [Daily News] Cyclone destroyed over 106,800 hectares of paddy- Minister...
#   16. [The Morning] Govt. assures stable rice supply...
#   17. [The Morning] Food Security: Min. says no risk of shortage...
#   18. [The Morning] Vegetable Imports: NAU accuses Govt of using cyclone to justify vegeta...
#   19. [Daily News] Govt. provides over Rs. 381Mn as special compensation to disaster-affe...
#   20. [The Morning] Post-Ditwah agri: 83,800+ farmers compensated, Rs. 5,650m+ paid...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 6,067 tokens (4,512 words)
#    Limit: 4,096 tokens
#    Lost: 1,971 tokens (~32.5% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (195.16s):
# The Trade, Commerce, Food Security and Cooperative Development Ministry yesterday moved to reassure the public that essential food commodities remain available across the country despite temporary disruptions caused by Cyclone Ditwah and the resulting floods. In a statement, the Ministry said: “There is no shortage of essential commodities,” adding that while transportation and distribution channels in several districts had been affected, “replenishment is continuous and in progress.”=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-The Ministry said Government and private sector agencies involved in importation, wholesale, storage, transportation, and retail are working together “to ensure the smooth flow and distribution ofessential commodities, making them available to the public as quickly as possible.“ District-level arrangements have also been put in place to deliver supplies directly to flood-affected areas.Importation and Customs clearance, it noted, are proceeding normally, and “there is now no flood threat to the release of containers from the Customs examination yards.The Government said it is prepared to import additional quantities of any essential good “should a temporary shortage arise,“ while safeguarding the interests of farmers where agricultural products are concerned.ŽuśžŽińżżąŽś ŽujźžĄž Žź ŽęźĆż Žjź‼ńĆ Žoń Ž śź Žēń‼ĆĆ”Žó Žóż ŁśĚŽ“ŽÄź ćź ÇŁĚćĚ ćĺć ćаń ćań ÇĄć,Žeńsń sœżósœć žąćńаŇņńaŇ, Žéńšź sŴńфąsŚą, žńzą sſíą žeć̂ńskń, šſą̇ żečń̇řń.ſſ̅ń ſᴄńâsŴ Že
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# Articles: 20
# ================================================================================
#
# Articles in group:
#   1. [Daily FT] CSE closes early for Ditwah, ends week on the up...
#   2. [Daily FT] Short-end yields drift higher as long end remains anchored...
#   3. [Daily FT] Secondary Bond market activity moderates...
#   4. [Daily FT] CSE falls steeply in Ditwah’s wake, opens December in red...
#   5. [The Island] Flood disaster taking toll on share market...
#   6. [Daily FT] T-Bill auction rates continue to hold broadly steady for 20th straight...
#   7. [Daily FT] Colombo stock market recoups 30% of Monday’s Rs. 240 b value wipe-off...
#   8. [The Morning] CSE turns red from Cyclone Ditwah...
#   9. [Daily FT] Secondary Bond market activity subdued amidst Cyclone Ditwah aftermath...
#   10. [Daily FT] Secondary Bond market activity subdued; yields consolidate...
#   11. [Daily News] CSE ASPI rebounds above 22,000, Gains 439 points amid market recovery...
#   12. [The Morning] ASPI surges past 22,000 amid market recovery...
#   13. [Daily FT] Secondary Bond market yields drop ahead of back-to-back auctions...
#   14. [The Island] Bullish surge on CSE amid signs of post-Ditwah recovery...
#   15. [The Island] Investor worries continue to hamper CSE’s trading vibrancy...
#   16. [The Morning] T-bill auction fully subscribed for first time in months...
#   17. [The Island] Lack of post- Ditwah policy direction snags stock market vibrancy...
#   18. [Daily FT] 364-day Bill weighted average increases by 16bps to 8.19%...
#   19. [The Morning] ASPI drops below 22,000...
#   20. [Daily FT] CSE ends week on the up, ASPI re-enters 22,000-point threshold...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 11,571 tokens (7,673 words)
#    Limit: 4,096 tokens
#    Lost: 7,475 tokens (~64.6% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (195.16s):
# The Trade, Commerce, Food Security and Cooperative Development Ministry yesterday moved to reassure the public that essential food commodities remain available across the country despite temporary disruptions caused by Cyclone Ditwah and the resulting floods. In a statement, the Ministry said: “There is no shortage of essential commodities,” adding that while transportation and distribution channels in several districts had been affected, “replenishment is continuous and in progress.”=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-The Ministry said Government and private sector agencies involved in importation, wholesale, storage, transportation, and retail are working together “to ensure the smooth flow and distribution ofessential commodities, making them available to the public as quickly as possible.“ District-level arrangements have also been put in place to deliver supplies directly to flood-affected areas.Importation and Customs clearance, it noted, are proceeding normally, and “there is now no flood threat to the release of containers from the Customs examination yards.The Government said it is prepared to import additional quantities of any essential good “should a temporary shortage arise,“ while safeguarding the interests of farmers where agricultural products are concerned.ŽuśžŽińżżąŽś ŽujźžĄž Žź ŽęźĆż Žjź‼ńĆ Žoń Ž śź Žēń‼ĆĆ”Žó Žóż ŁśĚŽ“ŽÄź ćź ÇŁĚćĚ ćĺć ćаń ćań ÇĄć,Žeńsń sœżósœć žąćńаŇņńaŇ, Žéńšź sŴńфąsŚą, žńzą sſíą žeć̂ńskń, šſą̇ żečń̇řń.ſſ̅ń ſᴄńâsŴ Že
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# Articles: 20
# ================================================================================
#
# Articles in group:
#   1. [Daily FT] CSE closes early for Ditwah, ends week on the up...
#   2. [Daily FT] Short-end yields drift higher as long end remains anchored...
#   3. [Daily FT] Secondary Bond market activity moderates...
#   4. [Daily FT] CSE falls steeply in Ditwah’s wake, opens December in red...
#   5. [The Island] Flood disaster taking toll on share market...
#   6. [Daily FT] T-Bill auction rates continue to hold broadly steady for 20th straight...
#   7. [Daily FT] Colombo stock market recoups 30% of Monday’s Rs. 240 b value wipe-off...
#   8. [The Morning] CSE turns red from Cyclone Ditwah...
#   9. [Daily FT] Secondary Bond market activity subdued amidst Cyclone Ditwah aftermath...
#   10. [Daily FT] Secondary Bond market activity subdued; yields consolidate...
#   11. [Daily News] CSE ASPI rebounds above 22,000, Gains 439 points amid market recovery...
#   12. [The Morning] ASPI surges past 22,000 amid market recovery...
#   13. [Daily FT] Secondary Bond market yields drop ahead of back-to-back auctions...
#   14. [The Island] Bullish surge on CSE amid signs of post-Ditwah recovery...
#   15. [The Island] Investor worries continue to hamper CSE’s trading vibrancy...
#   16. [The Morning] T-bill auction fully subscribed for first time in months...
#   17. [The Island] Lack of post- Ditwah policy direction snags stock market vibrancy...
#   18. [Daily FT] 364-day Bill weighted average increases by 16bps to 8.19%...
#   19. [The Morning] ASPI drops below 22,000...
#   20. [Daily FT] CSE ends week on the up, ASPI re-enters 22,000-point threshold...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 11,571 tokens (7,673 words)
#    Limit: 4,096 tokens
#    Lost: 7,475 tokens (~64.6% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (197.85s):
# Foreign investment net outflow nears Rs. 5 b in Nov.The Colombo stock market yesterday ended the week on the up after trading closed two hours earlier than the regular 2 p.m. close due to adverse weather conditions caused by cyclone Ditwah. The ASPI ended up 0.35% or 80.37 points to 22,742.46 and the active S&P SL20 gained 0.16% or 10.12 points to 6,278.57. The market closed at 12:30 p.n. yesterday on a turnover of over Rs. 1.9 billion on nearly 63.2 million shares traded. Foreign investors were net sellers with a net outturn of Rs. 326.3 million. Week-on-week, the ASPI was down 1.17% or 269.9 points while the S&Per SL20 declined 1.53% or 97.58 points. Foreigners were net seller in the week with a Rs. 684.35 million net outblow.First Capital Research said despite an early halt in trading, the Colombo Bourse gathered fresh momentum and nudged its way upward. Following a brief downward movement in the beginning of the session, market regained traction towards closing.Key positive contributors to today’s upward movement included BUKI, AEL, BIL, LOLC, and DOCK.The Capital Goods sector accounted for 35.4% of total turnover, followed by Banking and Telecommunication sectors, which collectively contributed 24.1%. Foreign investors remained net sellers, bringing the month-to-date net foreign outflow to Rs. 3.7 billion.The 2027 segment saw the 15.01.27, 01.0527, and 15.09.27 maturities changing hands within 8.30%–8.82%. The share price of Access Engineering increased by Rs. 2.40 to close at Rs. 74 and John Keells Holdings declined by 30 cents to 0. 21.80.The Banking sector was the second highest contributor to the market turnover due to Hatton National Bank, Sampath Bank and Commercial Bank with the sector index decreasing by 3.56%.The 15.03.31 maturity traded at 9.94%, while the 01.06.33 changed hands around 10.45% to 10.76%.In the longer tenors of the market, the weighted average interest rates on call money and repo were recorded within the ranges of 7.94%-7.95% and 7
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# Articles: 19
# ================================================================================
#
# Articles in group:
#   1. [The Morning] Police warns fake news purveyors...
#   2. [The Island] SLAF warns against unauthorised drone operations over cyclone-hit area...
#   3. [The Morning] Fate of disaster orphans: NCPA urges special law...
#   4. [The Morning] Govt. urged public not to share personal details with unauthorised ind...
#   5. [The Morning] Burglaries: Increased mobile patrols, addl. cops deployed...
#   6. [The Morning] Fake relief providers: Don’t give out personal info...
#   7. [Daily FT] NCPA calls on public to report suspicious childcare offers to 1929 hel...
#   8. [The Morning] Ditwah aftermath: Custody determination of affected children underway...
#   9. [The Morning] Child Protection: Ministry registers children orphaned by disasters...
#   10. [Daily News] Ministry cautions against sharing info of children affected by cyclone...
#   11. [The Morning] SL CERT: Vigilance urged over online/social media scams...
#   12. [Daily News] Police warn against individuals attempting to exploit situation target...
#   13. [Daily News] Sri Lanka CERT warns public of rising social media scams...
#   14. [The Island] CERT issues alert on sharp jump in online scams...
#   15. [The Morning] Leaving temporary camp shelters: Family-based housing units starting n...
#   16. [The Morning] Cyclone-Affected Children: Amending DMA considered...
#   17. [The Morning] Cyber intimidation and disruptions...
#   18. [The Morning] Security: CID probes series of false bomb threats...
#   19. [Daily FT] Beware of online scams relating to collection of donations/festive pro...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 7,930 tokens (6,265 words)
#    Limit: 4,096 tokens
#    Lost: 3,834 tokens (~48.3% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (197.85s):
# Foreign investment net outflow nears Rs. 5 b in Nov.The Colombo stock market yesterday ended the week on the up after trading closed two hours earlier than the regular 2 p.m. close due to adverse weather conditions caused by cyclone Ditwah. The ASPI ended up 0.35% or 80.37 points to 22,742.46 and the active S&P SL20 gained 0.16% or 10.12 points to 6,278.57. The market closed at 12:30 p.n. yesterday on a turnover of over Rs. 1.9 billion on nearly 63.2 million shares traded. Foreign investors were net sellers with a net outturn of Rs. 326.3 million. Week-on-week, the ASPI was down 1.17% or 269.9 points while the S&Per SL20 declined 1.53% or 97.58 points. Foreigners were net seller in the week with a Rs. 684.35 million net outblow.First Capital Research said despite an early halt in trading, the Colombo Bourse gathered fresh momentum and nudged its way upward. Following a brief downward movement in the beginning of the session, market regained traction towards closing.Key positive contributors to today’s upward movement included BUKI, AEL, BIL, LOLC, and DOCK.The Capital Goods sector accounted for 35.4% of total turnover, followed by Banking and Telecommunication sectors, which collectively contributed 24.1%. Foreign investors remained net sellers, bringing the month-to-date net foreign outflow to Rs. 3.7 billion.The 2027 segment saw the 15.01.27, 01.0527, and 15.09.27 maturities changing hands within 8.30%–8.82%. The share price of Access Engineering increased by Rs. 2.40 to close at Rs. 74 and John Keells Holdings declined by 30 cents to 0. 21.80.The Banking sector was the second highest contributor to the market turnover due to Hatton National Bank, Sampath Bank and Commercial Bank with the sector index decreasing by 3.56%.The 15.03.31 maturity traded at 9.94%, while the 01.06.33 changed hands around 10.45% to 10.76%.In the longer tenors of the market, the weighted average interest rates on call money and repo were recorded within the ranges of 7.94%-7.95% and 7
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# Articles: 19
# ================================================================================
#
# Articles in group:
#   1. [The Morning] Police warns fake news purveyors...
#   2. [The Island] SLAF warns against unauthorised drone operations over cyclone-hit area...
#   3. [The Morning] Fate of disaster orphans: NCPA urges special law...
#   4. [The Morning] Govt. urged public not to share personal details with unauthorised ind...
#   5. [The Morning] Burglaries: Increased mobile patrols, addl. cops deployed...
#   6. [The Morning] Fake relief providers: Don’t give out personal info...
#   7. [Daily FT] NCPA calls on public to report suspicious childcare offers to 1929 hel...
#   8. [The Morning] Ditwah aftermath: Custody determination of affected children underway...
#   9. [The Morning] Child Protection: Ministry registers children orphaned by disasters...
#   10. [Daily News] Ministry cautions against sharing info of children affected by cyclone...
#   11. [The Morning] SL CERT: Vigilance urged over online/social media scams...
#   12. [Daily News] Police warn against individuals attempting to exploit situation target...
#   13. [Daily News] Sri Lanka CERT warns public of rising social media scams...
#   14. [The Island] CERT issues alert on sharp jump in online scams...
#   15. [The Morning] Leaving temporary camp shelters: Family-based housing units starting n...
#   16. [The Morning] Cyclone-Affected Children: Amending DMA considered...
#   17. [The Morning] Cyber intimidation and disruptions...
#   18. [The Morning] Security: CID probes series of false bomb threats...
#   19. [Daily FT] Beware of online scams relating to collection of donations/festive pro...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 7,930 tokens (6,265 words)
#    Limit: 4,096 tokens
#    Lost: 3,834 tokens (~48.3% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (194.34s):
# The Police have issued a stern warning that the spreading of misinformation will not be tolerated, stating that active investigations are underway and that those found guilty will be dealt with in a court of law.=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-Speaking to The Daily Morning , the Police Media Spokesperson, Assistant Superintendent of Police and attorney F.U. Wootler stated, “We have already received complaints regarding the spread of misinformation and the investigation unit is making inquiries." He cautioned the general public against sharing wrong or misleading information. "You will have to deal with the consequences of your actions," he stated.He further added that a special gazette has been published regarding the matter."If anybody disseminates or publishes any wrongful message, untruthful messages or unreliable messages, and if the public becomes panicked, if they are scared, legal actions are taken by this special Gazette notification which is being investigated by the Criminal Investigation Department."He further stated that the Police have increased mobile patrols and deployed additional officers to vulnerable regions where certain individuals and groups had taken unnecessary advantage of the disaster situation by engaging in house-breakings, unauthorised entries, and the monitoring of private homes.He also stated that any persons who wish to provide proper care and guardianship to raise children who have been left without their guardians due to the Ditwah Cyclone must do so through the proper legal framework of the Sri Lanka’s Child Protection system coming under the supervision of the National Child Protection Authority (NCPA).The CERT called on the public to exercise heightened caution during this period and verify the authenticity of any message, fundraising request, or financial offer that they receive.Any suspicious activity can be reported to the CERT through the hotline or official channels. . The Ministry of Women and Child Affairs has warned the public not to respond to fraudulent messages requesting personal information under the guise of providing relief to those affected by Cyclone Ditweah.It stressed that all official data collection for post-disaster relief is carried out only through District and Divisional Secretariats, supported by field officers and Grama Niladhari officers.The public has been urged to report related concerns to the hotline 1929.The Ministry has asked the public that all officials have been asked to refrain from sharing photographs, video clips, or personal details of children affected by the recent disaster through social media or mainstream media.It has also been asked that the public be vigilant as a result of a surge in social media scams and embezzlement attempts has been observed across social media platforms
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# Articles: 19
# ================================================================================
#
# Articles in group:
#   1. [The Morning] Disaster on two fronts: Can SL’s hospitals handle the storm?...
#   2. [The Morning] Disaster child care advice proffered...
#   3. [Daily FT] WHO provides $ 175,000 emergency funds to scale up health response in ...
#   4. [The Morning] When Ditwah struck: Your health matters more than ever...
#   5. [The Morning] Donations: NMRA urges prior approval for donated supplies...
#   6. [The Morning] Cyclone Ditwah Impact: 33 State hospitals badly damaged...
#   7. [The Morning] Eye diseases spread likely in shelters...
#   8. [Daily News] WHO donates Rs.53Mn for rehabilitation of cyclone-damaged hospitals –D...
#   9. [The Morning] Crisis medicine: Regulator and experts urge coordinated supply...
#   10. [The Island] Lanka unveils world-first simplified dengue early action protocol...
#   11. [The Morning] Flood Response: WHO pledges continued support...
#   12. [The Morning] Health Services: Floods damage imaging equipment...
#   13. [Daily News] WHO pledges support for Sri Lanka’s Priority Health Requests...
#   14. [The Morning] Healthcare during a crisis...
#   15. [The Morning] No disease outbreaks reported post-Ditwah...
#   16. [The Island] Red Cross in action: Tackling dengue across communities...
#   17. [The Morning] Health sector in Ditwah’s wake: Reconstruct with fortitude...
#   18. [The Morning] Health sector suffers Rs. 21 bn loss...
#   19. [Daily News] Cyclone Ditwah inflicts Rs. 21 bn loss on Sri Lanka’s health sector...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 16,993 tokens (12,759 words)
#    Limit: 4,096 tokens
#    Lost: 12,897 tokens (~75.9% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (194.34s):
# The Police have issued a stern warning that the spreading of misinformation will not be tolerated, stating that active investigations are underway and that those found guilty will be dealt with in a court of law.=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-Speaking to The Daily Morning , the Police Media Spokesperson, Assistant Superintendent of Police and attorney F.U. Wootler stated, “We have already received complaints regarding the spread of misinformation and the investigation unit is making inquiries." He cautioned the general public against sharing wrong or misleading information. "You will have to deal with the consequences of your actions," he stated.He further added that a special gazette has been published regarding the matter."If anybody disseminates or publishes any wrongful message, untruthful messages or unreliable messages, and if the public becomes panicked, if they are scared, legal actions are taken by this special Gazette notification which is being investigated by the Criminal Investigation Department."He further stated that the Police have increased mobile patrols and deployed additional officers to vulnerable regions where certain individuals and groups had taken unnecessary advantage of the disaster situation by engaging in house-breakings, unauthorised entries, and the monitoring of private homes.He also stated that any persons who wish to provide proper care and guardianship to raise children who have been left without their guardians due to the Ditwah Cyclone must do so through the proper legal framework of the Sri Lanka’s Child Protection system coming under the supervision of the National Child Protection Authority (NCPA).The CERT called on the public to exercise heightened caution during this period and verify the authenticity of any message, fundraising request, or financial offer that they receive.Any suspicious activity can be reported to the CERT through the hotline or official channels. . The Ministry of Women and Child Affairs has warned the public not to respond to fraudulent messages requesting personal information under the guise of providing relief to those affected by Cyclone Ditweah.It stressed that all official data collection for post-disaster relief is carried out only through District and Divisional Secretariats, supported by field officers and Grama Niladhari officers.The public has been urged to report related concerns to the hotline 1929.The Ministry has asked the public that all officials have been asked to refrain from sharing photographs, video clips, or personal details of children affected by the recent disaster through social media or mainstream media.It has also been asked that the public be vigilant as a result of a surge in social media scams and embezzlement attempts has been observed across social media platforms
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# Articles: 19
# ================================================================================
#
# Articles in group:
#   1. [The Morning] Disaster on two fronts: Can SL’s hospitals handle the storm?...
#   2. [The Morning] Disaster child care advice proffered...
#   3. [Daily FT] WHO provides $ 175,000 emergency funds to scale up health response in ...
#   4. [The Morning] When Ditwah struck: Your health matters more than ever...
#   5. [The Morning] Donations: NMRA urges prior approval for donated supplies...
#   6. [The Morning] Cyclone Ditwah Impact: 33 State hospitals badly damaged...
#   7. [The Morning] Eye diseases spread likely in shelters...
#   8. [Daily News] WHO donates Rs.53Mn for rehabilitation of cyclone-damaged hospitals –D...
#   9. [The Morning] Crisis medicine: Regulator and experts urge coordinated supply...
#   10. [The Island] Lanka unveils world-first simplified dengue early action protocol...
#   11. [The Morning] Flood Response: WHO pledges continued support...
#   12. [The Morning] Health Services: Floods damage imaging equipment...
#   13. [Daily News] WHO pledges support for Sri Lanka’s Priority Health Requests...
#   14. [The Morning] Healthcare during a crisis...
#   15. [The Morning] No disease outbreaks reported post-Ditwah...
#   16. [The Island] Red Cross in action: Tackling dengue across communities...
#   17. [The Morning] Health sector in Ditwah’s wake: Reconstruct with fortitude...
#   18. [The Morning] Health sector suffers Rs. 21 bn loss...
#   19. [Daily News] Cyclone Ditwah inflicts Rs. 21 bn loss on Sri Lanka’s health sector...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 16,993 tokens (12,759 words)
#    Limit: 4,096 tokens
#    Lost: 12,897 tokens (~75.9% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (196.23s):
# 152 Divisional Secretariat Divisions across 20 districts affected; over 78,000 displaced TAMADRAMore than 100 essential medicines in short supply                As floodwaters continue to inundate large parts of the country, the storm-hit communities are facing a second, quieter emergency: a severe shortage of more than100 essential medicines.What began as a national supply issue has now become critical in areas struggling with the effects of Cyclonic Storm Ditwah.�ŽśśążśÄŸńŹżĄż ŽŁś ŽižŇźź Žćń Žаś,Žčń‼ńĆź,žĄ“Ž”Žoś.Žóż.ſń.żó.žiń,żoń:Žaż:żeńsń?żéńšń;żań sńczź;žaś:žàńdź:śaž żăńâż;ſĄęńzźĆ:šařż?žáńósœż, żáдńаž;ŽáżsŴńиżÇŁóś;ţńв.šářsźjźâž:ţaź.ţAżuń żäńużâńaŇ ża’śiżiŹ:ſāńéż” Žādń andżerńüńāż .ŽàŋńSri Lanka Podujana Peramuna (SLPP) MP Namal Rajapaksa also highlighted concerns about the medical sector, saying a growing number of doctors intended to migrate, partly due to unfulfilled promises on vehicle permits and allowances.He questioned why, despite claimed Government savings and increased revenue, State sector professionals, including doctors, had not received the support
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# Articles: 18
# ================================================================================
#
# Articles in group:
#   1. [The Island] Lanka signs USD 100M loan and USD 3M grant agreements with ADB...
#   2. [Daily News] USD 100 million loan assistance and USD 3 million Grant assistance fro...
#   3. [The Morning] Cabinet activates World Bank emergency components for post-Cyclone Dit...
#   4. [Daily FT] ADB grants $ 200 m loan for water, food security in North Central Prov...
#   5. [Daily News] ADB approves $200 Mn loan to boost Mahaweli Water Security and Agricul...
#   6. [The Island] ADB approves $200 million to improve water and food security in North ...
#   7. [The Morning] World Bank provides US$120 mn emergency support for Sri Lanka...
#   8. [Daily FT] World Bank to provide $ 120 m for emergency post-Ditwah spending...
#   9. [Daily News] World Bank to inject US$120 Mn in emergency support to Sri Lanka...
#   10. [The Morning] Cyclone Ditwah Recovery aid: WBG to extend funds to $ 120 m...
#   11. [The Island] WB pledges support for disaster victims in SL...
#   12. [The Morning] ADB provides $40m emergency trade finance to support Sri Lanka post-cy...
#   13. [The Morning] ADB launches $ 40 m financial support for SL...
#   14. [The Island] ADB launches $40m emergency aid for Lanka after Ditwah...
#   15. [Daily FT] ADB supports modern pipe distribution network systems for agriculture ...
#   16. [Daily FT] $ 50 m from World Bank to improve digital services and economy...
#   17. [The Island] Lanka gets US$50 Mn World Bank push for digital government...
#   18. [Daily News] World Bank approves USD 50 Mn to support Lanka’s digital transformatio...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 8,577 tokens (6,468 words)
#    Limit: 4,096 tokens
#    Lost: 4,481 tokens (~52.2% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (196.23s):
# 152 Divisional Secretariat Divisions across 20 districts affected; over 78,000 displaced TAMADRAMore than 100 essential medicines in short supply                As floodwaters continue to inundate large parts of the country, the storm-hit communities are facing a second, quieter emergency: a severe shortage of more than100 essential medicines.What began as a national supply issue has now become critical in areas struggling with the effects of Cyclonic Storm Ditwah.�ŽśśążśÄŸńŹżĄż ŽŁś ŽižŇźź Žćń Žаś,Žčń‼ńĆź,žĄ“Ž”Žoś.Žóż.ſń.żó.žiń,żoń:Žaż:żeńsń?żéńšń;żań sńczź;žaś:žàńdź:śaž żăńâż;ſĄęńzźĆ:šařż?žáńósœż, żáдńаž;ŽáżsŴńиżÇŁóś;ţńв.šářsźjźâž:ţaź.ţAżuń żäńużâńaŇ ża’śiżiŹ:ſāńéż” Žādń andżerńüńāż .ŽàŋńSri Lanka Podujana Peramuna (SLPP) MP Namal Rajapaksa also highlighted concerns about the medical sector, saying a growing number of doctors intended to migrate, partly due to unfulfilled promises on vehicle permits and allowances.He questioned why, despite claimed Government savings and increased revenue, State sector professionals, including doctors, had not received the support
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# Articles: 18
# ================================================================================
#
# Articles in group:
#   1. [The Island] Lanka signs USD 100M loan and USD 3M grant agreements with ADB...
#   2. [Daily News] USD 100 million loan assistance and USD 3 million Grant assistance fro...
#   3. [The Morning] Cabinet activates World Bank emergency components for post-Cyclone Dit...
#   4. [Daily FT] ADB grants $ 200 m loan for water, food security in North Central Prov...
#   5. [Daily News] ADB approves $200 Mn loan to boost Mahaweli Water Security and Agricul...
#   6. [The Island] ADB approves $200 million to improve water and food security in North ...
#   7. [The Morning] World Bank provides US$120 mn emergency support for Sri Lanka...
#   8. [Daily FT] World Bank to provide $ 120 m for emergency post-Ditwah spending...
#   9. [Daily News] World Bank to inject US$120 Mn in emergency support to Sri Lanka...
#   10. [The Morning] Cyclone Ditwah Recovery aid: WBG to extend funds to $ 120 m...
#   11. [The Island] WB pledges support for disaster victims in SL...
#   12. [The Morning] ADB provides $40m emergency trade finance to support Sri Lanka post-cy...
#   13. [The Morning] ADB launches $ 40 m financial support for SL...
#   14. [The Island] ADB launches $40m emergency aid for Lanka after Ditwah...
#   15. [Daily FT] ADB supports modern pipe distribution network systems for agriculture ...
#   16. [Daily FT] $ 50 m from World Bank to improve digital services and economy...
#   17. [The Island] Lanka gets US$50 Mn World Bank push for digital government...
#   18. [Daily News] World Bank approves USD 50 Mn to support Lanka’s digital transformatio...
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 8,577 tokens (6,468 words)
#    Limit: 4,096 tokens
#    Lost: 4,481 tokens (~52.2% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#
# PRIMERA Summary (192.01s):
# The Government of Sri Lanka held discussions with the Asian Development Bank (ADB) to mobilise a policy-based loan, amounting to USD 100 million, to implement the Power Sector Reforms and Financial Sustainability Programme (Subprogram 2).�żśŽśąż ŽńżćŁś ŽĄžń Ž́ń‼ŽĆŽ Žаž žąć Žóćą ŽÄźż ćźć”Žāż фťżаŇń хťć чśińĆ Žеćаń, Žeńsńczńа, žśjąs Žońšń and Žańzń.Žóżs žóń sśnś,žĄs šśíjĄ žeřĆ,Že’s ſeśjsńcń to žøńskń in Žegoś.žójsś and žéjĆ.ſśósœŽsſneńsmś to Žosńskińka in Łóř žíęńcińaž,żeż sžéńksńkństŚ in žjóę Žuś sſíĄć.żéżaŇ žjeęsŏĆ andžiśsŽiņź.Źť Žićnźsť andżiřiŋą.śZsşńsińt.ŭť.Ňóź Žíćkź andţńčń
#
#
# Average processing time: 195.12s
#   ✓ Saved primera topics to cache (primera_topics.json)
#
# PRIMERA Summary (192.01s):
# The Government of Sri Lanka held discussions with the Asian Development Bank (ADB) to mobilise a policy-based loan, amounting to USD 100 million, to implement the Power Sector Reforms and Financial Sustainability Programme (Subprogram 2).�żśŽśąż ŽńżćŁś ŽĄžń Ž́ń‼ŽĆŽ Žаž žąć Žóćą ŽÄźż ćźć”Žāż фťżаŇń хťć чśińĆ Žеćаń, Žeńsńczńа, žśjąs Žońšń and Žańzń.Žóżs žóń sśnś,žĄs šśíjĄ žeřĆ,Že’s ſeśjsńcń to žøńskń in Žegoś.žójsś and žéjĆ.ſśósœŽsſneńsmś to Žosńskińka in Łóř žíęńcińaž,żeż sžéńksńkństŚ in žjóę Žuś sſíĄć.żéżaŇ žjeęsŏĆ andžiśsŽiņź.Źť Žićnźsť andżiřiŋą.śZsşńsińt.ŭť.Ňóź Žíćkź andţńčń
#
#
# Average processing time: 195.12s
#   ✓ Saved primera topics to cache (primera_topics.json)

# %%
# Cell 9: Test LED on topics
if led_topic_results is not None:
    print("✓ LED topic results already loaded from cache - skipping generation")
else:
    print("Testing LED on topic groups...\n")

    # Initialize LED summarizer
    led_config = {
        'method': 'led'
    }
    led = LEDMultiDocSummarizer(led_config)

    led_topic_results = []

    for topic_name, articles in topic_groups.items():
        print(f"\n{'='*80}")
        print(f"Topic: {topic_name}")
        print(f"{'='*80}")
        
        documents = [a['content'] for a in articles]
        sources = [SOURCE_NAMES.get(a['source_id'], a['source_id']) for a in articles]
        
        start_time = time.time()
        summary = led.summarize_multiple(documents, sources)
        processing_time = time.time() - start_time
        
        print(f"LED Summary ({processing_time:.2f}s):")
        print(summary)
        
        led_topic_results.append({
            'group': topic_name,
            'article_count': len(articles),
            'summary': summary,
            'processing_time': processing_time,
            'word_count': led.count_words(summary)
        })

    avg_time = sum(r['processing_time'] for r in led_topic_results) / len(led_topic_results)
    print(f"\n\nAverage processing time: {avg_time:.2f}s")
    
    # Save immediately after generation
    save_cache('led', 'topics', led_topic_results, 
               topic_version_id, topic_version['name'], list(topic_groups.keys()))
# Out:
# Testing LED on topic groups...
# Input ids are automatically padded from 6149 to 7168 to be a multiple of `config.attention_window`: 1024
# Loaded allenai/led-base-16384 on CPU (max 16384 tokens)
#
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# ================================================================================
# Input ids are automatically padded from 11653 to 12288 to be a multiple of `config.attention_window`: 1024
# LED Summary (121.35s):
# [Daily for shortage,000 farmers’ to be affected by drought, drought, floods, and cyclone’s to the extent of food supply, no shortage, no shortages, no stocks, no crops, no supplies, no food supply.[ Daily for shortage of crops, No shortage, food supply and no shortage of food, no lack of supplies, No shortages, any shortage, any shortages, No supply, any food supply or lack of supply. No shortage of vegetables and no shortages of food. No shortages of crops.No shortage of goods, no supply of crops or no shortage.No shortages of vegetables, no need of supplies. No supply of food to be expected, no deliveries, no delays, no disruptions, no floods, no grains, no disasters, no crop, no famine, no drought, no disaster, no shocks, no flooding, no destruction, no disturbances, no damage, no loss of crops and no crops to be caused by drought and no disasters.“No shortage” of crops” Minister of Agriculture, that he explained that there was no shortage in agriculture, no farmers to be harmed, no major crops. No crops to being expected, any crops to been affected by the drought. No crop to be desired, no beans to be allowed, no rice to be distributed, no commodities to be supplied.” He said that he was not aware of any shortage of rice and no grains to be discovered, no growers to be found, no farms to be compensated, no conditions to be known, no foods to be sold, no production to be done, no livestock to be seen, no vegetables to be added to the market, no farming to be corrected, no grain to be released, no milk to be produced, no fruits to be exported, no agriculture to be destroyed, no producers to be notified, no markets to be visited, no agricultural to be told.No farmers to being sold, No farmers to been expected, No crops. no rice, no wheat to be sent to the country.No crop to being supplied, no harvest to be any crops. Livestock and no food to been supplied. No farmers will be affected, no market to be started.No crops to the day, no value to be awarded, no price to be paid, no produce to be delivered, no goods to be received, no new crops to farmers. No production to the year, no cultivation to be anticipated.No food to the days, no problems to be reported
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# Input ids are automatically padded from 8008 to 8192 to be a multiple of `config.attention_window`: 1024
# LED Summary (239.70s):
# [Daily] Bank’s rate of interest rate on top of the previous day‘s market price of Rs50,000, but not as much as expected by the market. On the day of the same, Bank.27% of the market price on top. The Bank. 27% of interest rates on top the previous days’ market price, Rs50.00, but the market was still closed. The market was also closed to the day. The bank. 27.00% of market price was also close to the market, but still closed to market. The Market was closed to a day of trading, but was not closed to any market.The market was closed at the same time as the market is closed.The Bank was closing to the Day of the week, but it was not yet closed to business. The banks were closing to a market price.The bank was closed the market to the same day, but also closed the day to market with the market being closed to no market.On the day after the market closed, the banks were closed to trading, But the bank was closing. The main market of the day was closed by the same price. On top of that market, the Bank was closed on the market with no market closed.On top of this market, The banks closed the Market to the last day, The Bank was close to trading. The shares were closed the same to market on the day before the market closing. On that day, the bank closed the door.On that day the Bank closed the bank. The stock was closed in the market and the banks closed to trade. The rest of the bank’d the market as a result of the following day’ and the last minute of the year. On- top of market, it was closed.[day of the next day, 09.00-to-day) The Bank is closed to B.27, the main market, and the bank is closed, The bank closed to 35.00. The capital market was active. The banking was closed, but on the same days the bank also closed. the bank, the market’t, the same-day of trading.On-day the bank and the Bank were close to market, But it was also closing to business, the markets were closed.To the day: The Bank closed to 10.00 and the markets closed to Market.The banks closed on top-to the first day of business, The market is close to 35%
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# Token indices sequence length is longer than the specified maximum sequence length for this model (17069 > 16384). Running this sequence through the model will result in indexing errors
# LED Summary (154.90s):
# ”[The Ministry’s Department of Public Safety and Civil Protection] is concerned about the lack of information about the public safety and protection of children”, The Ministry of Public Security and Civil Defence is concerned with the following:”We’re concerned about lack of Information about the need to protect children,”The Ministry of public safety, Civil Defence and Civil Defense are concerned about a lack of info about the Public Safety, Civil Defense is concerned over the public Safety and Protection of children.”” We’d been concerned about what happened to children, we’ve been concerned that there was no information about any information about children, We are concerned over what happened, we are concerned that children are not safe, we have been concerned over how to protect the children. We have been worried about what happen to children‛, we were concerned about how to respond to any information that children were not safe. We are also concerned that Children arent safe, We were worried about children being not safe to children.We are concerned with how to prevent the children from being harmed. We were concerned that they were safe.We were concerned with what happened. We had to be concerned that the children were safe to be safe. we were worried that children would be harmed.We also concerned about Children being harmed, We have to be worried about the children being hurt. We need not be concerned with children being harmed in any way.We have been told that children will be harmed, we need to be protected. We will be concerned about them being harmed and we need not to be alarmed. We also concerned with Children being hurt in any other way. We want to be sensitive to the childrens’ needs.We need not Be concerned about childrens being harmed or harmed.“[The ministry of public security and civil defense is concerned by the following] We need to ensure that childrens will be safe to the Childrens” and we will be careful to be helpful. We”t be aware that Childrens are not Safe to be harmed by any other situation. We do not want to see the children harmed, but we are worried about Children” Sri Lanka is concerned.We”s Ministry of Health and civil protection is concerned, We need be concerned over childrens and civil defence. We would be concerned to be aware of the children“We need to help the children to be safer”. We must be concerned for childrens, we must be
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# ⚠️  WARNING: LED truncation detected!
#    Input: 17,069 tokens (12,779 words)
#    Limit: 16,384 tokens
#    Lost: 685 tokens (~4.0% of content)
#    Suggestion: Use Claude/Gemini for inputs >16,384 tokens
# Input ids are automatically padded from 8651 to 9216 to be a multiple of `config.attention_window`: 1024
# LED Summary (358.26s):
# ray health, health, social services, public health, hospitals, and public health departments, along with the rest of the country’s hospitals, social health, education, healthcare, and social health services, all of the above mentioned areas, along health, Health, social care, health and education, all the abovementioned areas, all over the world, along Health, Health and social services. On the other side of the nation, along the same areas, social Health, education and health services. Along health, healthcare and social needs, all around the country, all other areas, none of the aforementioned areas, All over the same as the following areas, Along health and health systems, along on the same side of country, Along the same region, Along Health, health services and socials, along to the same places, All around the same time, along as the same regions, Along with the other countries, along and the same with the following countries, Along to the other regions, along in the same direction, along, socials and Health services, along. Health, Socials, Education, Health are concerned about the lack of medical supplies, all along the way, along along the other areas. Along with that, Along as the necessary areas,Along with the same to the following days, Along in the following weeks, Along and the following years, Along, along at the same moment, along is the same, along was the same. Along the other sectors, Along was the following: Along the following months, along by the same and along the others, Along is also the same: Along, Along. Along and along. Along is the following, Along by the following. Along. along. along the lines of the following day, along a few weeks, along” the same”…”.””On the same day”,”Along the same days” and along with others the following month, Along: Along.Along, along: Along:Along, Along With the following conditions, Along” along.Along. Along,Along. along, Along a few months ago, along are the following events, along- along the right side of a few days, along an order of the same kind, along I”s and the others.“On the contrary”: Along and Along with a few times, along them, along us, Along-related to the health and social systems, Alongside the same sites, along from the same-
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# LED Summary (173.90s):
# [it’s all-rounds] with the help of the private sector, we’re all ready to help the nation. We’ll be able to support the development of the nation with the assistance of the Private sector. We will also help the country with the aid of the public sector, We will help the region with the need to help to the nation, we are all ready for the nation to help.We will also support the Development Bank, lending action to the region, we will be ready to assist the nation and the nation in the need of the region.We’d help the government with the support of the country and the region to help us with the necessary assistance to the country. we will also assist the region in the region and the country to help with the region as well as to the world in need of water and electricity. We are ready to provide the necessary help to Sri Lanka with the expected help to our country.We are allready to help our nation with help to any region, We are able to assist with the nation as well. We need the assistance to our nation and we will provide the help to help them with the needed assistance.We need the help from the region we need to build the necessary infrastructure. We want to help Sri Lanka and the other countries with the anticipated assistance. We also need the support to our region as we are ready for our nation.We also need to provide our nation as we need the necessary resources. We can’t wait for our country to develop.We want the assistance from our region. we want the help we need, we need our nation to develop the country, we want to build our nation, We need to support our region and our country, We want the necessary services.We can help the following:We need to be ready for any region to develop our country as we want. We have to provide to our people with the required assistance. we need help with our region to the extent we can.We must provide the assistance we need. We must be ready with our partners. We all need to work with our country and our people.We have to be prepared for the need for our region, the nation will be the same.We all need the same, we can be ready. We do not need to wait for the moment. We needed to be the assistance, we have to work on our region with our development.We needed the assistance with the development, we needed the help, we must be able
#
#
# Average processing time: 209.62s
#   ✓ Saved led topics to cache (led_topics.json)
# LED Summary (173.90s):
# [it’s all-rounds] with the help of the private sector, we’re all ready to help the nation. We’ll be able to support the development of the nation with the assistance of the Private sector. We will also help the country with the aid of the public sector, We will help the region with the need to help to the nation, we are all ready for the nation to help.We will also support the Development Bank, lending action to the region, we will be ready to assist the nation and the nation in the need of the region.We’d help the government with the support of the country and the region to help us with the necessary assistance to the country. we will also assist the region in the region and the country to help with the region as well as to the world in need of water and electricity. We are ready to provide the necessary help to Sri Lanka with the expected help to our country.We are allready to help our nation with help to any region, We are able to assist with the nation as well. We need the assistance to our nation and we will provide the help to help them with the needed assistance.We need the help from the region we need to build the necessary infrastructure. We want to help Sri Lanka and the other countries with the anticipated assistance. We also need the support to our region as we are ready for our nation.We also need to provide our nation as we need the necessary resources. We can’t wait for our country to develop.We want the assistance from our region. we want the help we need, we need our nation to develop the country, we want to build our nation, We need to support our region and our country, We want the necessary services.We can help the following:We need to be ready for any region to develop our country as we want. We have to provide to our people with the required assistance. we need help with our region to the extent we can.We must provide the assistance we need. We must be ready with our partners. We all need to work with our country and our people.We have to be prepared for the need for our region, the nation will be the same.We all need the same, we can be ready. We do not need to wait for the moment. We needed to be the assistance, we have to work on our region with our development.We needed the assistance with the development, we needed the help, we must be able
#
#
# Average processing time: 209.62s
#   ✓ Saved led topics to cache (led_topics.json)

# %%
# Cell 10: Test LongT5 on topics
if longt5_topic_results is not None:
    print("✓ LongT5 topic results already loaded from cache - skipping generation")
else:
    print("Testing LongT5 on topic groups...\n")

    # Initialize LongT5 summarizer
    longt5_config = {
        'method': 'longt5'
    }
    longt5 = LongT5MultiDocSummarizer(longt5_config)

    longt5_topic_results = []

    for topic_name, articles in topic_groups.items():
        print(f"\n{'='*80}")
        print(f"Topic: {topic_name}")
        print(f"{'='*80}")
        
        documents = [a['content'] for a in articles]
        sources = [SOURCE_NAMES.get(a['source_id'], a['source_id']) for a in articles]
        
        start_time = time.time()
        summary = longt5.summarize_multiple(documents, sources)
        processing_time = time.time() - start_time
        
        print(f"LongT5 Summary ({processing_time:.2f}s):")
        print(summary)
        
        longt5_topic_results.append({
            'group': topic_name,
            'article_count': len(articles),
            'summary': summary,
            'processing_time': processing_time,
            'word_count': longt5.count_words(summary)
        })

    avg_time = sum(r['processing_time'] for r in longt5_topic_results) / len(longt5_topic_results)
    print(f"\n\nAverage processing time: {avg_time:.2f}s")
    
    # Save immediately after generation
    save_cache('longt5', 'topics', longt5_topic_results, 
               topic_version_id, topic_version['name'], list(topic_groups.keys()))
# Out:
# Testing LongT5 on topic groups...
#
# Loaded google/long-t5-tglobal-base on CPU (max 4096 tokens)
#
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 6,421 tokens (4,533 words)
#    Limit: 4,096 tokens
#    Lost: 2,325 tokens (~36.2% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# Loaded google/long-t5-tglobal-base on CPU (max 4096 tokens)
#
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 6,421 tokens (4,533 words)
#    Limit: 4,096 tokens
#    Lost: 2,325 tokens (~36.2% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (139.99s):
# In a statement, the Ministry said: “There is no shortage of essential commodities,” adding that while transportation and distribution channels in several districts had been affected, “replenishment is continuous and in progress.” The Ministry said Government and private sector agencies involved in importation, wholesale, storage, transportation, and retail are working together “to ensure the smooth flow and distribution of essential commodity, making them available to the public as quickly as possible.” District-level arrangements have also been put in place to deliver supplies directly to flood-affected areas. says if prompt measures not taken, SL could face food shortage To implement action plan and commence data gathering/assessments once waters recede The Agriculture Ministry will compensate all cultivators affected by the severe weather conditions and flooding that battered the country, the Deputy Agriculture and Livestock Minister Namal Karunarathne said. [The Morning] Post-disaster crop damage to be assessed to prepare for post-Feb.-2026 period Farmers can report damages to ‘1918’ The Trade, Commerce, and Food Security Ministry stated that there is enough rice in the country for the next few months, and that it would assess the full extent of the flood-related crop damage and prepare for any possible shortages after February of next year (2026). [Daily FT] Agriculture, Livestock, Lands and Irrigation Ministry says no shortages of essential goods Urges public to avoid panic buying and warns traders against unfair practices Flood affected districts receiving direct deliveries through local authorities Importation and Customs clearance continuing without interruption The Ministry yesterday moved to reassure the public that essential food commodities remain available across the country despite temporary disruptions caused by Cyclone Ditwah and the resulting floods. The Ministry also said that “there is now no flood threat to the release of containers from the Customs examination yards.” The Government said it is prepared to import additional quantities of any essential good “should a temporary shortage arise,” while safeguarding the interests of farmers where agricultural products are concerned. The public was urged to avoid stockpiling, with the Ministry warning that “purchasing more than necessary strains the supply chain and risks creating an artificial shortage in the market.” It added that excessive consumer buying could impede relief operations, saying: “We urge everyone to purchase only the quantities required for their daily needs.” The statement also called on traders to maintain ethical conduct, emphasising
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 11,857 tokens (7,694 words)
#    Limit: 4,096 tokens
#    Lost: 7,761 tokens (~65.5% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (139.99s):
# In a statement, the Ministry said: “There is no shortage of essential commodities,” adding that while transportation and distribution channels in several districts had been affected, “replenishment is continuous and in progress.” The Ministry said Government and private sector agencies involved in importation, wholesale, storage, transportation, and retail are working together “to ensure the smooth flow and distribution of essential commodity, making them available to the public as quickly as possible.” District-level arrangements have also been put in place to deliver supplies directly to flood-affected areas. says if prompt measures not taken, SL could face food shortage To implement action plan and commence data gathering/assessments once waters recede The Agriculture Ministry will compensate all cultivators affected by the severe weather conditions and flooding that battered the country, the Deputy Agriculture and Livestock Minister Namal Karunarathne said. [The Morning] Post-disaster crop damage to be assessed to prepare for post-Feb.-2026 period Farmers can report damages to ‘1918’ The Trade, Commerce, and Food Security Ministry stated that there is enough rice in the country for the next few months, and that it would assess the full extent of the flood-related crop damage and prepare for any possible shortages after February of next year (2026). [Daily FT] Agriculture, Livestock, Lands and Irrigation Ministry says no shortages of essential goods Urges public to avoid panic buying and warns traders against unfair practices Flood affected districts receiving direct deliveries through local authorities Importation and Customs clearance continuing without interruption The Ministry yesterday moved to reassure the public that essential food commodities remain available across the country despite temporary disruptions caused by Cyclone Ditwah and the resulting floods. The Ministry also said that “there is now no flood threat to the release of containers from the Customs examination yards.” The Government said it is prepared to import additional quantities of any essential good “should a temporary shortage arise,” while safeguarding the interests of farmers where agricultural products are concerned. The public was urged to avoid stockpiling, with the Ministry warning that “purchasing more than necessary strains the supply chain and risks creating an artificial shortage in the market.” It added that excessive consumer buying could impede relief operations, saying: “We urge everyone to purchase only the quantities required for their daily needs.” The statement also called on traders to maintain ethical conduct, emphasising
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 11,857 tokens (7,694 words)
#    Limit: 4,096 tokens
#    Lost: 7,761 tokens (~65.5% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (147.03s):
# In terms of the secondary Bond market trade summary for the week, the 2026 maturity of 01.06.26 traded at 8.20%, while the 2027 segment saw the 15.01.27, 01.05.27, and 15.09.27 maturities changing hands within 8.30%–8.82%. Those crossings were reported in HNB where 300,000 shares crossed to the tune of Rs 118.5 million, its shares traded at Rs 35, Access Engineering one million shares crossed for Rs 78 million; ts shares trading at Rs 74, JKH t2 million shares crossing to the tun of Rs 43.8 million; its shares sold at Rs 21.80, Commercial Bank 104,000 shares crossed on the tune Rs 20.9 million, Chevron Lubricants 115,000 shares crossed at Rs 20.7 million and Colombo Dockyard 45500 shares crossed the tune on Rs 440. In the retail market top seven companies that mainly contributed to the turnover were; Access Engineering Rs 421 million (5.7 million shares traded), Sampath Bank Rs 250 million (1.8 million shares  traded), HNB Rs 202 million (511,000 shares tradable) Commercial Bank Rs 157 million (835,000 shares traded) Tokyo Cement Rs 156 million (1.7 million shares) Sierra Cables Rs 139 million (4.3 million shares traded) and JkH Rs 137 million (6.3 million shares). By Hiran H Senewiratne [Daily FT] Secondary Bond market activity picks up; rates increase Rupee depreciates further By Wealth Trust Securities The weighted average rates at the weekly Treasury Bill auction conducted yesterday held steady.
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 8,496 tokens (6,285 words)
#    Limit: 4,096 tokens
#    Lost: 4,400 tokens (~51.8% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (147.03s):
# In terms of the secondary Bond market trade summary for the week, the 2026 maturity of 01.06.26 traded at 8.20%, while the 2027 segment saw the 15.01.27, 01.05.27, and 15.09.27 maturities changing hands within 8.30%–8.82%. Those crossings were reported in HNB where 300,000 shares crossed to the tune of Rs 118.5 million, its shares traded at Rs 35, Access Engineering one million shares crossed for Rs 78 million; ts shares trading at Rs 74, JKH t2 million shares crossing to the tun of Rs 43.8 million; its shares sold at Rs 21.80, Commercial Bank 104,000 shares crossed on the tune Rs 20.9 million, Chevron Lubricants 115,000 shares crossed at Rs 20.7 million and Colombo Dockyard 45500 shares crossed the tune on Rs 440. In the retail market top seven companies that mainly contributed to the turnover were; Access Engineering Rs 421 million (5.7 million shares traded), Sampath Bank Rs 250 million (1.8 million shares  traded), HNB Rs 202 million (511,000 shares tradable) Commercial Bank Rs 157 million (835,000 shares traded) Tokyo Cement Rs 156 million (1.7 million shares) Sierra Cables Rs 139 million (4.3 million shares traded) and JkH Rs 137 million (6.3 million shares). By Hiran H Senewiratne [Daily FT] Secondary Bond market activity picks up; rates increase Rupee depreciates further By Wealth Trust Securities The weighted average rates at the weekly Treasury Bill auction conducted yesterday held steady.
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 8,496 tokens (6,285 words)
#    Limit: 4,096 tokens
#    Lost: 4,400 tokens (~51.8% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (147.07s):
# "If anybody disseminates or publishes any wrongful message, untruthful messages or unreliable messages, and if the general public becomes panicked, if they are scared, legal actions are taken by this special Gazette notification which is being investigated by the Criminal Investigation Department." [The Morning] Child Affairs Ministry gathering data on affected children Unless a special law is introduced - similar to the one enacted following the 2004 tsunami for children who lost both their parents or their guardian — children orphaned by the recent floods and landslides that followed Cyclone Ditwah will be placed under the Probation and Child Care Services Department, in accordance with the existing legal provisions in the country. [Daily News] The Sri Lanka Computer Emergency Readiness Team (Sri Lanka CERT) urges the public to remain extremely vigilant as a surge in online scams and embezzlement attempts has been observed across social media platforms in recent weeks, the organisation said in a news release yesterday.
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 18,098 tokens (12,779 words)
#    Limit: 4,096 tokens
#    Lost: 14,002 tokens (~77.4% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (147.07s):
# "If anybody disseminates or publishes any wrongful message, untruthful messages or unreliable messages, and if the general public becomes panicked, if they are scared, legal actions are taken by this special Gazette notification which is being investigated by the Criminal Investigation Department." [The Morning] Child Affairs Ministry gathering data on affected children Unless a special law is introduced - similar to the one enacted following the 2004 tsunami for children who lost both their parents or their guardian — children orphaned by the recent floods and landslides that followed Cyclone Ditwah will be placed under the Probation and Child Care Services Department, in accordance with the existing legal provisions in the country. [Daily News] The Sri Lanka Computer Emergency Readiness Team (Sri Lanka CERT) urges the public to remain extremely vigilant as a surge in online scams and embezzlement attempts has been observed across social media platforms in recent weeks, the organisation said in a news release yesterday.
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 18,098 tokens (12,779 words)
#    Limit: 4,096 tokens
#    Lost: 14,002 tokens (~77.4% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (113.05s):
# According to the Government Medical Officers’ Association (GMOA), hospitals across the country – both State and private – had been reporting shortages of life-saving medicines, including antibiotics, painkillers, insulin, and treatments for chronic conditions such as diabetes, hypertension, cancer, and psychiatric illnesses. [The Morning] Over 275,000 children affected Mothers in centres told to breastfeed babies, provide cooked food, boiled and cooled/bottled water, bury faeces SLMA issues an emergency hotline - 0777119900 – for the public to seek med. To respond to the urgent needs of children and families in the hardest-hit Districts, UNICEF is reportedly scaling up its efforts and appealing for additional funding to provide clean drinking water, essential nutrition supplies, psychosocial support and emergency education kits to displaced children and mothers who need them the most. Rajesh Pandav said, “The funds will be used for rapid response teams to support essential health services for the affected communities, and for strengthening health information management and surveillance, key for timely detection of disease outbreaks to facilitate appropriate response.” Cyclone Ditwah made landfall in Sri Lanka on 28 November, causing unprecedented flooding, landslides, and major infrastructure damage across the county. WHO funding, partly from WHO South-East Asia Regional Health Emergency Fund (SEARHEF), supports operational costs for mobilisation and deployment of Rapid Response medical and public health teams which will deliver trauma/first aid on site, refer individuals for hospital care, attend to pregnant women, children, the elderly, among others.
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 8,858 tokens (6,487 words)
#    Limit: 4,096 tokens
#    Lost: 4,762 tokens (~53.8% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (113.05s):
# According to the Government Medical Officers’ Association (GMOA), hospitals across the country – both State and private – had been reporting shortages of life-saving medicines, including antibiotics, painkillers, insulin, and treatments for chronic conditions such as diabetes, hypertension, cancer, and psychiatric illnesses. [The Morning] Over 275,000 children affected Mothers in centres told to breastfeed babies, provide cooked food, boiled and cooled/bottled water, bury faeces SLMA issues an emergency hotline - 0777119900 – for the public to seek med. To respond to the urgent needs of children and families in the hardest-hit Districts, UNICEF is reportedly scaling up its efforts and appealing for additional funding to provide clean drinking water, essential nutrition supplies, psychosocial support and emergency education kits to displaced children and mothers who need them the most. Rajesh Pandav said, “The funds will be used for rapid response teams to support essential health services for the affected communities, and for strengthening health information management and surveillance, key for timely detection of disease outbreaks to facilitate appropriate response.” Cyclone Ditwah made landfall in Sri Lanka on 28 November, causing unprecedented flooding, landslides, and major infrastructure damage across the county. WHO funding, partly from WHO South-East Asia Regional Health Emergency Fund (SEARHEF), supports operational costs for mobilisation and deployment of Rapid Response medical and public health teams which will deliver trauma/first aid on site, refer individuals for hospital care, attend to pregnant women, children, the elderly, among others.
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 8,858 tokens (6,487 words)
#    Limit: 4,096 tokens
#    Lost: 4,762 tokens (~53.8% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# LongT5 Summary (114.17s):
# Grant proceeds will be used for activities including, but not limited to, emergency rescue equipment, medical supplies and kits, food supplies, water and sanitation systems, transitional shelter materials, hygiene kits, debris-clearance equipment, aviation fuel, and communication equipment. “Higher agricultural productivity and crop diversification are necessary to achieve food security, and adequate water resources and disaster-resilient irrigation systems are key.” The project will complete the Government’s North Central Province Canal (NCPC) irrigation infrastructure, which is expected to irrigate about 14,912 hectares (ha) of paddy fields and provide reliable irrigation water for commercial agriculture development (CAD). The International Finance Corporation (IFC), private sector arm of the World Bank Group, will continue to strengthen the private sector by providing advisory support and strategic investments in key sectors ­– such as agriculture, manufacturing and logistics, including support to MSMEs – to create jobs and drive economic recovery. We commend the remarkable resilience shown by Sri Lankans in the face of this disaster and the Government's swift action to save lives and launch recovery efforts.” To guide recovery efforts, a Global Rapid Post-Disaster Damage Estimation (GRADE) assessment is already underway in partnership with the Global Facility for Disaster Risk Reduction (GFDRR). The World Bank is committed to helping Sri Lanka restore livelihoods, accelerate economic recovery, and rebuild stronger, safer, and more resilient communities.” Looking ahead, the WB Group said it stands ready to work with the Government to mobilise additional resources based on the findings of the GRADE assessment and the financing requirements for recovery and resilient reconstruction.
#
#
# Average processing time: 132.26s
#   ✓ Saved longt5 topics to cache (longt5_topics.json)
# LongT5 Summary (114.17s):
# Grant proceeds will be used for activities including, but not limited to, emergency rescue equipment, medical supplies and kits, food supplies, water and sanitation systems, transitional shelter materials, hygiene kits, debris-clearance equipment, aviation fuel, and communication equipment. “Higher agricultural productivity and crop diversification are necessary to achieve food security, and adequate water resources and disaster-resilient irrigation systems are key.” The project will complete the Government’s North Central Province Canal (NCPC) irrigation infrastructure, which is expected to irrigate about 14,912 hectares (ha) of paddy fields and provide reliable irrigation water for commercial agriculture development (CAD). The International Finance Corporation (IFC), private sector arm of the World Bank Group, will continue to strengthen the private sector by providing advisory support and strategic investments in key sectors ­– such as agriculture, manufacturing and logistics, including support to MSMEs – to create jobs and drive economic recovery. We commend the remarkable resilience shown by Sri Lankans in the face of this disaster and the Government's swift action to save lives and launch recovery efforts.” To guide recovery efforts, a Global Rapid Post-Disaster Damage Estimation (GRADE) assessment is already underway in partnership with the Global Facility for Disaster Risk Reduction (GFDRR). The World Bank is committed to helping Sri Lanka restore livelihoods, accelerate economic recovery, and rebuild stronger, safer, and more resilient communities.” Looking ahead, the WB Group said it stands ready to work with the Government to mobilise additional resources based on the findings of the GRADE assessment and the financing requirements for recovery and resilient reconstruction.
#
#
# Average processing time: 132.26s
#   ✓ Saved longt5 topics to cache (longt5_topics.json)

# %%
# Cell 11: Test OpenAI on topics
if openai_topic_results is not None:
    print("✓ OpenAI topic results already loaded from cache - skipping generation")
else:
    print("Testing OpenAI GPT-4o on topic groups...\n")

    # Initialize OpenAI summarizer
    openai_config = {
        'method': 'openai',
        'llm_model': 'gpt-4o',
        'llm_temperature': 0.0
    }
    openai = OpenAIMultiDocSummarizer(openai_config)

    openai_topic_results = []

    for topic_name, articles in topic_groups.items():
        print(f"\n{'='*80}")
        print(f"Topic: {topic_name}")
        print(f"{'='*80}")
        
        documents = [a['content'] for a in articles]
        sources = [SOURCE_NAMES.get(a['source_id'], a['source_id']) for a in articles]
        
        start_time = time.time()
        summary = openai.summarize_multiple(documents, sources)
        processing_time = time.time() - start_time
        
        print(f"OpenAI Summary ({processing_time:.2f}s):")
        print(summary)
        
        openai_topic_results.append({
            'group': topic_name,
            'article_count': len(articles),
            'summary': summary,
            'processing_time': processing_time,
            'word_count': openai.count_words(summary)
        })

    avg_time = sum(r['processing_time'] for r in openai_topic_results) / len(openai_topic_results)
    print(f"\n\nAverage processing time: {avg_time:.2f}s")
    
    # Save immediately after generation
    save_cache('openai', 'topics', openai_topic_results, 
               topic_version_id, topic_version['name'], list(topic_groups.keys()))
# Out:
# Testing OpenAI GPT-4o on topic groups...
#
#
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# ================================================================================
#
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# ================================================================================
# OpenAI Summary (7.00s):
# In the wake of Cyclone Ditwah, Sri Lanka's government has assured the public that there is no immediate shortage of essential commodities, despite significant agricultural damage. The Trade, Commerce, Food Security, and Cooperative Development Ministry emphasized that importation and distribution channels remain operational, urging the public to avoid panic buying. Meanwhile, the Agriculture Ministry has committed to compensating all affected farmers, extending beyond the usual six crops covered by regulations. The Morning highlighted the severe impact on paddy, maize, and vegetable crops, with over 200,000 hectares damaged, while the Daily News reported compensation efforts totaling over Rs. 381 million for affected farmers. Despite these challenges, Deputy Minister R.M. Jayawardana assured that rice stocks are sufficient for the coming months, though there may be temporary vegetable shortages. The National Agrarian Unity criticized potential vegetable imports, arguing that local production is adequate. Public health concerns have also arisen over attempts to sell flood-affected food items, as reported by The Morning. Overall, while the government is actively addressing the crisis, differing views exist on the adequacy of local food supplies and the need for imports.
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# OpenAI Summary (7.00s):
# In the wake of Cyclone Ditwah, Sri Lanka's government has assured the public that there is no immediate shortage of essential commodities, despite significant agricultural damage. The Trade, Commerce, Food Security, and Cooperative Development Ministry emphasized that importation and distribution channels remain operational, urging the public to avoid panic buying. Meanwhile, the Agriculture Ministry has committed to compensating all affected farmers, extending beyond the usual six crops covered by regulations. The Morning highlighted the severe impact on paddy, maize, and vegetable crops, with over 200,000 hectares damaged, while the Daily News reported compensation efforts totaling over Rs. 381 million for affected farmers. Despite these challenges, Deputy Minister R.M. Jayawardana assured that rice stocks are sufficient for the coming months, though there may be temporary vegetable shortages. The National Agrarian Unity criticized potential vegetable imports, arguing that local production is adequate. Public health concerns have also arisen over attempts to sell flood-affected food items, as reported by The Morning. Overall, while the government is actively addressing the crisis, differing views exist on the adequacy of local food supplies and the need for imports.
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# OpenAI Summary (8.03s):
# The Colombo Stock Exchange (CSE) experienced significant volatility in recent weeks, primarily due to the impact of Cyclone Ditwah. The cyclone led to panic selling and a sharp decline in the All Share Price Index (ASPI), which fell from its all-time high of 23,659.70 points on November 13 to below 22,000 points. The market has since shown signs of recovery, with the ASPI climbing back above 22,000 points, driven by bargain hunting and optimism as the country returns to normalcy. The construction and banking sectors have been key contributors to the market's rebound, with increased interest in stocks like Access Engineering and Tokyo Cement. Despite the recovery, foreign investors have remained net sellers, contributing to a net outflow of funds. The bond market has also been affected, with yields initially rising but later stabilizing as the Central Bank of Sri Lanka maintained its policy rates. The rupee has depreciated against the US dollar, reflecting broader economic concerns. Overall, while the market shows signs of stabilization, uncertainty remains due to the cyclone's economic impact and ongoing global financial conditions.
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# OpenAI Summary (8.03s):
# The Colombo Stock Exchange (CSE) experienced significant volatility in recent weeks, primarily due to the impact of Cyclone Ditwah. The cyclone led to panic selling and a sharp decline in the All Share Price Index (ASPI), which fell from its all-time high of 23,659.70 points on November 13 to below 22,000 points. The market has since shown signs of recovery, with the ASPI climbing back above 22,000 points, driven by bargain hunting and optimism as the country returns to normalcy. The construction and banking sectors have been key contributors to the market's rebound, with increased interest in stocks like Access Engineering and Tokyo Cement. Despite the recovery, foreign investors have remained net sellers, contributing to a net outflow of funds. The bond market has also been affected, with yields initially rising but later stabilizing as the Central Bank of Sri Lanka maintained its policy rates. The rupee has depreciated against the US dollar, reflecting broader economic concerns. Overall, while the market shows signs of stabilization, uncertainty remains due to the cyclone's economic impact and ongoing global financial conditions.
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# OpenAI Summary (8.28s):
# In the wake of Cyclone Ditwah, Sri Lanka faces multiple challenges, including misinformation, scams, and child protection issues. The Police and the Sri Lanka Computer Emergency Readiness Team (CERT) have issued warnings about the spread of misinformation and online scams exploiting the disaster situation. The Police, as reported by The Morning, have increased patrols and are investigating misinformation that has caused public panic, while CERT highlights a surge in online fraud, particularly scams impersonating government and relief agencies. The Island and Daily News emphasize the risks posed by unauthorized drone operations and cyber threats, respectively, which could disrupt relief efforts and national security.
#
# Child protection is a significant concern, with the National Child Protection Authority (NCPA) and the Ministry of Women and Child Affairs focusing on safeguarding children orphaned by the cyclone. The Morning reports that these children are under state protection, with efforts to provide psychosocial support and prevent exploitation. The Daily FT and Daily News highlight the need for legal frameworks to protect vulnerable children and warn against unauthorized adoption offers on social media.
#
# Authorities are also addressing the overcrowding and safety issues in temporary shelters, as noted by The Morning, with plans to move families to more private housing units. The government, supported by international organizations, is working on long-term solutions for affected families. Overall, the response to Cyclone Ditwah involves a coordinated effort to manage misinformation, protect vulnerable populations, and ensure the safety and well-being of those affected.
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# OpenAI Summary (8.28s):
# In the wake of Cyclone Ditwah, Sri Lanka faces multiple challenges, including misinformation, scams, and child protection issues. The Police and the Sri Lanka Computer Emergency Readiness Team (CERT) have issued warnings about the spread of misinformation and online scams exploiting the disaster situation. The Police, as reported by The Morning, have increased patrols and are investigating misinformation that has caused public panic, while CERT highlights a surge in online fraud, particularly scams impersonating government and relief agencies. The Island and Daily News emphasize the risks posed by unauthorized drone operations and cyber threats, respectively, which could disrupt relief efforts and national security.
#
# Child protection is a significant concern, with the National Child Protection Authority (NCPA) and the Ministry of Women and Child Affairs focusing on safeguarding children orphaned by the cyclone. The Morning reports that these children are under state protection, with efforts to provide psychosocial support and prevent exploitation. The Daily FT and Daily News highlight the need for legal frameworks to protect vulnerable children and warn against unauthorized adoption offers on social media.
#
# Authorities are also addressing the overcrowding and safety issues in temporary shelters, as noted by The Morning, with plans to move families to more private housing units. The government, supported by international organizations, is working on long-term solutions for affected families. Overall, the response to Cyclone Ditwah involves a coordinated effort to manage misinformation, protect vulnerable populations, and ensure the safety and well-being of those affected.
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# OpenAI Summary (20.38s):
# Cyclone Ditwah has severely impacted Sri Lanka, causing widespread flooding, landslides, and significant damage to infrastructure, including the health sector. Over 78,000 people have been displaced, with more than 100 essential medicines in short supply, exacerbating the crisis in affected areas. Hospitals in regions like Chilaw, Mahiyangana, and Wattegama have suffered extensive damage, with critical medical equipment destroyed, leading to disrupted services. The World Health Organization (WHO) has provided financial assistance to support the restoration of health services, while international aid from countries like Japan and India is helping establish field hospitals to maintain essential care. The Government Medical Officers’ Association (GMOA) and other health bodies have mobilized resources to address immediate health needs, focusing on preventing disease outbreaks such as dengue and leptospirosis. Despite political disputes over the severity of medicine shortages, health authorities emphasize the importance of rapid procurement and coordinated relief efforts. The cyclone has highlighted vulnerabilities in the health system, prompting calls for resilient infrastructure and improved disaster preparedness.
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# OpenAI Summary (20.38s):
# Cyclone Ditwah has severely impacted Sri Lanka, causing widespread flooding, landslides, and significant damage to infrastructure, including the health sector. Over 78,000 people have been displaced, with more than 100 essential medicines in short supply, exacerbating the crisis in affected areas. Hospitals in regions like Chilaw, Mahiyangana, and Wattegama have suffered extensive damage, with critical medical equipment destroyed, leading to disrupted services. The World Health Organization (WHO) has provided financial assistance to support the restoration of health services, while international aid from countries like Japan and India is helping establish field hospitals to maintain essential care. The Government Medical Officers’ Association (GMOA) and other health bodies have mobilized resources to address immediate health needs, focusing on preventing disease outbreaks such as dengue and leptospirosis. Despite political disputes over the severity of medicine shortages, health authorities emphasize the importance of rapid procurement and coordinated relief efforts. The cyclone has highlighted vulnerabilities in the health system, prompting calls for resilient infrastructure and improved disaster preparedness.
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# OpenAI Summary (18.28s):
# Sri Lanka is actively engaging with international financial institutions to address both immediate and long-term challenges following Cyclone Ditwah. The Asian Development Bank (ADB) and the World Bank are key partners in these efforts. The ADB has approved a $100 million policy-based loan to support power sector reforms and renewable energy development, as reported by The Island and Daily News. Additionally, a $3 million grant from the ADB will aid in emergency response to Cyclone Ditwah, focusing on life-preserving services, as highlighted by The Island. The ADB is also providing a $200 million loan for the Mahaweli Development Program to enhance agricultural resilience, as noted by Daily FT and The Island.
#
# Meanwhile, the World Bank is repurposing $120 million from existing projects to support recovery efforts, including infrastructure restoration and private sector recovery, as detailed by The Morning and Daily FT. The World Bank has also approved a $50 million project to advance Sri Lanka's digital transformation, aiming to modernize government services and foster innovation, as reported by The Island and Daily News. Both institutions emphasize the importance of building resilience and supporting sustainable development in Sri Lanka. While there is consensus on the need for immediate relief and long-term recovery, the sources vary in their emphasis on specific projects and funding allocations.
#
#
# Average processing time: 12.39s
#   ✓ Saved openai topics to cache (openai_topics.json)
# OpenAI Summary (18.28s):
# Sri Lanka is actively engaging with international financial institutions to address both immediate and long-term challenges following Cyclone Ditwah. The Asian Development Bank (ADB) and the World Bank are key partners in these efforts. The ADB has approved a $100 million policy-based loan to support power sector reforms and renewable energy development, as reported by The Island and Daily News. Additionally, a $3 million grant from the ADB will aid in emergency response to Cyclone Ditwah, focusing on life-preserving services, as highlighted by The Island. The ADB is also providing a $200 million loan for the Mahaweli Development Program to enhance agricultural resilience, as noted by Daily FT and The Island.
#
# Meanwhile, the World Bank is repurposing $120 million from existing projects to support recovery efforts, including infrastructure restoration and private sector recovery, as detailed by The Morning and Daily FT. The World Bank has also approved a $50 million project to advance Sri Lanka's digital transformation, aiming to modernize government services and foster innovation, as reported by The Island and Daily News. Both institutions emphasize the importance of building resilience and supporting sustainable development in Sri Lanka. While there is consensus on the need for immediate relief and long-term recovery, the sources vary in their emphasis on specific projects and funding allocations.
#
#
# Average processing time: 12.39s
#   ✓ Saved openai topics to cache (openai_topics.json)

# %%
# Cell 12: Test Gemini on topics
if gemini_topic_results is not None:
    print("✓ Gemini topic results already loaded from cache - skipping generation")
else:
    print("Testing Gemini on topic groups...\n")

    # Initialize Gemini summarizer
    gemini_config = {
        'method': 'gemini',
        'llm_model': 'gemini-2.0-flash',
        'llm_temperature': 0.0
    }
    gemini = GeminiMultiDocSummarizer(gemini_config)

    gemini_topic_results = []

    for topic_name, articles in topic_groups.items():
        print(f"\n{'='*80}")
        print(f"Topic: {topic_name}")
        print(f"{'='*80}")
        
        documents = [a['content'] for a in articles]
        sources = [SOURCE_NAMES.get(a['source_id'], a['source_id']) for a in articles]
        
        start_time = time.time()
        summary = gemini.summarize_multiple(documents, sources)
        processing_time = time.time() - start_time
        
        print(f"Gemini Summary ({processing_time:.2f}s):")
        print(summary)
        
        gemini_topic_results.append({
            'group': topic_name,
            'article_count': len(articles),
            'summary': summary,
            'processing_time': processing_time,
            'word_count': gemini.count_words(summary)
        })

    avg_time = sum(r['processing_time'] for r in gemini_topic_results) / len(gemini_topic_results)
    print(f"\n\nAverage processing time: {avg_time:.2f}s")
    
    # Save immediately after generation
    save_cache('gemini', 'topics', gemini_topic_results, 
               topic_version_id, topic_version['name'], list(topic_groups.keys()))
# Out:
# Testing Gemini on topic groups...
# ================================================================================
# Topic: Deputy, Imports, Recent Extreme Weather, Commodities, Affected Recent
# ================================================================================
# Gemini Summary (3.81s):
# Following Cyclone Ditwah and subsequent flooding, Sri Lanka's agricultural sector has suffered significant damage, with initial estimates suggesting over 200,000 hectares of farmland affected, including substantial paddy field losses. The government, through the Agriculture and Trade Ministries, has assured the public that there is no critical shortage of essential goods, although vegetable prices have seen temporary spikes due to disrupted supply chains. To mitigate potential food shortages, the government is implementing compensation programs for affected farmers, extending support beyond the traditionally covered crops like paddy, maize, and potatoes. Compensation rates vary, with higher amounts allocated for vegetable crop damage to encourage replanting. While some officials express confidence in the ability to recover and replant damaged fields, particularly paddy, others warn of potential shortages of specific rice varieties like Samba and Keeri Samba. The National Agrarian Unity (NAU) disputes the need for imports, claiming sufficient local vegetable production, while public health officials warn against the sale of flood-damaged food items. The government has disbursed millions in compensation to thousands of farmers, with ongoing efforts to process remaining applications.
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# Gemini Summary (3.81s):
# Following Cyclone Ditwah and subsequent flooding, Sri Lanka's agricultural sector has suffered significant damage, with initial estimates suggesting over 200,000 hectares of farmland affected, including substantial paddy field losses. The government, through the Agriculture and Trade Ministries, has assured the public that there is no critical shortage of essential goods, although vegetable prices have seen temporary spikes due to disrupted supply chains. To mitigate potential food shortages, the government is implementing compensation programs for affected farmers, extending support beyond the traditionally covered crops like paddy, maize, and potatoes. Compensation rates vary, with higher amounts allocated for vegetable crop damage to encourage replanting. While some officials express confidence in the ability to recover and replant damaged fields, particularly paddy, others warn of potential shortages of specific rice varieties like Samba and Keeri Samba. The National Agrarian Unity (NAU) disputes the need for imports, claiming sufficient local vegetable production, while public health officials warn against the sale of flood-damaged food items. The government has disbursed millions in compensation to thousands of farmers, with ongoing efforts to process remaining applications.
#
# ================================================================================
# Topic: Sector, Yields, Securities, Wealth, Engineering
# ================================================================================
# Gemini Summary (3.06s):
# Following Cyclone Ditwah, the Colombo Stock Exchange (CSE) experienced significant volatility, initially marked by a sharp decline and panic selling due to concerns about the economic impact, with analysts estimating a potential GDP contraction of 0.5-1% for the next year. The ASPI fell below 22,000 points, reversing a historic bull run. However, the market showed signs of recovery, driven by bargain hunting and renewed investor interest in construction and banking sectors, anticipating rebuilding efforts. Bond yields initially increased, particularly on shorter tenors, but later exhibited mixed movements. Foreign investors were initially net sellers, but later turned net buyers. The rupee depreciated against the US dollar. Treasury bill auctions saw fluctuating demand, with one auction being fully subscribed after a period of undersubscription, while another saw yields increase. Towards the end of the period, positive news regarding potential IMF engagement and external financing from India boosted market confidence, leading to a recovery in bond prices and increased trading volumes.
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# Gemini Summary (3.06s):
# Following Cyclone Ditwah, the Colombo Stock Exchange (CSE) experienced significant volatility, initially marked by a sharp decline and panic selling due to concerns about the economic impact, with analysts estimating a potential GDP contraction of 0.5-1% for the next year. The ASPI fell below 22,000 points, reversing a historic bull run. However, the market showed signs of recovery, driven by bargain hunting and renewed investor interest in construction and banking sectors, anticipating rebuilding efforts. Bond yields initially increased, particularly on shorter tenors, but later exhibited mixed movements. Foreign investors were initially net sellers, but later turned net buyers. The rupee depreciated against the US dollar. Treasury bill auctions saw fluctuating demand, with one auction being fully subscribed after a period of undersubscription, while another saw yields increase. Towards the end of the period, positive news regarding potential IMF engagement and external financing from India boosted market confidence, leading to a recovery in bond prices and increased trading volumes.
#
# ================================================================================
# Topic: Incidents, Affairs, Disruptions, Regarding, Involved
# ================================================================================
# Gemini Summary (2.78s):
# Following Cyclone Ditwah, Sri Lankan authorities are grappling with a surge in fraudulent activities targeting vulnerable populations and exploiting the disaster for financial gain. The Police and the Computer Emergency Readiness Team (CERT) have issued warnings about misinformation, online scams impersonating government and relief organizations, and individuals attempting to exploit children orphaned or displaced by the cyclone. The public is urged to verify information, avoid sharing personal details online, and report suspicious activity to relevant authorities like the NCPA and CERT. Concerns have also been raised about the safety and well-being of those in temporary shelters, with efforts underway to improve conditions and prevent exploitation. The Ministry of Women and Child Affairs is compiling data on affected children and working to ensure their protection through formal legal channels, cautioning against unofficial adoption attempts via social media. The NCPA emphasized that children who lost their parents will remain under state protection until legal procedures are completed. The government is also considering amending the Disaster Management Act to better address the needs of children in disaster situations.
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# Gemini Summary (2.78s):
# Following Cyclone Ditwah, Sri Lankan authorities are grappling with a surge in fraudulent activities targeting vulnerable populations and exploiting the disaster for financial gain. The Police and the Computer Emergency Readiness Team (CERT) have issued warnings about misinformation, online scams impersonating government and relief organizations, and individuals attempting to exploit children orphaned or displaced by the cyclone. The public is urged to verify information, avoid sharing personal details online, and report suspicious activity to relevant authorities like the NCPA and CERT. Concerns have also been raised about the safety and well-being of those in temporary shelters, with efforts underway to improve conditions and prevent exploitation. The Ministry of Women and Child Affairs is compiling data on affected children and working to ensure their protection through formal legal channels, cautioning against unofficial adoption attempts via social media. The NCPA emphasized that children who lost their parents will remain under state protection until legal procedures are completed. The government is also considering amending the Disaster Management Act to better address the needs of children in disaster situations.
#
# ================================================================================
# Topic: Flooding, Flood, Sector, Floodwater, Aftermath
# ================================================================================
# Gemini Summary (4.07s):
# Cyclone Ditwah's devastating impact on Sri Lanka has resulted in widespread flooding, displacement of over 78,000 people, and a severe strain on the nation's healthcare system.  A shortage of over 100 essential medicines, exacerbated by pre-existing supply issues and procurement delays, is critically impacting affected communities.  Hospitals, including those in Chilaw and Mahiyangana, have suffered damage to infrastructure and vital medical equipment, disrupting services and leading to patient referrals.  While the government insists the situation is under control, the opposition claims shortages are worsening, sparking political disputes.  The World Health Organization (WHO) has provided emergency funds and is working with authorities to support essential health services, while countries like India and Japan are providing field hospitals and medical supplies.  The Sri Lanka Medical Association (SLMA) has launched fundraising efforts to rebuild damaged infrastructure and support healthcare workers, emphasizing transparency and climate-resilient construction.  While no disease outbreaks have been reported yet, health authorities are on high alert for waterborne illnesses, and the Sri Lanka Red Cross Society is implementing a dengue prevention protocol.  The total losses to the health sector are estimated at Rs. 21 billion, prompting calls for improved disaster preparedness and resilient infrastructure.
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# Gemini Summary (4.07s):
# Cyclone Ditwah's devastating impact on Sri Lanka has resulted in widespread flooding, displacement of over 78,000 people, and a severe strain on the nation's healthcare system.  A shortage of over 100 essential medicines, exacerbated by pre-existing supply issues and procurement delays, is critically impacting affected communities.  Hospitals, including those in Chilaw and Mahiyangana, have suffered damage to infrastructure and vital medical equipment, disrupting services and leading to patient referrals.  While the government insists the situation is under control, the opposition claims shortages are worsening, sparking political disputes.  The World Health Organization (WHO) has provided emergency funds and is working with authorities to support essential health services, while countries like India and Japan are providing field hospitals and medical supplies.  The Sri Lanka Medical Association (SLMA) has launched fundraising efforts to rebuild damaged infrastructure and support healthcare workers, emphasizing transparency and climate-resilient construction.  While no disease outbreaks have been reported yet, health authorities are on high alert for waterborne illnesses, and the Sri Lanka Red Cross Society is implementing a dengue prevention protocol.  The total losses to the health sector are estimated at Rs. 21 billion, prompting calls for improved disaster preparedness and resilient infrastructure.
#
# ================================================================================
# Topic: Recovery Efforts, Resilience, Economic Recovery, Recovery, Sector
# ================================================================================
# Gemini Summary (3.06s):
# Following the devastation caused by Cyclone Ditwah, Sri Lanka is receiving financial assistance from the Asian Development Bank (ADB) and the World Bank Group. The ADB is providing a $100 million policy-based loan for power sector reforms and a $3 million grant for immediate disaster relief, focusing on essential services and supplies. Additionally, the ADB launched a $40 million emergency assistance facility to finance essential imports like food and medicine, channeled through local banks. The ADB also approved a $3 million grant to address water shortages in the North Western and Uva Provinces by constructing modern pipe distribution network systems. The World Bank Group is providing up to $120 million by repurposing existing project funds to restore essential services and infrastructure in cyclone-affected areas, with the IFC supporting private sector recovery. Furthermore, the World Bank approved a $50 million project to support Sri Lanka's digital transformation, aiming to modernize government services and strengthen the technology sector. The World Bank is also conducting a rapid damage assessment to guide recovery efforts, while the ADB is providing a $200 million loan to support the ongoing Mahaweli Development Program, Sri Lanka’s largest multi-use water resources development initiative.
#
#
# Average processing time: 3.36s
#   ✓ Saved gemini topics to cache (gemini_topics.json)
# Gemini Summary (3.06s):
# Following the devastation caused by Cyclone Ditwah, Sri Lanka is receiving financial assistance from the Asian Development Bank (ADB) and the World Bank Group. The ADB is providing a $100 million policy-based loan for power sector reforms and a $3 million grant for immediate disaster relief, focusing on essential services and supplies. Additionally, the ADB launched a $40 million emergency assistance facility to finance essential imports like food and medicine, channeled through local banks. The ADB also approved a $3 million grant to address water shortages in the North Western and Uva Provinces by constructing modern pipe distribution network systems. The World Bank Group is providing up to $120 million by repurposing existing project funds to restore essential services and infrastructure in cyclone-affected areas, with the IFC supporting private sector recovery. Furthermore, the World Bank approved a $50 million project to support Sri Lanka's digital transformation, aiming to modernize government services and strengthen the technology sector. The World Bank is also conducting a rapid damage assessment to guide recovery efforts, while the ADB is providing a $200 million loan to support the ongoing Mahaweli Development Program, Sri Lanka’s largest multi-use water resources development initiative.
#
#
# Average processing time: 3.36s
#   ✓ Saved gemini topics to cache (gemini_topics.json)

# %%
# Cell 13: Compare topic summaries
print("\nTopic Summaries Comparison\n" + "="*80 + "\n")

# Create comparison dataframe
comparison_data = []
for method_name, results in [
    ('PRIMERA', primera_topic_results),
    ('LED', led_topic_results),
    ('LongT5', longt5_topic_results),
    ('OpenAI', openai_topic_results),
    ('Gemini', gemini_topic_results)
]:
    for result in results:
        comparison_data.append({
            'Method': method_name,
            'Group': result['group'][:30] + '...' if len(result['group']) > 30 else result['group'],
            'Time (s)': f"{result['processing_time']:.2f}",
            'Words': result['word_count'],
            'Articles': result['article_count']
        })

comparison_df = pd.DataFrame(comparison_data)
display(comparison_df)

# Summary statistics
print("\n" + "="*80)
print("Summary Statistics")
print("="*80)
for method in ['PRIMERA', 'LED', 'LongT5', 'OpenAI', 'Gemini']:
    method_data = comparison_df[comparison_df['Method'] == method]
    avg_time = method_data['Time (s)'].astype(float).mean()
    avg_words = method_data['Words'].mean()
    print(f"{method:12s} - Avg time: {avg_time:5.2f}s, Avg words: {avg_words:6.1f}")
# Out:
# Topic Summaries Comparison
# ================================================================================
#      Method                              Group Time (s)  Words  Articles
# 0   PRIMERA  Deputy, Imports, Recent Extrem...   195.16    200        20
# 1   PRIMERA  Sector, Yields, Securities, We...   197.85    318        20
# 2   PRIMERA  Incidents, Affairs, Disruption...   194.34    417        19
# 3   PRIMERA  Flooding, Flood, Sector, Flood...   196.23    130        19
# 4   PRIMERA  Recovery Efforts, Resilience, ...   192.01     79        18
# 5       LED  Deputy, Imports, Recent Extrem...   121.35    396        20
# 6       LED  Sector, Yields, Securities, We...   239.70    393        20
# 7       LED  Incidents, Affairs, Disruption...   154.90    407        19
# 8       LED  Flooding, Flood, Sector, Flood...   358.26    364        19
# 9       LED  Recovery Efforts, Resilience, ...   173.90    435        18
# 10   LongT5  Deputy, Imports, Recent Extrem...   139.99    386        20
# 11   LongT5  Sector, Yields, Securities, We...   147.03    230        20
# 12   LongT5  Incidents, Affairs, Disruption...   147.07    158        19
# 13   LongT5  Flooding, Flood, Sector, Flood...   113.05    237        19
# 14   LongT5  Recovery Efforts, Resilience, ...   114.17    253        18
# 15   OpenAI  Deputy, Imports, Recent Extrem...     7.00    182        20
# 16   OpenAI  Sector, Yields, Securities, We...     8.03    178        20
# 17   OpenAI  Incidents, Affairs, Disruption...     8.28    242        19
# 18   OpenAI  Flooding, Flood, Sector, Flood...    20.38    163        19
# 19   OpenAI  Recovery Efforts, Resilience, ...    18.28    213        18
# 20   Gemini  Deputy, Imports, Recent Extrem...     3.81    177        20
# 21   Gemini  Sector, Yields, Securities, We...     3.06    158        20
# 22   Gemini  Incidents, Affairs, Disruption...     2.78    175        19
# 23   Gemini  Flooding, Flood, Sector, Flood...     4.07    194        19
# 24   Gemini  Recovery Efforts, Resilience, ...     3.06    194        18
# ================================================================================
# Summary Statistics
# ================================================================================
# PRIMERA      - Avg time: 195.12s, Avg words:  228.8
# LED          - Avg time: 209.62s, Avg words:  399.0
# LongT5       - Avg time: 132.26s, Avg words:  252.8
# OpenAI       - Avg time: 12.39s, Avg words:  195.6
# Gemini       - Avg time:  3.36s, Avg words:  179.6

# %% [markdown]
# ## Section 3: Method Comparison on Event Clusters

# %%
# Cell: Load cached cluster results or prepare for fresh generation
print("Loading cluster results from cache...\n")

# Initialize cluster results dictionary
cluster_results_by_method = {
    'PRIMERA': None,
    'LED': None,
    'LongT5': None,
    'OpenAI': None,
    'Gemini': None
}

if USE_CACHE:
    primera_cache = load_cache('primera', 'clusters')
    led_cache = load_cache('led', 'clusters')
    longt5_cache = load_cache('longt5', 'clusters')
    openai_cache = load_cache('openai', 'clusters')
    gemini_cache = load_cache('gemini', 'clusters')
    
    if primera_cache:
        cluster_results_by_method['PRIMERA'] = primera_cache['results']
    if led_cache:
        cluster_results_by_method['LED'] = led_cache['results']
    if longt5_cache:
        cluster_results_by_method['LongT5'] = longt5_cache['results']
    if openai_cache:
        cluster_results_by_method['OpenAI'] = openai_cache['results']
    if gemini_cache:
        cluster_results_by_method['Gemini'] = gemini_cache['results']

# Summary
cached = [m for m, r in cluster_results_by_method.items() if r is not None]
missing = [m for m, r in cluster_results_by_method.items() if r is None]

print(f"\n✓ Cached: {', '.join(cached) if cached else 'None'}")
print(f"✗ Missing (will generate): {', '.join(missing) if missing else 'None'}")
# Out:
# Loading cluster results from cache...
#
#
# ✓ Cached: None
# ✗ Missing (will generate): PRIMERA, LED, LongT5, OpenAI, Gemini

# %%
# Cell 14: Test all methods on event clusters

# Check which methods need generation
methods_to_run = [m for m, r in cluster_results_by_method.items() if r is None]

if not methods_to_run:
    print("✓ All cluster results already loaded from cache - skipping generation")
else:
    print(f"Generating cluster summaries for: {', '.join(methods_to_run)}\n")
    
    # Initialize summarizers only for methods that need generation
    summarizers = {}
    if 'PRIMERA' in methods_to_run:
        summarizers['PRIMERA'] = PRIMERASummarizer({'method': 'primera'})
        cluster_results_by_method['PRIMERA'] = []
    if 'LED' in methods_to_run:
        summarizers['LED'] = LEDMultiDocSummarizer({'method': 'led'})
        cluster_results_by_method['LED'] = []
    if 'LongT5' in methods_to_run:
        summarizers['LongT5'] = LongT5MultiDocSummarizer({'method': 'longt5'})
        cluster_results_by_method['LongT5'] = []
    if 'OpenAI' in methods_to_run:
        summarizers['OpenAI'] = OpenAIMultiDocSummarizer({'method': 'openai', 'llm_model': 'gpt-4o', 'llm_temperature': 0.0})
        cluster_results_by_method['OpenAI'] = []
    if 'Gemini' in methods_to_run:
        summarizers['Gemini'] = GeminiMultiDocSummarizer({'method': 'gemini', 'llm_model': 'gemini-2.0-flash', 'llm_temperature': 0.0})
        cluster_results_by_method['Gemini'] = []

    for cluster_name, articles in cluster_groups.items():
        print(f"\n{'='*80}")
        print(f"Cluster: {cluster_name}")
        print(f"Articles: {len(articles)} from {len(set(a['source_id'] for a in articles))} sources")
        print(f"{'='*80}\n")
        
        # Show article titles
        print("Articles in cluster:")
        for i, article in enumerate(articles):
            source_name = SOURCE_NAMES.get(article['source_id'], article['source_id'])
            print(f"  {i+1}. [{source_name}] {article['title'][:70]}...")
        print()
        
        documents = [a['content'] for a in articles]
        sources = [SOURCE_NAMES.get(a['source_id'], a['source_id']) for a in articles]
        
        # Test each method that needs generation
        for method_name, summarizer in summarizers.items():
            print(f"{method_name}:")
            start_time = time.time()
            summary = summarizer.summarize_multiple(documents, sources)
            processing_time = time.time() - start_time
            
            print(f"  ({processing_time:.2f}s) {summary}")
            print()
            
            cluster_results_by_method[method_name].append({
                'group': cluster_name,
                'article_count': len(articles),
                'summary': summary,
                'processing_time': processing_time,
                'word_count': summarizer.count_words(summary)
            })

    # Save results for each newly generated method
    method_file_map = {'PRIMERA': 'primera', 'LED': 'led', 'LongT5': 'longt5', 'OpenAI': 'openai', 'Gemini': 'gemini'}
    groups_tested = list(cluster_groups.keys())
    
    print("\nSaving cluster results...")
    for method_name in methods_to_run:
        save_cache(method_file_map[method_name], 'clusters', cluster_results_by_method[method_name],
                   clustering_version_id, clustering_version['name'], groups_tested)

    print("\n" + "="*80)
    print("Cluster testing complete")
    print("="*80)
# Out:
# Generating cluster summaries for: PRIMERA, LED, LongT5, OpenAI, Gemini
#
# Loaded allenai/primera on CPU (max 4096 tokens)
# Loaded allenai/primera on CPU (max 4096 tokens)
# Loaded allenai/led-base-16384 on CPU (max 16384 tokens)
# Loaded allenai/led-base-16384 on CPU (max 16384 tokens)
# Loaded google/long-t5-tglobal-base on CPU (max 4096 tokens)
#
# ================================================================================
# Cluster: Sri Lankan economy still vulnerable: IMF
# Articles: 10 from 4 sources
# ================================================================================
#
# Articles in cluster:
#   1. [Daily News] The need for external financing...
#   2. [Daily FT] IMF says hard-won economic gains vulnerable to fresh shocks...
#   3. [The Morning] Budget 2026: Reflections on classical economic thinking...
#   4. [Daily FT] IMF warns debt risks remain high as repayment capacity tightens...
#   5. [The Island] Sri Lankan economy still vulnerable: IMF...
#   6. [Daily News] A reasonable request...
#   7. [Daily FT] Debt relief as disaster relief: A timely call by international experts...
#   8. [The Morning] 2026: Recovery or relapse?...
#   9. [Daily News] MSME Chamber asks the Gov. for financial facilities at low interest ra...
#   10. [Daily News] A nation remade by trial...
#
# PRIMERA:
# Loaded google/long-t5-tglobal-base on CPU (max 4096 tokens)
#
# ================================================================================
# Cluster: Sri Lankan economy still vulnerable: IMF
# Articles: 10 from 4 sources
# ================================================================================
#
# Articles in cluster:
#   1. [Daily News] The need for external financing...
#   2. [Daily FT] IMF says hard-won economic gains vulnerable to fresh shocks...
#   3. [The Morning] Budget 2026: Reflections on classical economic thinking...
#   4. [Daily FT] IMF warns debt risks remain high as repayment capacity tightens...
#   5. [The Island] Sri Lankan economy still vulnerable: IMF...
#   6. [Daily News] A reasonable request...
#   7. [Daily FT] Debt relief as disaster relief: A timely call by international experts...
#   8. [The Morning] 2026: Recovery or relapse?...
#   9. [Daily News] MSME Chamber asks the Gov. for financial facilities at low interest ra...
#   10. [Daily News] A nation remade by trial...
#
# PRIMERA:
# Token indices sequence length is longer than the specified maximum sequence length for this model (12408 > 4096). Running this sequence through the model will result in indexing errors
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 12,408 tokens (9,632 words)
#    Limit: 4,096 tokens
#    Lost: 8,312 tokens (~67.0% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#   (213.25s) In an environment where Sri Lanka is recovering from its third shock in six years, our economy it not capable of withstanding much. The social landscape stands vulnerable as almost 1/4th of Sri Lankan’s live below the middle-income poverty line earning less than Rs. 1100 a day. About 33% of households goes into debt to cover their basic day-to-day needs, such as food, education and medical treatments.The prevailing common theme is pawning jewellery meet regular income needs.A further, quarter of Sri Lanka Lankans are in informal employment.¯¯¯¯The financial landscape is restricted with concerns over debt sustainability. The Government must manage their deficits, and Sri Lanka has to ensure our recurrent import needs does not eat into our reserves. In terms of debt, we have toservice any payment that will fall due from 2025 onwards, and beyond 2028 is when Sri Lanka would approach the period of highest debt repayments until 2038.¯¯¯¯To manage the current debt portfolio feasibly, Sri Lanka needed to achieve economic growth (GDP) of 5%;at least in the near term. The conversation circled around how that number is attainable and how we would reach a stage where the Sri Lanka can ensure a sustainable economic growth of 7%-8%.However, according to number of projections it seemed that, though 5% growth was not far-fetched stimulating the economy was a challenge.For a brief period in 2024 Sri Lanka struggled to energize the economy even after it had stabilized.This probably underlines the deep impact that the 2022 economic crisis had on us.He also noted that the CBSL has already announced measures to support borrowers affected by the disaster and stands ready to provide liquidity support to the financial system if needed.The International Monetary Fund (IMF) on Friday underscored both support and caution as the country seeks emergency assistance under its Rapid Financing Instrument (RFI) in the aftermath of Cyclone Ditwah, warning that the country’‘s hard-won economic recovery remains vulnerable to fresh shocks.That means the economical progress that Sri Lanka made so far is expected to slow down.As discussed above, disruptionsfrom impacted parts around the country and the reduced output will be main reasons for this reduction.However, construction needs required to restore damaged infrastructure maypartially offset the slowdown as construction itself will provide some stimulus for economic activity.“The supplementary budget will help bridge the gap between immediate humanitarian needs and the longer term reconstruction efforts,” Papageorgiou said.He
#
# LED:
#   (213.25s) In an environment where Sri Lanka is recovering from its third shock in six years, our economy it not capable of withstanding much. The social landscape stands vulnerable as almost 1/4th of Sri Lankan’s live below the middle-income poverty line earning less than Rs. 1100 a day. About 33% of households goes into debt to cover their basic day-to-day needs, such as food, education and medical treatments.The prevailing common theme is pawning jewellery meet regular income needs.A further, quarter of Sri Lanka Lankans are in informal employment.¯¯¯¯The financial landscape is restricted with concerns over debt sustainability. The Government must manage their deficits, and Sri Lanka has to ensure our recurrent import needs does not eat into our reserves. In terms of debt, we have toservice any payment that will fall due from 2025 onwards, and beyond 2028 is when Sri Lanka would approach the period of highest debt repayments until 2038.¯¯¯¯To manage the current debt portfolio feasibly, Sri Lanka needed to achieve economic growth (GDP) of 5%;at least in the near term. The conversation circled around how that number is attainable and how we would reach a stage where the Sri Lanka can ensure a sustainable economic growth of 7%-8%.However, according to number of projections it seemed that, though 5% growth was not far-fetched stimulating the economy was a challenge.For a brief period in 2024 Sri Lanka struggled to energize the economy even after it had stabilized.This probably underlines the deep impact that the 2022 economic crisis had on us.He also noted that the CBSL has already announced measures to support borrowers affected by the disaster and stands ready to provide liquidity support to the financial system if needed.The International Monetary Fund (IMF) on Friday underscored both support and caution as the country seeks emergency assistance under its Rapid Financing Instrument (RFI) in the aftermath of Cyclone Ditwah, warning that the country’‘s hard-won economic recovery remains vulnerable to fresh shocks.That means the economical progress that Sri Lanka made so far is expected to slow down.As discussed above, disruptionsfrom impacted parts around the country and the reduced output will be main reasons for this reduction.However, construction needs required to restore damaged infrastructure maypartially offset the slowdown as construction itself will provide some stimulus for economic activity.“The supplementary budget will help bridge the gap between immediate humanitarian needs and the longer term reconstruction efforts,” Papageorgiou said.He
#
# LED:
# Input ids are automatically padded from 12450 to 13312 to be a multiple of `config.attention_window`: 1024
#   (273.33s) “We’re not sure how much we’ll be able to recover from this crisis.” We are not sure whether we will be expected to recover. We’ve been told that we will not be required to rebuild the economy.We are not certain whether we can recover from the current crisis. We will be expecting to recover the economy from this year’s recession. We are expected to be needed to rebuild. We have been told to recover to the economy, but we are not expected to rebuild it.We will be assured that the economy will recover from these years’ recession.We have been assured that we would not be necessary to rebuild our economy. We would be expecting the economy to recover but we will still need to rebuild to the extent possible. We need to recover our economy from the recession. we will also be expected that the economic recovery will be gradual.We need not be expected the economic growth to recover, we need not to rebuild but we need to be ready to recover soon. We want to recover and recover our economic growth. We also need to wait for the next crisis.We can’t expect to recover much from this years recession. The economic recovery is expected to progress but we still need not rebuild.We must be expected not to recover quickly. We do not want to rebuild ourselves but we must be ready. We must be prepared to rebuild and recover.We also need not wait to recover any time. The economy will not recover from any years. We can not rebuild our economic recovery but we have to be prepared for the following years.WE need not recover quickly, we must not rebuild ourselves. We should be ready for the future. We cannot recover quickly but we do not need to.We do not expect to rebuild any time soon.We want not to be expected of the following year.We cannot recover the economic crisis but we can be expected. We were expected to return to recovery. We needed not to wait.We were expecting to be the same thing. We expected the economy would recover.WE have been expected to respond to the current situation. We expect to be recovering to the next year.WE will be the only way to rebuild, we are expected the same.We would be the first time to recover recoveries, we will have to wait until the last year. We still need the stability of the economy and we will need to respond.We expected to the situation to be critical to the recovery.We expect the economy not to
#
# LongT5:
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 13,153 tokens (9,643 words)
#    Limit: 4,096 tokens
#    Lost: 9,057 tokens (~68.9% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#   (143.51s) About 33% of households goes into debt to cover their basic day-to-day needs, such as food, education and medical treatments.The prevailing common theme is pawning jewellery meet regular income needs.A further, quarter of Sri Lankans are in informal employment. Email: ranjulamanchanayake@gmail.com) [Daily FT] IMF Mission Chief for Sri Lanka Evan Papageorgiou says fresh funds aimed at bridging humanitarian relief and long-term reconstruction Identifies agriculture and tourism as most exposed sectors Expects inflation risks and widening current account deficit in short term Says Fifth EFF Review deferred; IMF mission planned for early 2026 Insists on transparent, well-targeted emergency spending Calls on CBSL to maintain monetary discipline and avoid money financing Reaffirms commitment to protecting Sri Lanka’s hard-won gains By Charumini de Silva mission chief for Sri lanka evan papegociou The International Monetary Fund (IMF) on Friday underscored both support and caution as the country seeks emergency assistance under its Rapid Financing Instrument (RFI) in the aftermath of Cyclone Ditwah, warning that the country’s tough economic recovery remains vulnerable to fresh shocks. “These include a robust economic recovery, price stability, and progress in rebuilding foreign exchange reserves,” he said, adding that revenue-based fiscal consolidation and public financial management reforms have strengthened fiscal discipline and reduced risks. He reiterated that the core objectives of the IMF-supported program remain unchanged: restoring fiscal and debt sustainability while protecting the vulnerable, safeguarding price and financial sector stability, rebuilding external buffers, strengthening governance, and advancing growth-oriented structural reforms. The Budget framework reflects classical economic thinking, similar to Scottish economist Adam Smith’s view that Governments should maintain fiscal discipline, minimise debt, and allow private enterprise to drive economic growth (An Inquiry into the Nature and Causes of the Wealth of Nations. This strategy depends on private-sector-led investment and growth, attracting foreign direct investment (FDI), modernising State-owned enterprises (SOEs), and promoting export-driven economic expansion. The writer is an economist and researcher in trade, investment and capital markets --------- The views and opinions expressed in this column are those of the
#
# OpenAI:
#   (143.51s) About 33% of households goes into debt to cover their basic day-to-day needs, such as food, education and medical treatments.The prevailing common theme is pawning jewellery meet regular income needs.A further, quarter of Sri Lankans are in informal employment. Email: ranjulamanchanayake@gmail.com) [Daily FT] IMF Mission Chief for Sri Lanka Evan Papageorgiou says fresh funds aimed at bridging humanitarian relief and long-term reconstruction Identifies agriculture and tourism as most exposed sectors Expects inflation risks and widening current account deficit in short term Says Fifth EFF Review deferred; IMF mission planned for early 2026 Insists on transparent, well-targeted emergency spending Calls on CBSL to maintain monetary discipline and avoid money financing Reaffirms commitment to protecting Sri Lanka’s hard-won gains By Charumini de Silva mission chief for Sri lanka evan papegociou The International Monetary Fund (IMF) on Friday underscored both support and caution as the country seeks emergency assistance under its Rapid Financing Instrument (RFI) in the aftermath of Cyclone Ditwah, warning that the country’s tough economic recovery remains vulnerable to fresh shocks. “These include a robust economic recovery, price stability, and progress in rebuilding foreign exchange reserves,” he said, adding that revenue-based fiscal consolidation and public financial management reforms have strengthened fiscal discipline and reduced risks. He reiterated that the core objectives of the IMF-supported program remain unchanged: restoring fiscal and debt sustainability while protecting the vulnerable, safeguarding price and financial sector stability, rebuilding external buffers, strengthening governance, and advancing growth-oriented structural reforms. The Budget framework reflects classical economic thinking, similar to Scottish economist Adam Smith’s view that Governments should maintain fiscal discipline, minimise debt, and allow private enterprise to drive economic growth (An Inquiry into the Nature and Causes of the Wealth of Nations. This strategy depends on private-sector-led investment and growth, attracting foreign direct investment (FDI), modernising State-owned enterprises (SOEs), and promoting export-driven economic expansion. The writer is an economist and researcher in trade, investment and capital markets --------- The views and opinions expressed in this column are those of the
#
# OpenAI:
#   (8.87s) Sri Lanka is grappling with significant economic challenges following Cyclone Ditwah, which has exacerbated the country's fragile recovery from a severe economic crisis. The cyclone has caused extensive damage, estimated at $4.1 billion, affecting infrastructure, agriculture, and livelihoods, and has led to calls for debt repayment suspension from global economists, including Nobel laureate Joseph Stiglitz. The International Monetary Fund (IMF) has provided emergency financial support under its Rapid Financing Instrument (RFI) to address immediate needs, but warns that Sri Lanka's economic recovery remains vulnerable to further shocks. The IMF emphasizes the importance of fiscal discipline and structural reforms to maintain debt sustainability and support reconstruction efforts.
#
# The Daily News highlights the cyclone's impact on poverty and informal employment, stressing the need for targeted social support and local production to aid recovery. The Daily FT underscores the IMF's role in stabilizing the economy and the necessity of transparent emergency spending. The Morning praises the government's continuity in economic policies and notes the progress in macroeconomic stability, while also acknowledging the cyclone's disruption to key sectors like agriculture and tourism. The Island emphasizes the humanitarian and fiscal pressures created by the disaster, urging adherence to fiscal rules and governance standards.
#
# Overall, while there is consensus on the need for international support and domestic reforms, opinions differ on the adequacy of current measures and the potential for long-term recovery. The situation calls for a balanced approach that prioritizes immediate relief and sustainable economic growth, with a focus on strengthening trade partnerships and diversifying exports.
#
# Gemini:
#   (8.87s) Sri Lanka is grappling with significant economic challenges following Cyclone Ditwah, which has exacerbated the country's fragile recovery from a severe economic crisis. The cyclone has caused extensive damage, estimated at $4.1 billion, affecting infrastructure, agriculture, and livelihoods, and has led to calls for debt repayment suspension from global economists, including Nobel laureate Joseph Stiglitz. The International Monetary Fund (IMF) has provided emergency financial support under its Rapid Financing Instrument (RFI) to address immediate needs, but warns that Sri Lanka's economic recovery remains vulnerable to further shocks. The IMF emphasizes the importance of fiscal discipline and structural reforms to maintain debt sustainability and support reconstruction efforts.
#
# The Daily News highlights the cyclone's impact on poverty and informal employment, stressing the need for targeted social support and local production to aid recovery. The Daily FT underscores the IMF's role in stabilizing the economy and the necessity of transparent emergency spending. The Morning praises the government's continuity in economic policies and notes the progress in macroeconomic stability, while also acknowledging the cyclone's disruption to key sectors like agriculture and tourism. The Island emphasizes the humanitarian and fiscal pressures created by the disaster, urging adherence to fiscal rules and governance standards.
#
# Overall, while there is consensus on the need for international support and domestic reforms, opinions differ on the adequacy of current measures and the potential for long-term recovery. The situation calls for a balanced approach that prioritizes immediate relief and sustainable economic growth, with a focus on strengthening trade partnerships and diversifying exports.
#
# Gemini:
# Input ids are automatically padded from 2667 to 3072 to be a multiple of `config.attention_window`: 512
#   (3.37s) Sri Lanka faces significant economic challenges following Cyclone Ditwah, which has exacerbated existing vulnerabilities despite recent macroeconomic stabilization. While GDP grew in 2024 and early 2025, projections indicate a slowdown in 2026 due to the cyclone's impact on key sectors like agriculture and tourism. The IMF has provided emergency financial support, but stresses the need for transparent and well-targeted spending, urging adherence to fiscal discipline. Several sources highlight the potential for increased inflation and a widening current account deficit. Some economists are calling for a suspension of Sri Lanka's debt repayments to provide crucial fiscal space for recovery efforts, while others emphasize the importance of continued structural reforms and private sector-led growth. The long-term economic impact of Ditwah is estimated to be substantial, potentially increasing poverty and requiring significant reconstruction costs. The MSME sector is requesting low interest rates to make new investments and empower small and medium scale entrepreneurs who were devastated by Cyclone Ditwah. The country's capacity to repay the IMF has weakened temporarily compared with Fourth Review.
#
#
# ================================================================================
# Cluster: Two financial contributions received for the ‘Rebuilding Sri Lanka’
# Articles: 10 from 4 sources
# ================================================================================
#
# Articles in cluster:
#   1. [Daily News] Business community extends support to “Rebuild Sri Lanka” fund...
#   2. [Daily News] Multiple Financial contributions to ‘Rebuilding Sri Lanka’ Fund...
#   3. [Daily News] People’s Leasing Group donates Rs. 10 Mn to ‘Rebuilding Sri Lanka’ Fun...
#   4. [Daily News] ‘Rebuilding Sri Lanka’ Fund receives over Rs. 4.2 billion in disaster ...
#   5. [Daily News] Two financial contributions received for the ‘Rebuilding Sri Lanka’...
#   6. [The Island] Financial contributions received for ‘Rebuilding Sri Lanka’ Fund...
#   7. [Daily News] ComBank’s Cyclone Ditwah recovery support crosses Rs. 125Mn...
#   8. [Daily FT] Several private companies donate to ‘Rebuilding Sri Lanka’...
#   9. [The Morning] Rebuilding Sri Lanka: Estate workers donate one-day salary...
#   10. [Daily FT] ’’Rebuilding Sri Lanka’’ Fund gets Rs. 14.1 m in support...
#
# PRIMERA:
# Input ids are automatically padded from 2707 to 3072 to be a multiple of `config.attention_window`: 1024
#   (155.51s) A group of businessmen has extended support to the “Rebuild Sri Lanka” programme by handing over their donations to the Minister of Agriculture, Livestock, Lands and Irrigation, K.D. Lalkantha, at a special event.¯¯¯¯.Kandy Spices Agro (Pvt) Ltd donated Rs. 4 million, while the Minindoru Association contributed Rs. 1 million towards the initiative. In addition, Orange donated electrical equipment valued at over Rs. 15 million, targeting the Badulla, Nuwara Eliya and Kandy districts.Addressing the gathering, Minister K. D.Lalkantha urged the public and the business community to continue supporting the Rebuild Sri Lanka programme, assuring that the government is utilizing these funds responsibly and transparently.“During the cyclone, the general public came forward voluntarily to help. This sense of solidarity is part of our DNA and is not commonly seen in some other countries. Today, we are gradually recovering and breathing a sigh of relief from this disaster,” the Minister said.Several government officials from the Kandy District were also present at the event.
#
# LED:
#   (48.18s) clone Ditwah the group of businessmen has extended to be distributed by the Sri Lanka Air Force among more than 5,000 flood-affected families. In support of business recovery, and following the announcement of relief from the Cyclone, a total of Rs. 1 million. In addition to the more than 4 million, local businessmen, for disaster-affected, received through direct foreign currency deposits. Sri Lanka Spices Agro and resume operations. USDThe Bank has also supported, while Disaster Management Centre alone sponsoring the contributed over of USD. 6 million. The Finance Data expressed to strengthen national overwhelming risk management capabilities, over Rs. 15 million and targeting the key stakeholders of the country.In addition, social responsibility has been received from Eliya supported Kandy districts, school, hospitals, hospitals and hospitals, the Government of Canada, Australia, China, the UK, Germany, Italy, Bhutan the public and the business community to continue supporting the government of Sri Lanka.In the event of the cyclone, the President of the Government and the Ministry of Finance and the Government’s Media Division has said that daily contributions are being made by the Government.“During the storm, the government has been handed over to the Disaster management Centre for distribution voluntarily to help.”Dr. Suriyapper of our DNA and D have been seen in some other countries. Today, financial donations to recovering and breathing the President also noted from this disaster multilateral Kumanay said at the Presidential Secretariat. The President, President, the Presidential government officials, and The Kandy, as additional support to rebuild the country from Cyclone.The Government of the Maldives and Sri Lanka has been provided with the assistance of the government. In fact, in addition, Sri Lanka’ debt and Rs. 2.5 million each (OCC) Gold Centre its Committee’ed to the President. The Government of Maldives has been given to the government, and the country in., Chairman of Cyclone has now restructured Ramesh. The government of the Republic of Maldivian has been providing the Government with the help of the Federal Government. The Federal Government has also provided the government with the support from Nandawa Sanath, Dr. Nihal and international institutions as “heartwarming,” and emphasized that the government will provide the country rebuild and support citizens affected by floods, The donation was handed over, Rs. 10 million People.G.S.[Daily News] The Government Eliya’
#
# LongT5:
#   (48.18s) clone Ditwah the group of businessmen has extended to be distributed by the Sri Lanka Air Force among more than 5,000 flood-affected families. In support of business recovery, and following the announcement of relief from the Cyclone, a total of Rs. 1 million. In addition to the more than 4 million, local businessmen, for disaster-affected, received through direct foreign currency deposits. Sri Lanka Spices Agro and resume operations. USDThe Bank has also supported, while Disaster Management Centre alone sponsoring the contributed over of USD. 6 million. The Finance Data expressed to strengthen national overwhelming risk management capabilities, over Rs. 15 million and targeting the key stakeholders of the country.In addition, social responsibility has been received from Eliya supported Kandy districts, school, hospitals, hospitals and hospitals, the Government of Canada, Australia, China, the UK, Germany, Italy, Bhutan the public and the business community to continue supporting the government of Sri Lanka.In the event of the cyclone, the President of the Government and the Ministry of Finance and the Government’s Media Division has said that daily contributions are being made by the Government.“During the storm, the government has been handed over to the Disaster management Centre for distribution voluntarily to help.”Dr. Suriyapper of our DNA and D have been seen in some other countries. Today, financial donations to recovering and breathing the President also noted from this disaster multilateral Kumanay said at the Presidential Secretariat. The President, President, the Presidential government officials, and The Kandy, as additional support to rebuild the country from Cyclone.The Government of the Maldives and Sri Lanka has been provided with the assistance of the government. In fact, in addition, Sri Lanka’ debt and Rs. 2.5 million each (OCC) Gold Centre its Committee’ed to the President. The Government of Maldives has been given to the government, and the country in., Chairman of Cyclone has now restructured Ramesh. The government of the Republic of Maldivian has been providing the Government with the help of the Federal Government. The Federal Government has also provided the government with the support from Nandawa Sanath, Dr. Nihal and international institutions as “heartwarming,” and emphasized that the government will provide the country rebuild and support citizens affected by floods, The donation was handed over, Rs. 10 million People.G.S.[Daily News] The Government Eliya’
#
# LongT5:
#   (120.11s) [Daily News] Financial contributions from local and international institutions and philanthropists continue to be received daily by the Government’s ‘Rebuilding Sri Lanka’ Fund, established to restore livelihoods and rebuild the country in the aftermath of Cyclone Ditwah. As key initiative under the aforementioned community projects and demonstrating its strong commitment to supporting national recovery and development, People’s Leasing group has presented Rs.10 million to the ‘Re building Sri Lanka Fund’ on December 11, 2025, at the Presidential Secretariat, where Sanjeewa Bandaranayake, Chief Executive Officer/General Manager of People’ Leasing, handed over the cheque to Dr. Through these programmes ranging from national level support initiatives to immediate on the ground assistance for affected communities and dedicated welfare measures for PLC employees, PLC Group reaffirms its deep-rooted commitment to standing hand in hand with the wider Sri Lankan community. As part of a series of relief measures under its ‘Rebuild Together’ theme, demonstrating it’s commitment to stand with Sri Lanka when it matters the most, the Commercial Bank of Ceylon on December 22, announced a total commitment exceeding Rs. The Bank has also supported the Disaster Management Centre by sponsoring the revamp of the RiskInfo Spatial Data Portal to strengthen national disaster risk management capabilities. Additionally, with education long recognised as a key corporate social responsibility priority, Commercial Bank supported children in returning to school by facilitating the clean-up of affected schools and providing essential stationery supplies following Cyclotwath. [The Morning] Workers from the N.C. section of the Kotiyagala Estate in Bogawantalawa donated Rs. 10 million, W.J. Priyantha, on behalf of the Irrigation Engineering Diplomates Association, contributed Rs. 1 million and Sciences & Information Technology City Campus CEO Cader Rahmathulla, donated Rs 1.1 million. The relevant cheques were handed over to the Secretary to the President, Dr. Nandika Sanath Kumanayaka, last week. The donations were as follows: Rs. 5 million from Sirilak Sea Food Ltd, Managing Director D.A. Nissanka, and Rs. 2.5 million each from Narmatha Gold Centre Chairman N. Jegatheeswaran, and IWW Steel Industries Ltd., Chairman Dr. Sival
#
# OpenAI:
#   (120.11s) [Daily News] Financial contributions from local and international institutions and philanthropists continue to be received daily by the Government’s ‘Rebuilding Sri Lanka’ Fund, established to restore livelihoods and rebuild the country in the aftermath of Cyclone Ditwah. As key initiative under the aforementioned community projects and demonstrating its strong commitment to supporting national recovery and development, People’s Leasing group has presented Rs.10 million to the ‘Re building Sri Lanka Fund’ on December 11, 2025, at the Presidential Secretariat, where Sanjeewa Bandaranayake, Chief Executive Officer/General Manager of People’ Leasing, handed over the cheque to Dr. Through these programmes ranging from national level support initiatives to immediate on the ground assistance for affected communities and dedicated welfare measures for PLC employees, PLC Group reaffirms its deep-rooted commitment to standing hand in hand with the wider Sri Lankan community. As part of a series of relief measures under its ‘Rebuild Together’ theme, demonstrating it’s commitment to stand with Sri Lanka when it matters the most, the Commercial Bank of Ceylon on December 22, announced a total commitment exceeding Rs. The Bank has also supported the Disaster Management Centre by sponsoring the revamp of the RiskInfo Spatial Data Portal to strengthen national disaster risk management capabilities. Additionally, with education long recognised as a key corporate social responsibility priority, Commercial Bank supported children in returning to school by facilitating the clean-up of affected schools and providing essential stationery supplies following Cyclotwath. [The Morning] Workers from the N.C. section of the Kotiyagala Estate in Bogawantalawa donated Rs. 10 million, W.J. Priyantha, on behalf of the Irrigation Engineering Diplomates Association, contributed Rs. 1 million and Sciences & Information Technology City Campus CEO Cader Rahmathulla, donated Rs 1.1 million. The relevant cheques were handed over to the Secretary to the President, Dr. Nandika Sanath Kumanayaka, last week. The donations were as follows: Rs. 5 million from Sirilak Sea Food Ltd, Managing Director D.A. Nissanka, and Rs. 2.5 million each from Narmatha Gold Centre Chairman N. Jegatheeswaran, and IWW Steel Industries Ltd., Chairman Dr. Sival
#
# OpenAI:
#   (6.54s) The "Rebuild Sri Lanka" initiative, established in response to Cyclone Ditwah, has garnered substantial support from both local and international donors. The fund, aimed at restoring livelihoods and rebuilding infrastructure, has received over Rs. 4,286 million, with significant contributions from local businesses and foreign entities. Notable donations include Rs. 110 million from the Commercial Bank of Ceylon and Rs. 20 million from Super Feed (Pvt) Ltd. The Daily News highlights the government's emphasis on transparency and responsible fund utilization, as articulated by Minister K.D. Lalkantha. Meanwhile, the Finance Secretary, Dr. Harshana Suriyapperuma, expressed gratitude for the global support, noting contributions from 43 countries. The People's Leasing & Finance PLC has also been proactive, not only donating Rs. 10 million but also launching community projects and a hotline for affected individuals. The Island and Daily FT report on various corporate and community contributions, underscoring a collective effort to aid recovery. While all sources agree on the importance of the fund, the Daily News and The Island emphasize the role of local businesses, whereas The Morning highlights grassroots contributions, such as those from estate workers.
#
# Gemini:
#   (6.54s) The "Rebuild Sri Lanka" initiative, established in response to Cyclone Ditwah, has garnered substantial support from both local and international donors. The fund, aimed at restoring livelihoods and rebuilding infrastructure, has received over Rs. 4,286 million, with significant contributions from local businesses and foreign entities. Notable donations include Rs. 110 million from the Commercial Bank of Ceylon and Rs. 20 million from Super Feed (Pvt) Ltd. The Daily News highlights the government's emphasis on transparency and responsible fund utilization, as articulated by Minister K.D. Lalkantha. Meanwhile, the Finance Secretary, Dr. Harshana Suriyapperuma, expressed gratitude for the global support, noting contributions from 43 countries. The People's Leasing & Finance PLC has also been proactive, not only donating Rs. 10 million but also launching community projects and a hotline for affected individuals. The Island and Daily FT report on various corporate and community contributions, underscoring a collective effort to aid recovery. While all sources agree on the importance of the fund, the Daily News and The Island emphasize the role of local businesses, whereas The Morning highlights grassroots contributions, such as those from estate workers.
#
# Gemini:
#   (3.09s) Following Cyclone Ditwah, the Sri Lankan government established the "Rebuilding Sri Lanka" Fund to aid in disaster relief, economic recovery, and community development. Numerous local and international entities, including businesses, organizations, and individuals, have contributed financially to the fund. The Daily News, Daily FT, The Island, and The Morning all reported on these ongoing donations, highlighting specific contributions from companies like Kandy Spices Agro, People's Leasing & Finance, Commercial Bank of Ceylon, and ITOCHU Corporation, as well as associations and individual philanthropists. While most articles focused on the monetary value of donations, some, like the Daily News article on People's Leasing, emphasized additional support such as identifying affected families and providing a dedicated hotline. The Finance Secretary reported the fund has received over Rs. 4,286 million, including foreign currency deposits, and expressed gratitude for the widespread support. Minister Lalkantha assured the public that the government is utilizing the funds responsibly. The contributions reflect a collective effort to rebuild Sri Lanka after the devastating cyclone.
#
#
# ================================================================================
# Cluster: Govt. announces robust post-disaster rebuilding fund
# Articles: 10 from 3 sources
# ================================================================================
#
# Articles in cluster:
#   1. [Daily FT] Management Committee of ‘Rebuilding Sri Lanka’ Fund convenes...
#   2. [Daily FT] Govt. announces robust post-disaster rebuilding fund...
#   3. [The Island] Cabinet approves establishment of “Rebuilding Sri Lanka Fund”...
#   4. [Daily News] Ceylon Chamber affirms support for national recovery efforts following...
#   5. [The Island] Management Committee of the ‘Rebuilding Sri Lanka’ Fund Appointed with...
#   6. [Daily News] International partners reaffirm strong support for Sri Lanka’s relief ...
#   7. [Daily FT] Who decides what ‘Rebuilding’ looks like after Ditwah?...
#   8. [Daily FT] Nearly Rs. 700 m raised for ‘Rebuilding Sri Lanka’...
#   9. [Daily FT] Experience on rebuilding funds: Selective amnesia?...
#   10. [Daily News] Rs. 1,893 Million in local and foreign support secured for the ‘Rebuil...
#
# PRIMERA:
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 7,149 tokens (5,310 words)
#    Limit: 4,096 tokens
#    Lost: 3,053 tokens (~42.7% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#   (3.09s) Following Cyclone Ditwah, the Sri Lankan government established the "Rebuilding Sri Lanka" Fund to aid in disaster relief, economic recovery, and community development. Numerous local and international entities, including businesses, organizations, and individuals, have contributed financially to the fund. The Daily News, Daily FT, The Island, and The Morning all reported on these ongoing donations, highlighting specific contributions from companies like Kandy Spices Agro, People's Leasing & Finance, Commercial Bank of Ceylon, and ITOCHU Corporation, as well as associations and individual philanthropists. While most articles focused on the monetary value of donations, some, like the Daily News article on People's Leasing, emphasized additional support such as identifying affected families and providing a dedicated hotline. The Finance Secretary reported the fund has received over Rs. 4,286 million, including foreign currency deposits, and expressed gratitude for the widespread support. Minister Lalkantha assured the public that the government is utilizing the funds responsibly. The contributions reflect a collective effort to rebuild Sri Lanka after the devastating cyclone.
#
#
# ================================================================================
# Cluster: Govt. announces robust post-disaster rebuilding fund
# Articles: 10 from 3 sources
# ================================================================================
#
# Articles in cluster:
#   1. [Daily FT] Management Committee of ‘Rebuilding Sri Lanka’ Fund convenes...
#   2. [Daily FT] Govt. announces robust post-disaster rebuilding fund...
#   3. [The Island] Cabinet approves establishment of “Rebuilding Sri Lanka Fund”...
#   4. [Daily News] Ceylon Chamber affirms support for national recovery efforts following...
#   5. [The Island] Management Committee of the ‘Rebuilding Sri Lanka’ Fund Appointed with...
#   6. [Daily News] International partners reaffirm strong support for Sri Lanka’s relief ...
#   7. [Daily FT] Who decides what ‘Rebuilding’ looks like after Ditwah?...
#   8. [Daily FT] Nearly Rs. 700 m raised for ‘Rebuilding Sri Lanka’...
#   9. [Daily FT] Experience on rebuilding funds: Selective amnesia?...
#   10. [Daily News] Rs. 1,893 Million in local and foreign support secured for the ‘Rebuil...
#
# PRIMERA:
# ⚠️  WARNING: PRIMERA truncation detected!
#    Input: 7,149 tokens (5,310 words)
#    Limit: 4,096 tokens
#    Lost: 3,053 tokens (~42.7% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# Input ids are automatically padded from 7191 to 8192 to be a multiple of `config.attention_window`: 1024
#   (204.74s) The Management Committee of the ‘Rebuilding Sri Lanka’ Fund, established on the instructions of President Anura Kumara Dissanayake to assist the country’s recovery following Cyclone Ditwah, met yesterday morning at the Presidential Secretariat. The meeting was chaired by Labour Minister and Finance and Planning Deputy Minister Dr. Anil Jayantha Fernando. . The meeting further discussed the various ways in which State and private sector institutions, as well as individuals in Sri Lanka, could contribute to the national rebuilding process. ངསཁརོཤལའབགུཛྷདཧཨམཊཥ཈཯཮ཕཆཡཽཉཛིཞྲྀཚཀཙཅ཭ཋཀྵཇཱིཌྷ཰ཪླྀཌཱཿབྷཝདྷེགྷཫཬཎཟཻནཹཔཱུཾཷཐཏ�аໄ྄່໙ྤ໘ྨྲྙໜྦྼྣ໚྘໨࿄༁ໍ໲ໝྭྯྮྱྜ༄࿲༚༈༙༘༨༜�ྴ྿໴໤ྖྜྷ༢ྥྚ࿽ಲಿನತ�.ŽŁŽĀ໮༼༲࿴ಮ࿿ല্രীനලമප�, കാ
#
# LED:
#   (153.55s) , to Management in Sri Lanka’s public sector, and to the extent of the public sector and the Government of Sri Lanka, we’re not aware of the need for any of them. We’m not aware that the government of the Sri Lanka is not aware about the need of any of the government, we are not aware. We are not sure about the needs of the country. We were not aware the government was not aware, but we are aware that there is a need for the government to supply the following, We are also aware that government is not know about the government. We will not be aware of any need of the nation. We have not been aware the need to supply, we will not know. We also know that there are a need to provide for the nation to rebuild, we have been aware of a need of government to provide the nation with the necessary to rebuild the nation, We will be aware that we will be able to provide to the nation and the nation that will be rebuilding, we need to address the need. We need not be unaware that the nation is not ready to rebuild.We are not unaware of the lack of funds, we can not be sure the government will be ready to provide. We want to be sure that there will be no shortage of funds.We need to be aware the nation was not ready for the disaster, We need to help the nation as we need not to be expected. We must not be surprised by the nation being not ready. We can’t be expected to be the same. We do not know the need, we want to help. We shall be grateful to the government as we have to be ready.We will be the following: We need the nation not to have any problems, we must be ready for disaster, we also need to work with the nation of the following. We would be the first to be briefed on the disaster.We’ll be the next to be prepared. We should be the Committee of the same, We have been the same as we are now the first of the year. We expect the country to be on the path to recovery, we should be ready as the nation needs to be grateful.We must be prepared for disaster and we needn’ t be the other. We may be the committee of the committee. We did not know what to do. We needed to be in the process of the development. We had to be wary of the situation. We could not be expected the
#
# LongT5:
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 7,686 tokens (5,321 words)
#    Limit: 4,096 tokens
#    Lost: 3,590 tokens (~46.7% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#   (153.55s) , to Management in Sri Lanka’s public sector, and to the extent of the public sector and the Government of Sri Lanka, we’re not aware of the need for any of them. We’m not aware that the government of the Sri Lanka is not aware about the need of any of the government, we are not aware. We are not sure about the needs of the country. We were not aware the government was not aware, but we are aware that there is a need for the government to supply the following, We are also aware that government is not know about the government. We will not be aware of any need of the nation. We have not been aware the need to supply, we will not know. We also know that there are a need to provide for the nation to rebuild, we have been aware of a need of government to provide the nation with the necessary to rebuild the nation, We will be aware that we will be able to provide to the nation and the nation that will be rebuilding, we need to address the need. We need not be unaware that the nation is not ready to rebuild.We are not unaware of the lack of funds, we can not be sure the government will be ready to provide. We want to be sure that there will be no shortage of funds.We need to be aware the nation was not ready for the disaster, We need to help the nation as we need not to be expected. We must not be surprised by the nation being not ready. We can’t be expected to be the same. We do not know the need, we want to help. We shall be grateful to the government as we have to be ready.We will be the following: We need the nation not to have any problems, we must be ready for disaster, we also need to work with the nation of the following. We would be the first to be briefed on the disaster.We’ll be the next to be prepared. We should be the Committee of the same, We have been the same as we are now the first of the year. We expect the country to be on the path to recovery, we should be ready as the nation needs to be grateful.We must be prepared for disaster and we needn’ t be the other. We may be the committee of the committee. We did not know what to do. We needed to be in the process of the development. We had to be wary of the situation. We could not be expected the
#
# LongT5:
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 7,686 tokens (5,321 words)
#    Limit: 4,096 tokens
#    Lost: 3,590 tokens (~46.7% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
# ...
#
# LongT5:
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 5,040 tokens (3,782 words)
#    Limit: 4,096 tokens
#    Lost: 944 tokens (~18.7% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#   (104.10s) wah . The Government of Sri Lanka’s response to the cyclone and its impact on the lives of the people of the affected areas. We’re also aware of the need to mobilise resources for the recovery of the nation. We are also aware that we’ve seen the need for the nation to rebuild the country following the disaster. We also know that we have seen the impact of the disaster on the country. We have seen that the nation has seen the development of the destruction of the country, we are ready to mobilize resources to the nation following the disasters.We are aware that the country has seen that there is a need to mobilize the nation and the nation, we have been ready to work with the country to recover the nation from the devastation.We have also seen the findings of the widespread destruction of our nation, We will be ready to make the necessary adjustments of our project, we will be prepared to work on the nation after the crisis. We will also be ready for the people to recover from the destruction.We will be able to help the nation with the nation as we will work with our nation to recover. We need to ensure that our nation will not be affected by the disaster, we need to make sure the nation is ready to rebuild.We need to help Sri Lanka as we are able to provide the necessary assistance to the country after the devastation of the island. We must be ready the nation for the country as we need not to be affected.We’ll be ready as we have the nation ready to meet their needs daily projects. The UN is essential services, provide the hardest hit areas, We need not be the government. We do not need to wait for the government to respond to the disaster and we need the necessary help.We also need to be prepared for the disaster to the people. We want to be ready. The nation will be the first to respond. We would be ready and willing to meet the needs of our country.We would be prepared as the nation need to meet our needs, we would be the same as the disaster-hit areas, we must be prepared and ready to respond as we would need to. We were ready to be the following: We need the help of the government as we were ready. We needed to be on the ground.We must be the most ready to support the country and the country with the help to the community. We can be the only to provide a necessary assistance.We want to work as the country needs to recover
#
# LongT5:
# ⚠️  WARNING: LongT5 truncation detected!
#    Input: 5,040 tokens (3,782 words)
#    Limit: 4,096 tokens
#    Lost: 944 tokens (~18.7% of content)
#    Suggestion: Use LED (16K tokens) or Claude/Gemini for longer inputs
#   (153.69s) [Daily FT] In the aftermath of the devastating Cyclone Ditwah which caused massive losses to a number of families in the country, the Government is now facing the enormous challenge of providing humanitarian and financial assistance to those who lost their loved ones as well as people whose properties were either destroyed or damaged severely.” To guide recovery efforts, a Global Rapid Post-Disaster Damage Estimation (GRADE) assessment is already underway in partnership with the Global Facility for Disaster Risk Reduction (GFDRR). At the same time, we continue to coordinate closely with development partners to ensure that our collective efforts have the greatest possible impact and help Sri Lanka recover and rebuild for the long term.” [The Morning] The World Bank Group (WBG) is to extend $ 120 million in emergency support to Sri Lanka, by repurposing funds from its ongoing projects, in order to support recovery and infrastructure. [The Island] The United Nations has pledged US$4.5 million (LKR 1.38 billion) from its Central Emergency Response Fund (CERF) to strengthen Sri Lanka’s response to Cyclonic DitWah, which made landfall on 28 November. The funds will enable the UN to rapidly scale up emergency food assistance, shelter support, and water, sanitation and hygiene services for the communities most severely affected by the floods and landslides that have impacted the country. Communities across Sri Lanka are continuing to grapple with the widespread impacts of the cyclone, with thousands of families still displaced after extensive damage to housing and infrastructure.” Even as response efforts are underway, latest assessments indicate that the effects of the Cyclones are broader and more severe than initially understood, leaving many communities in urgent need of sustained support to fully recover from Cycline. The UN’s global emergency fund CERF enables rapid funding to humanitarian responders to help support life-saving, humanitarian activities in the initial stages of a sudden-onset crisis. As the full scale of the devastation becomes clearer, the UN will expand its life-saving assistance to the hardest-hit communities through a broader Humanitarian Priorities Plan, expected to be announced this week. The Government is already under fire for not acting proactively to mitigate the impact from the disaster in spite of receiving early warnings about the calamity both locally and internationally. Hence, the ruling party politicians are well advised to refrain from
#
# OpenAI:
#   (153.69s) [Daily FT] In the aftermath of the devastating Cyclone Ditwah which caused massive losses to a number of families in the country, the Government is now facing the enormous challenge of providing humanitarian and financial assistance to those who lost their loved ones as well as people whose properties were either destroyed or damaged severely.” To guide recovery efforts, a Global Rapid Post-Disaster Damage Estimation (GRADE) assessment is already underway in partnership with the Global Facility for Disaster Risk Reduction (GFDRR). At the same time, we continue to coordinate closely with development partners to ensure that our collective efforts have the greatest possible impact and help Sri Lanka recover and rebuild for the long term.” [The Morning] The World Bank Group (WBG) is to extend $ 120 million in emergency support to Sri Lanka, by repurposing funds from its ongoing projects, in order to support recovery and infrastructure. [The Island] The United Nations has pledged US$4.5 million (LKR 1.38 billion) from its Central Emergency Response Fund (CERF) to strengthen Sri Lanka’s response to Cyclonic DitWah, which made landfall on 28 November. The funds will enable the UN to rapidly scale up emergency food assistance, shelter support, and water, sanitation and hygiene services for the communities most severely affected by the floods and landslides that have impacted the country. Communities across Sri Lanka are continuing to grapple with the widespread impacts of the cyclone, with thousands of families still displaced after extensive damage to housing and infrastructure.” Even as response efforts are underway, latest assessments indicate that the effects of the Cyclones are broader and more severe than initially understood, leaving many communities in urgent need of sustained support to fully recover from Cycline. The UN’s global emergency fund CERF enables rapid funding to humanitarian responders to help support life-saving, humanitarian activities in the initial stages of a sudden-onset crisis. As the full scale of the devastation becomes clearer, the UN will expand its life-saving assistance to the hardest-hit communities through a broader Humanitarian Priorities Plan, expected to be announced this week. The Government is already under fire for not acting proactively to mitigate the impact from the disaster in spite of receiving early warnings about the calamity both locally and internationally. Hence, the ruling party politicians are well advised to refrain from
#
# OpenAI:
#   (5.94s) In response to the devastation caused by Cyclone Ditwah, the Sri Lankan government has activated emergency response components within World Bank-funded projects to expedite post-disaster reconstruction. The cyclone resulted in significant damage to infrastructure, agriculture, and housing, displacing thousands. The government plans to secure $92 million to $112 million from the World Bank for recovery activities, as reported by The Morning. The Daily FT highlights a comprehensive financial support program, including cash transfers for affected households and compensation for farmers and small businesses, despite fiscal pressures from the IMF program. The UN has allocated $4.5 million from its Central Emergency Response Fund to bolster food, shelter, and sanitation services, as noted by The Island. Meanwhile, the World Bank has repurposed $120 million from ongoing projects to restore essential services and infrastructure, with a Global Rapid Post-Disaster Damage Estimation assessment underway to guide recovery efforts. However, The Daily FT and The Island report concerns over potential politicization and inefficiencies in relief distribution, echoing past challenges in disaster response. Overall, while international and domestic efforts are underway, ensuring transparent and effective aid distribution remains a critical challenge.
#
# Gemini:
#   (5.94s) In response to the devastation caused by Cyclone Ditwah, the Sri Lankan government has activated emergency response components within World Bank-funded projects to expedite post-disaster reconstruction. The cyclone resulted in significant damage to infrastructure, agriculture, and housing, displacing thousands. The government plans to secure $92 million to $112 million from the World Bank for recovery activities, as reported by The Morning. The Daily FT highlights a comprehensive financial support program, including cash transfers for affected households and compensation for farmers and small businesses, despite fiscal pressures from the IMF program. The UN has allocated $4.5 million from its Central Emergency Response Fund to bolster food, shelter, and sanitation services, as noted by The Island. Meanwhile, the World Bank has repurposed $120 million from ongoing projects to restore essential services and infrastructure, with a Global Rapid Post-Disaster Damage Estimation assessment underway to guide recovery efforts. However, The Daily FT and The Island report concerns over potential politicization and inefficiencies in relief distribution, echoing past challenges in disaster response. Overall, while international and domestic efforts are underway, ensuring transparent and effective aid distribution remains a critical challenge.
#
# Gemini:
#   (3.17s) Following the devastation caused by Cyclone Ditwah, the Sri Lankan government and international organizations are mobilizing resources for disaster relief and reconstruction. The government has announced a comprehensive financial support program, including direct cash transfers, housing reconstruction grants (up to Rs. 5 million for total loss), and compensation for affected sectors like agriculture and small businesses. To fund these efforts, the government is seeking approximately $200 million from the IMF and has requested an increase to the next tranche under the External Fund Facility (EFF). The World Bank Group is providing up to $120 million by repurposing existing project funds to restore essential services like healthcare, water, education, and infrastructure. The UN has also allocated $4.5 million from its Central Emergency Response Fund (CERF) for emergency food, shelter, and WASH services. A Global Rapid Post-Disaster Damage Estimation (GRADE) assessment is underway to guide recovery efforts. Concerns have been raised regarding potential political interference and misuse of funds in the distribution of aid, echoing issues from past disaster relief efforts. The government has been urged to ensure transparency and prevent corruption in the aid distribution process.
#
#
# Saving cluster results...
#   ✓ Saved primera clusters to cache (primera_clusters.json)
#   ✓ Saved led clusters to cache (led_clusters.json)
#   ✓ Saved longt5 clusters to cache (longt5_clusters.json)
#   ✓ Saved openai clusters to cache (openai_clusters.json)
#   ✓ Saved gemini clusters to cache (gemini_clusters.json)
#
# ================================================================================
# Cluster testing complete
# ================================================================================
#   (3.17s) Following the devastation caused by Cyclone Ditwah, the Sri Lankan government and international organizations are mobilizing resources for disaster relief and reconstruction. The government has announced a comprehensive financial support program, including direct cash transfers, housing reconstruction grants (up to Rs. 5 million for total loss), and compensation for affected sectors like agriculture and small businesses. To fund these efforts, the government is seeking approximately $200 million from the IMF and has requested an increase to the next tranche under the External Fund Facility (EFF). The World Bank Group is providing up to $120 million by repurposing existing project funds to restore essential services like healthcare, water, education, and infrastructure. The UN has also allocated $4.5 million from its Central Emergency Response Fund (CERF) for emergency food, shelter, and WASH services. A Global Rapid Post-Disaster Damage Estimation (GRADE) assessment is underway to guide recovery efforts. Concerns have been raised regarding potential political interference and misuse of funds in the distribution of aid, echoing issues from past disaster relief efforts. The government has been urged to ensure transparency and prevent corruption in the aid distribution process.
#
#
# Saving cluster results...
#   ✓ Saved primera clusters to cache (primera_clusters.json)
#   ✓ Saved led clusters to cache (led_clusters.json)
#   ✓ Saved longt5 clusters to cache (longt5_clusters.json)
#   ✓ Saved openai clusters to cache (openai_clusters.json)
#   ✓ Saved gemini clusters to cache (gemini_clusters.json)
#
# ================================================================================
# Cluster testing complete
# ================================================================================

# %%
# Cell 15: Compare cluster summaries
print("\nEvent Cluster Summaries Comparison\n" + "="*80 + "\n")

# Create comparison dataframe
cluster_comparison_data = []
for method_name, results in cluster_results_by_method.items():
    for result in results:
        cluster_comparison_data.append({
            'Method': method_name,
            'Cluster': result['group'][:30] + '...' if len(result['group']) > 30 else result['group'],
            'Time (s)': f"{result['processing_time']:.2f}",
            'Words': result['word_count'],
            'Articles': result['article_count']
        })

cluster_comparison_df = pd.DataFrame(cluster_comparison_data)
display(cluster_comparison_df)

# Summary statistics
print("\n" + "="*80)
print("Summary Statistics (Event Clusters)")
print("="*80)
for method in ['PRIMERA', 'LED', 'LongT5', 'OpenAI', 'Gemini']:
    method_data = cluster_comparison_df[cluster_comparison_df['Method'] == method]
    avg_time = method_data['Time (s)'].astype(float).mean()
    avg_words = method_data['Words'].mean()
    print(f"{method:12s} - Avg time: {avg_time:5.2f}s, Avg words: {avg_words:6.1f}")
# Out:
# Event Cluster Summaries Comparison
# ================================================================================
#      Method                            Cluster Time (s)  Words  Articles
# 0   PRIMERA  Sri Lankan economy still vulne...   213.25    394        10
# 1   PRIMERA  Two financial contributions re...   155.51    160        10
# 2   PRIMERA  Govt. announces robust post-di...   204.74     81        10
# 3   PRIMERA              The burden of neglect   200.49    157        10
# 4   PRIMERA  World Bank to inject US$120 Mn...   221.49    103        10
# 5       LED  Sri Lankan economy still vulne...   273.33    427        10
# 6       LED  Two financial contributions re...    48.18    378        10
# 7       LED  Govt. announces robust post-di...   153.55    445        10
# 8       LED              The burden of neglect   302.94    440        10
# 9       LED  World Bank to inject US$120 Mn...   104.10    450        10
# 10   LongT5  Sri Lankan economy still vulne...   143.51    331        10
# 11   LongT5  Two financial contributions re...   120.11    336        10
# 12   LongT5  Govt. announces robust post-di...   148.28    334        10
# 13   LongT5              The burden of neglect   156.07    374        10
# 14   LongT5  World Bank to inject US$120 Mn...   153.69    382        10
# 15   OpenAI  Sri Lankan economy still vulne...     8.87    251        10
# 16   OpenAI  Two financial contributions re...     6.54    183        10
# 17   OpenAI  Govt. announces robust post-di...     6.38    218        10
# 18   OpenAI              The burden of neglect     5.92    173        10
# 19   OpenAI  World Bank to inject US$120 Mn...     5.94    185        10
# 20   Gemini  Sri Lankan economy still vulne...     3.37    170        10
# 21   Gemini  Two financial contributions re...     3.09    164        10
# 22   Gemini  Govt. announces robust post-di...     3.24    182        10
# 23   Gemini              The burden of neglect     3.45    175        10
# 24   Gemini  World Bank to inject US$120 Mn...     3.17    185        10
# ================================================================================
# Summary Statistics (Event Clusters)
# ================================================================================
# PRIMERA      - Avg time: 199.10s, Avg words:  179.0
# LED          - Avg time: 176.42s, Avg words:  428.0
# LongT5       - Avg time: 144.33s, Avg words:  351.4
# OpenAI       - Avg time:  6.73s, Avg words:  202.0
# Gemini       - Avg time:  3.26s, Avg words:  175.2

# %% [markdown]
# ## Section 4: Performance Analysis

# %%
# Cell 16: Processing time comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Topics
topic_times = {}
for method, results in [
    ('PRIMERA', primera_topic_results),
    ('LED', led_topic_results),
    ('LongT5', longt5_topic_results),
    ('OpenAI', openai_topic_results),
    ('Gemini', gemini_topic_results)
]:
    topic_times[method] = [r['processing_time'] for r in results]

axes[0].bar(topic_times.keys(), [sum(times)/len(times) for times in topic_times.values()])
axes[0].set_title('Average Processing Time - Topics')
axes[0].set_ylabel('Time (seconds)')
axes[0].tick_params(axis='x', rotation=45)

# Clusters
cluster_times = {}
for method, results in cluster_results_by_method.items():
    cluster_times[method] = [r['processing_time'] for r in results]

axes[1].bar(cluster_times.keys(), [sum(times)/len(times) for times in cluster_times.values()])
axes[1].set_title('Average Processing Time - Event Clusters')
axes[1].set_ylabel('Time (seconds)')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# Cell 18: Summary statistics
# Word count distribution per method
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Topics
topic_word_counts = {}
for method, results in [
    ('PRIMERA', primera_topic_results),
    ('LED', led_topic_results),
    ('LongT5', longt5_topic_results),
    ('OpenAI', openai_topic_results),
    ('Gemini', gemini_topic_results)
]:
    topic_word_counts[method] = [r['word_count'] for r in results]

axes[0].bar(topic_word_counts.keys(), [sum(counts)/len(counts) for counts in topic_word_counts.values()])
axes[0].set_title('Average Summary Length - Topics')
axes[0].set_ylabel('Word Count')
axes[0].tick_params(axis='x', rotation=45)

# Clusters
cluster_word_counts = {}
for method, results in cluster_results_by_method.items():
    cluster_word_counts[method] = [r['word_count'] for r in results]

axes[1].bar(cluster_word_counts.keys(), [sum(counts)/len(counts) for counts in cluster_word_counts.values()])
axes[1].set_title('Average Summary Length - Event Clusters')
axes[1].set_ylabel('Word Count')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# Cell 21: Close database connection
db.close()
print("✓ Database connection closed")
print("\nNotebook complete!")
# Out:
# ✓ Database connection closed
#
# Notebook complete!
